# %%
import pandas as pd
from sqlalchemy import create_engine, Integer, VARCHAR
from util import consts
from collections import Counter
from seg import segmentation 


engine = create_engine(consts.MYSQL_CONNECTION_PMS)
connect = engine.connect()

# %%
sql = 'select story, title, spec from zt_storyspec'
story_df = pd.read_sql(sql, engine)
from nohtml import strip_tags
story_df['spec'] = story_df['spec'].apply(lambda x:strip_tags(x))
story_df = story_df.loc[story_df['story'].drop_duplicates().index,:]

story_df = story_df.set_index(story_df['story'].values)

story_df
# Out:
#       story                               title  \
# 1         1                               加密狗选型
# 2         2                      特定情况下的外框最后排序问题
# 3         3                      带膜切割开发一个直接跟随选项
# 4         4                         双交换工作台的到位检测
# 5         5                        CypOne动态速度算法
# ...     ...                                 ...
# 4647   4647  设计喷码装机界面，将原调试界面中属于第一次装机才设置的参数提取出来。
# 4648   4648                           优化喷码调试界面。
# 4649   4649                          增加断点续喷的功能。
# 4650   4650              提供只喷码，只加工，喷码并加工三种加工方式。
# 4651   4651                      每个分组都能够设置定位补偿值
#
#                                                    spec
# 1              选择一个合适的加密狗，带有硬件时钟，稳定性好，供应商信誉好，供货稳定，价格偏移。
# 2     类似于\n打标图层\n:\n开放一个\n最后切割图层\n, \n以弥补和应对\n新排序原则下...
# 3           目前带膜切割采用的是类似于定高切割规则执行，能满足大多数需求。\n但是如果切割板...
# 4     \r\n需求由天琪、迪能提出\r\n\r\n目前双交换工作台是用手工方式来控制的，也就是客户...
# 5     1. 在不同速度下算法的切换。\r\n    1）速度\r\n < 10mmm/s \r\n...
# ...                                                 ...
# 4647  【内部迭代需求】\n         基于功能点文档优化界面显示。功能点文档参考：http:...
# 4648  【内部迭代需求】\n         基于功能点文档优化界面显示。功能点文档参考：http:...
# 4649  【内部迭代需求】\n           在喷码的过程中可能会遇到客户人为暂停或者停止，也可...
# 4650  【内部迭代需求】\n          在切割系统中喷码是一个非必须的操作，即使文件里面包含...
# 4651  作为青虹的马工，我在设置4个分组进行定位切割时，发现各个分组切割后的误差情况并不相同。此时，...
#
# [4651 rows x 3 columns]

# %%
dict(story_df.loc[1,:])
# Out:
# {'story': 1,
#  'title': '加密狗选型',
#  'spec': '选择一个合适的加密狗，带有硬件时钟，稳定性好，供应商信誉好，供货稳定，价格偏移。'}

# %%
words = Counter()
words['n'] = len(story_df)
story_df['seg'] = ''
for i in range(1, len(story_df) + 1):
    seg = segmentation((story_df['title'][i] + story_df['spec'][i]).split())
    word_count = Counter(seg)
    print(i)
    print(word_count)
    wordn = sum(word_count.values())
    for word in word_count:
        word_count[word] = word_count[word]/wordn
    print(word_count)
        
        
    story_df['seg'][i] = word_count
    words += Counter(word_count.keys())
# Out:
# 1
# Counter({'加密狗': 2, '选型': 1, '硬件': 1, '时钟': 1, '稳定性': 1, '信誉': 1, '供货': 1, '价格': 1})
# Counter({'加密狗': 0.2222222222222222, '选型': 0.1111111111111111, '硬件': 0.1111111111111111, '时钟': 0.1111111111111111, '稳定性': 0.1111111111111111, '信誉': 0.1111111111111111, '供货': 0.1111111111111111, '价格': 0.1111111111111111})
# 2
# Counter({'排序': 3, '外框': 2, '原则': 2, '标图': 1, '图层': 1, '图形': 1})
# Counter({'排序': 0.3, '外框': 0.2, '原则': 0.2, '标图': 0.1, '图层': 0.1, '图形': 0.1})
# 3
# Counter({'板材': 3, '规则': 2, '选项': 1, '水平度': 1, '曲面': 1, '模式': 1, '带膜': 1})
# Counter({'板材': 0.3, '规则': 0.2, '选项': 0.1, '水平度': 0.1, '曲面': 0.1, '模式': 0.1, '带膜': 0.1})
# 4
# Counter({'工作台': 5, '按钮': 3, '气缸': 3, '手工': 2, '动作': 2, '信号': 2, '控制卡': 2, '由天琪': 1, '迪能': 1, '钢板': 1, '硬件': 1, '条件': 1, '行程开关': 1})
# Counter({'工作台': 0.2, '按钮': 0.12, '气缸': 0.12, '手工': 0.08, '动作': 0.08, '信号': 0.08, '控制卡': 0.08, '由天琪': 0.04, '迪能': 0.04, '钢板': 0.04, '硬件': 0.04, '条件': 0.04, '行程开关': 0.04})
# 5
# Counter({'加速度': 7, 'FBFW3': 5, 'mmm': 4, '滤波器': 2, '控制精度': 2, 'CypOne': 1, '动态': 1, 'and': 1, 'MaxAcc': 1, 'WorkSpeed': 1, 'Acc': 1, 'FIRFreq': 1, '通滤波': 1, '频率': 1, 'ArcTolerance': 1, '圆弧': 1, 'CornerTolerance': 1, '拐角': 1, 'SplitTime': 1, '边框': 1})
# Counter({'加速度': 0.2, 'FBFW3': 0.14285714285714285, 'mmm': 0.11428571428571428, '滤波器': 0.05714285714285714, '控制精度': 0.05714285714285714, 'CypOne': 0.02857142857142857, '动态': 0.02857142857142857, 'and': 0.02857142857142857, 'MaxAcc': 0.02857142857142857, 'WorkSpeed': 0.02857142857142857, 'Acc': 0.02857142857142857, 'FIRFreq': 0.02857142857142857, '通滤波': 0.02857142857142857, '频率': 0.02857142857142857, 'ArcTolerance': 0.02857142857142857, '圆弧': 0.02857142857142857, 'CornerTolerance': 0.02857142857142857, '拐角': 0.02857142857142857, 'SplitTime': 0.02857142857142857, '边框': 0.02857142857142857})
# 6
# Counter({'程序': 3, '任务栏': 3, 'Windows': 2, 'CypCut': 2, '对话框': 1, 'Cypcut': 1})
# Counter({'程序': 0.25, '任务栏': 0.25, 'Windows': 0.16666666666666666, 'CypCut': 0.16666666666666666, '对话框': 0.08333333333333333, 'Cypcut': 0.08333333333333333})
# 7
# Counter({'板子': 1, '角度': 1, '板边': 1, '距离': 1})
# Counter({'板子': 0.25, '角度': 0.25, '板边': 0.25, '距离': 0.25})
# 8
# Counter({'雷达': 1, '图形': 1})
# Counter({'雷达': 0.5, '图形': 0.5})
# 9
# Counter({'功率': 7, '曲线': 5, '方法': 2, '单调': 1, '半速': 1, '成功率': 1, '规律': 1})
# Counter({'功率': 0.3888888888888889, '曲线': 0.2777777777777778, '方法': 0.1111111111111111, '单调': 0.05555555555555555, '半速': 0.05555555555555555, '成功率': 0.05555555555555555, '规律': 0.05555555555555555})
# 10
# Counter({'高度': 4, '方管': 2})
# Counter({'高度': 0.6666666666666666, '方管': 0.3333333333333333})
# 11
# Counter({'圆管': 3, '图形': 3, '文字': 2, '灯具': 1, '艺术': 1, '造型': 1, '平面': 1})
# Counter({'圆管': 0.25, '图形': 0.25, '文字': 0.16666666666666666, '灯具': 0.08333333333333333, '艺术': 0.08333333333333333, '造型': 0.08333333333333333, '平面': 0.08333333333333333})
# 12
# Counter({'开机': 2, '画面': 2, '制造商': 1, '出厂': 1, '示教盒': 1, '认知度': 1})
# Counter({'开机': 0.25, '画面': 0.25, '制造商': 0.125, '出厂': 0.125, '示教盒': 0.125, '认知度': 0.125})
# 13
# Counter({'加密': 2, '注册码': 2, '制造商': 1, 'BCS100': 1, '天数': 1, '序列号': 1, '贷款': 1, '银行': 1})
# Counter({'加密': 0.2, '注册码': 0.2, '制造商': 0.1, 'BCS100': 0.1, '天数': 0.1, '序列号': 0.1, '贷款': 0.1, '银行': 0.1})
# 14
# Counter({'cypcut': 1, '场合': 1})
# Counter({'cypcut': 0.5, '场合': 0.5})
# 15
# Counter({'人机界面': 3, '经理': 1, 'CypCut': 1, '无线': 1, '面板': 1, '场合': 1, '体验': 1})
# Counter({'人机界面': 0.3333333333333333, '经理': 0.1111111111111111, 'CypCut': 0.1111111111111111, '无线': 0.1111111111111111, '面板': 0.1111111111111111, '场合': 0.1111111111111111, '体验': 0.1111111111111111})
# 16
# Counter({'人机界面': 3, '状态': 2, '经理': 1, '面板': 1})
# Counter({'人机界面': 0.42857142857142855, '状态': 0.2857142857142857, '经理': 0.14285714285714285, '面板': 0.14285714285714285})
# 17
# Counter({'动作': 1})
# Counter({'动作': 1.0})
# 18
# d:\Users\fscut\anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# Counter({'圆管': 4, '天琪': 2, '地方': 2, '间距': 2, '旋转轴': 2, '武汉': 1, '管径': 1, '角度': 1, '编程': 1, '方管': 1, '全局': 1, '减速比': 1})
# Counter({'圆管': 0.21052631578947367, '天琪': 0.10526315789473684, '地方': 0.10526315789473684, '间距': 0.10526315789473684, '旋转轴': 0.10526315789473684, '武汉': 0.05263157894736842, '管径': 0.05263157894736842, '角度': 0.05263157894736842, '编程': 0.05263157894736842, '方管': 0.05263157894736842, '全局': 0.05263157894736842, '减速比': 0.05263157894736842})
# 19
# Counter({'开发人员': 2, '体验': 2, '键盘': 1, '强制性': 1})
# Counter({'开发人员': 0.3333333333333333, '体验': 0.3333333333333333, '键盘': 0.16666666666666666, '强制性': 0.16666666666666666})
# 20
# Counter({'人机界面': 2, '面板': 2, '独立性': 1, '时则': 1})
# Counter({'人机界面': 0.3333333333333333, '面板': 0.3333333333333333, '独立性': 0.16666666666666666, '时则': 0.16666666666666666})
# 21
# Counter({'加密': 4, '计时': 3, 'DSP3000': 2, '系列产品': 2, 'BCS100': 1, '时钟': 1, '电池': 1})
# Counter({'加密': 0.2857142857142857, '计时': 0.21428571428571427, 'DSP3000': 0.14285714285714285, '系列产品': 0.14285714285714285, 'BCS100': 0.07142857142857142, '时钟': 0.07142857142857142, '电池': 0.07142857142857142})
# 22
# Counter({'钥匙': 2, '工具': 2, '恒顺': 1, '老板': 1, '小弟': 1, '权限': 1, '电脑': 1})
# Counter({'钥匙': 0.2222222222222222, '工具': 0.2222222222222222, '恒顺': 0.1111111111111111, '老板': 0.1111111111111111, '小弟': 0.1111111111111111, '权限': 0.1111111111111111, '电脑': 0.1111111111111111})
# 23
# Counter({'板材': 1, '距离': 1, '高度': 1})
# Counter({'板材': 0.3333333333333333, '距离': 0.3333333333333333, '高度': 0.3333333333333333})
# 24
# Counter({'微狗': 2, '许可证': 2, '加密狗': 1, '载体': 1})
# Counter({'微狗': 0.3333333333333333, '许可证': 0.3333333333333333, '加密狗': 0.16666666666666666, '载体': 0.16666666666666666})
# 25
# Counter({'DSP3000M': 1, '抗干扰性': 1, '恒顺': 1, '通讯': 1, '键盘': 1})
# Counter({'DSP3000M': 0.2, '抗干扰性': 0.2, '恒顺': 0.2, '通讯': 0.2, '键盘': 0.2})
# 26
# Counter({'伺服电机': 1, '报警信号': 1})
# Counter({'伺服电机': 0.5, '报警信号': 0.5})
# 27
# Counter({'间距': 3, '不合理': 1, '步骤': 1, '边缘': 1, '材料': 1, '引刀': 1, '线会': 1, '期望值': 1, '等离子': 1})
# Counter({'间距': 0.2727272727272727, '不合理': 0.09090909090909091, '步骤': 0.09090909090909091, '边缘': 0.09090909090909091, '材料': 0.09090909090909091, '引刀': 0.09090909090909091, '线会': 0.09090909090909091, '期望值': 0.09090909090909091, '等离子': 0.09090909090909091})
# 28
# Counter({'恒顺': 1, '序列号': 1, '解密': 1, '密码': 1})
# Counter({'恒顺': 0.25, '序列号': 0.25, '解密': 0.25, '密码': 0.25})
# 29
# Counter({'NCK': 2, '限位': 1, '单轴': 1, '误差': 1, '龙门': 1, '基本功能': 1, '主轴': 1})
# Counter({'NCK': 0.25, '限位': 0.125, '单轴': 0.125, '误差': 0.125, '龙门': 0.125, '基本功能': 0.125, '主轴': 0.125})
# 30
# Counter({'序列号': 3, '钥匙': 2, '加密狗': 2, '制造商': 1, '加密': 1, '商务': 1})
# Counter({'序列号': 0.3, '钥匙': 0.2, '加密狗': 0.2, '制造商': 0.1, '加密': 0.1, '商务': 0.1})
# 31
# Counter({'DSP3000': 1, '序列号': 1, '注册码': 1, '规则': 1, '上位': 1})
# Counter({'DSP3000': 0.2, '序列号': 0.2, '注册码': 0.2, '规则': 0.2, '上位': 0.2})
# 32
# Counter({'CLR': 2, '管脚': 1, '武汉': 1, '嘉铭': 1, '清空': 1, '错误': 1, '欧系': 1})
# Counter({'CLR': 0.25, '管脚': 0.125, '武汉': 0.125, '嘉铭': 0.125, '清空': 0.125, '错误': 0.125, '欧系': 0.125})
# 33
# Counter({'信号': 2, 'PLC': 1, '编程': 1, '韩国': 1, 'bjlaser': 1})
# Counter({'信号': 0.3333333333333333, 'PLC': 0.16666666666666666, '编程': 0.16666666666666666, '韩国': 0.16666666666666666, 'bjlaser': 0.16666666666666666})
# 34
# Counter({'地方': 2, '路径': 1, '有点': 1, '明灯': 1})
# Counter({'地方': 0.4, '路径': 0.2, '有点': 0.2, '明灯': 0.2})
# 35
# Counter({'通讯': 2, '飞博': 1, '协议': 1, '应飞博': 1, '老总': 1})
# Counter({'通讯': 0.3333333333333333, '飞博': 0.16666666666666666, '协议': 0.16666666666666666, '应飞博': 0.16666666666666666, '老总': 0.16666666666666666})
# 36
# Counter({'中科': 2, '光辉': 2, '通讯': 2, '技术人员': 1, '嘉泰': 1, '陈大健': 1, '个带': 1, 'CypCut': 1, '市场': 1})
# Counter({'中科': 0.16666666666666666, '光辉': 0.16666666666666666, '通讯': 0.16666666666666666, '技术人员': 0.08333333333333333, '嘉泰': 0.08333333333333333, '陈大健': 0.08333333333333333, '个带': 0.08333333333333333, 'CypCut': 0.08333333333333333, '市场': 0.08333333333333333})
# 37
# Counter({'单位': 3, '英寸': 2, '市场': 1, '大量': 1, '终端用户': 1, '制造商': 1, '机制': 1, '国际友人': 1, '习惯': 1})
# Counter({'单位': 0.25, '英寸': 0.16666666666666666, '市场': 0.08333333333333333, '大量': 0.08333333333333333, '终端用户': 0.08333333333333333, '制造商': 0.08333333333333333, '机制': 0.08333333333333333, '国际友人': 0.08333333333333333, '习惯': 0.08333333333333333})
# 38
# Counter({'画面': 4, '开机': 3, '迪能': 1, 'oem': 1, '警告': 1, '图片': 1})
# Counter({'画面': 0.36363636363636365, '开机': 0.2727272727272727, '迪能': 0.09090909090909091, 'oem': 0.09090909090909091, '警告': 0.09090909090909091, '图片': 0.09090909090909091})
# 39
# Counter({'BCP5045': 1, 'LED': 1, '亮度': 1, 'SIEMENS': 1})
# Counter({'BCP5045': 0.25, 'LED': 0.25, '亮度': 0.25, 'SIEMENS': 0.25})
# 40
# Counter({'相框': 1, '图形': 1, '乐创': 1, '硬件': 1, '级联': 1, '项目经理': 1, '王仕卿': 1})
# Counter({'相框': 0.14285714285714285, '图形': 0.14285714285714285, '乐创': 0.14285714285714285, '硬件': 0.14285714285714285, '级联': 0.14285714285714285, '项目经理': 0.14285714285714285, '王仕卿': 0.14285714285714285})
# 41
# Counter({'磁铁': 3, '磁力': 1, '教盒': 1})
# Counter({'磁铁': 0.6, '磁力': 0.2, '教盒': 0.2})
# 42
# Counter({'文字': 4, '迪能周': 1, '橙色': 1, '黄色': 1, '身体': 1, '区域': 1, '标题栏': 1, 'BCS100': 1})
# Counter({'文字': 0.36363636363636365, '迪能周': 0.09090909090909091, '橙色': 0.09090909090909091, '黄色': 0.09090909090909091, '身体': 0.09090909090909091, '区域': 0.09090909090909091, '标题栏': 0.09090909090909091, 'BCS100': 0.09090909090909091})
# 43
# Counter({'间隔': 1, '小时': 1, '金厂': 1, '工件': 1})
# Counter({'间隔': 0.25, '小时': 0.25, '金厂': 0.25, '工件': 0.25})
# 44
# Counter({'发票': 1})
# Counter({'发票': 1.0})
# 45
# Counter({'PWM': 2, '胶量': 2, '胶头': 1, '创新性': 1, '滴塑': 1, '拐弯': 1, '整体': 1, '功率': 1})
# Counter({'PWM': 0.2, '胶量': 0.2, '胶头': 0.1, '创新性': 0.1, '滴塑': 0.1, '拐弯': 0.1, '整体': 0.1, '功率': 0.1})
# 46
# Counter({'面板': 4, '网络连接': 1, '网络结构': 1, '网线': 1, '网卡': 1, '交换机': 1})
# Counter({'面板': 0.4444444444444444, '网络连接': 0.1111111111111111, '网络结构': 0.1111111111111111, '网线': 0.1111111111111111, '网卡': 0.1111111111111111, '交换机': 0.1111111111111111})
# 47
# Counter({'OEM': 4, '列表': 3, '数据库': 2, '市场': 2, '编辑': 1, '经理': 1, '工具': 1, '厂家': 1, '资源': 1})
# Counter({'OEM': 0.25, '列表': 0.1875, '数据库': 0.125, '市场': 0.125, '编辑': 0.0625, '经理': 0.0625, '工具': 0.0625, '厂家': 0.0625, '资源': 0.0625})
# 48
# Counter({'开机': 2, '画面': 2})
# Counter({'开机': 0.5, '画面': 0.5})
# 49
# Counter({'次数': 10, '文件': 10, '管理者': 6, '密码': 4, '计数': 3, '加密': 2, '手动': 2, '数量': 2, '菜单': 1, '使用者': 1, '电脑': 1, '试用版': 1, '上将': 1, 'Userconfig': 1, '条件': 1})
# Counter({'次数': 0.21739130434782608, '文件': 0.21739130434782608, '管理者': 0.13043478260869565, '密码': 0.08695652173913043, '计数': 0.06521739130434782, '加密': 0.043478260869565216, '手动': 0.043478260869565216, '数量': 0.043478260869565216, '菜单': 0.021739130434782608, '使用者': 0.021739130434782608, '电脑': 0.021739130434782608, '试用版': 0.021739130434782608, '上将': 0.021739130434782608, 'Userconfig': 0.021739130434782608, '条件': 0.021739130434782608})
# 50
# Counter({'动作': 2, 'PLC': 2, 'PIC': 1, '端口': 1, '庆源': 1, '零点': 1, '定义': 1, '工作台': 1, '风险': 1, '类型': 1})
# Counter({'动作': 0.16666666666666666, 'PLC': 0.16666666666666666, 'PIC': 0.08333333333333333, '端口': 0.08333333333333333, '庆源': 0.08333333333333333, '零点': 0.08333333333333333, '定义': 0.08333333333333333, '工作台': 0.08333333333333333, '风险': 0.08333333333333333, '类型': 0.08333333333333333})
# 51
# Counter({'按钮': 1, '区域': 1, '画圆': 1, '原点': 1, '零点': 1})
# Counter({'按钮': 0.2, '区域': 0.2, '画圆': 0.2, '原点': 0.2, '零点': 0.2})
# 52
# Counter({'氮气': 3, '高低压': 2, '流量': 2, '广州': 1, '海目': 1, '气路': 1, '原理图': 1, '附件': 1, '空气': 1, '氧气': 1, '高压': 1, '单向': 1, '电磁阀': 1, '端口': 1})
# Counter({'氮气': 0.16666666666666666, '高低压': 0.1111111111111111, '流量': 0.1111111111111111, '广州': 0.05555555555555555, '海目': 0.05555555555555555, '气路': 0.05555555555555555, '原理图': 0.05555555555555555, '附件': 0.05555555555555555, '空气': 0.05555555555555555, '氧气': 0.05555555555555555, '高压': 0.05555555555555555, '单向': 0.05555555555555555, '电磁阀': 0.05555555555555555, '端口': 0.05555555555555555})
# 53
# Counter({'一段距离': 1, '刚性': 1, '床子': 1, '因素': 1, '距离': 1, '原地': 1, '烧点': 1, '手动': 1, '整体': 1})
# Counter({'一段距离': 0.1111111111111111, '刚性': 0.1111111111111111, '床子': 0.1111111111111111, '因素': 0.1111111111111111, '距离': 0.1111111111111111, '原地': 0.1111111111111111, '烧点': 0.1111111111111111, '手动': 0.1111111111111111, '整体': 0.1111111111111111})
# 54
# Counter({'并联': 1, '架构': 1, '网络': 1, '调高器': 1, '损失': 1, '性价比': 1, '产生': 1, '替代': 1})
# Counter({'并联': 0.125, '架构': 0.125, '网络': 0.125, '调高器': 0.125, '损失': 0.125, '性价比': 0.125, '产生': 0.125, '替代': 0.125})
# 55
# Counter({'并联': 1, '架构': 1, '网络': 1, '调高器': 1, '损失': 1, '性价比': 1, '产生': 1, '替代': 1})
# Counter({'并联': 0.125, '架构': 0.125, '网络': 0.125, '调高器': 0.125, '损失': 0.125, '性价比': 0.125, '产生': 0.125, '替代': 0.125})
# 56
# Counter({'轨迹': 3, '吹气': 2, '板材': 2, '热加工': 1, '效应': 1, '高精度': 1, '误差': 1, '可选择性': 1})
# Counter({'轨迹': 0.25, '吹气': 0.16666666666666666, '板材': 0.16666666666666666, '热加工': 0.08333333333333333, '效应': 0.08333333333333333, '高精度': 0.08333333333333333, '误差': 0.08333333333333333, '可选择性': 0.08333333333333333})
# 57
# Counter({'板材': 2, '高度': 2, '穿孔': 2, '规则': 1, '用法': 1, '浮渣': 1, '温漂': 1, 'PLC': 1, '不锈钢': 1, '分段': 1, '传统': 1})
# Counter({'板材': 0.14285714285714285, '高度': 0.14285714285714285, '穿孔': 0.14285714285714285, '规则': 0.07142857142857142, '用法': 0.07142857142857142, '浮渣': 0.07142857142857142, '温漂': 0.07142857142857142, 'PLC': 0.07142857142857142, '不锈钢': 0.07142857142857142, '分段': 0.07142857142857142, '传统': 0.07142857142857142})
# 58
# Counter({'计时': 3, '自润滑': 1, '延时': 1, '润滑油': 1, '间隔': 1})
# Counter({'计时': 0.42857142857142855, '自润滑': 0.14285714285714285, '延时': 0.14285714285714285, '润滑油': 0.14285714285714285, '间隔': 0.14285714285714285})
# 59
# Counter({'俄文版': 1, 'Cyp': 1})
# Counter({'俄文版': 0.5, 'Cyp': 0.5})
# 60
# Counter({'幅面': 6, '市场': 1, '机型': 1, '交换式': 1, '效率': 1})
# Counter({'幅面': 0.6, '市场': 0.1, '机型': 0.1, '交换式': 0.1, '效率': 0.1})
# 61
# Counter({'山大鲁': 1, '英文版': 1, '页面': 1, '网站': 1, 'PLC': 1, '编辑': 1, '框框': 1, '红色': 1, '字体': 1, '平台': 1})
# Counter({'山大鲁': 0.1, '英文版': 0.1, '页面': 0.1, '网站': 0.1, 'PLC': 0.1, '编辑': 0.1, '框框': 0.1, '红色': 0.1, '字体': 0.1, '平台': 0.1})
# 62
# Counter({'轨迹': 3, '经理': 1, '曲线': 1})
# Counter({'轨迹': 0.6, '经理': 0.2, '曲线': 0.2})
# 63
# Counter({'按钮': 7, '标记': 4, '限位': 2, '面板': 1, 'BCP5045': 1, '空气': 1, '氧气': 1, '氮气': 1, '除尘': 1, '方管': 1, '校平': 1, '测试点': 1, '动时': 1, '失灵': 1, '负向': 1, '轴会': 1, '程序': 1, '零点': 1, '机械': 1, '原点': 1})
# Counter({'按钮': 0.23333333333333334, '标记': 0.13333333333333333, '限位': 0.06666666666666667, '面板': 0.03333333333333333, 'BCP5045': 0.03333333333333333, '空气': 0.03333333333333333, '氧气': 0.03333333333333333, '氮气': 0.03333333333333333, '除尘': 0.03333333333333333, '方管': 0.03333333333333333, '校平': 0.03333333333333333, '测试点': 0.03333333333333333, '动时': 0.03333333333333333, '失灵': 0.03333333333333333, '负向': 0.03333333333333333, '轴会': 0.03333333333333333, '程序': 0.03333333333333333, '零点': 0.03333333333333333, '机械': 0.03333333333333333, '原点': 0.03333333333333333})
# 64
# Counter({'区域': 8, '分区': 3, '除尘': 3, '延时': 3, '平台': 1, '工具': 1, '无锡': 1, '桥联': 1, '卖点': 1, '大量': 1, '选项': 1, '幅面': 1, '手动': 1, '地方': 1, '长度': 1})
# Counter({'区域': 0.2857142857142857, '分区': 0.10714285714285714, '除尘': 0.10714285714285714, '延时': 0.10714285714285714, '平台': 0.03571428571428571, '工具': 0.03571428571428571, '无锡': 0.03571428571428571, '桥联': 0.03571428571428571, '卖点': 0.03571428571428571, '大量': 0.03571428571428571, '选项': 0.03571428571428571, '幅面': 0.03571428571428571, '手动': 0.03571428571428571, '地方': 0.03571428571428571, '长度': 0.03571428571428571})
# 65
# Counter({'选项': 2, '图形': 1, '群组': 1})
# Counter({'选项': 0.5, '图形': 0.25, '群组': 0.25})
# 66
# Counter({'SPI': 2, '通讯': 1, '协议': 1, '说明书': 1, 'IPG': 1, 'YLS': 1, '选项': 1})
# Counter({'SPI': 0.25, '通讯': 0.125, '协议': 0.125, '说明书': 0.125, 'IPG': 0.125, 'YLS': 0.125, '选项': 0.125})
# 67
# Counter({'CCD': 4, '对位': 4, '广东地区': 1, '机台': 1, 'PCB': 1, '钢网': 1, '蓝宝石': 1, '陶瓷': 1})
# Counter({'CCD': 0.2857142857142857, '对位': 0.2857142857142857, '广东地区': 0.07142857142857142, '机台': 0.07142857142857142, 'PCB': 0.07142857142857142, '钢网': 0.07142857142857142, '蓝宝石': 0.07142857142857142, '陶瓷': 0.07142857142857142})
# 68
# Counter({'BCS100': 2, '网络': 2, '按钮': 1})
# Counter({'BCS100': 0.4, '网络': 0.4, '按钮': 0.2})
# 69
# Counter({'指令': 2, '安全性': 1, '上海': 1, '奉贤': 1, '周志祥': 1, '程序': 1, '零点': 1, '标记': 1, '产生': 1, '起点': 1, '按钮': 1})
# Counter({'指令': 0.16666666666666666, '安全性': 0.08333333333333333, '上海': 0.08333333333333333, '奉贤': 0.08333333333333333, '周志祥': 0.08333333333333333, '程序': 0.08333333333333333, '零点': 0.08333333333333333, '标记': 0.08333333333333333, '产生': 0.08333333333333333, '起点': 0.08333333333333333, '按钮': 0.08333333333333333})
# 70
# Counter({'气缸': 9, '进料': 7, '管材': 7, '动作': 6, 'PLC': 3, '长度': 2, '指令': 2, '手动': 1, '旋转轴': 1, '距离': 1, '全自动': 1, '步骤': 1, '限位': 1, '附件': 1, '大族': 1, '视频': 1, '条件': 1})
# Counter({'气缸': 0.1956521739130435, '进料': 0.15217391304347827, '管材': 0.15217391304347827, '动作': 0.13043478260869565, 'PLC': 0.06521739130434782, '长度': 0.043478260869565216, '指令': 0.043478260869565216, '手动': 0.021739130434782608, '旋转轴': 0.021739130434782608, '距离': 0.021739130434782608, '全自动': 0.021739130434782608, '步骤': 0.021739130434782608, '限位': 0.021739130434782608, '附件': 0.021739130434782608, '大族': 0.021739130434782608, '视频': 0.021739130434782608, '条件': 0.021739130434782608})
# 71
# Counter({'双驱': 1, '专业': 1, '米左右': 1, '特作': 1, '主动轴': 1, '动轴': 1, '伺服电机': 1})
# Counter({'双驱': 0.14285714285714285, '专业': 0.14285714285714285, '米左右': 0.14285714285714285, '特作': 0.14285714285714285, '主动轴': 0.14285714285714285, '动轴': 0.14285714285714285, '伺服电机': 0.14285714285714285})
# 72
# Counter({'单位': 3, 'min': 2, '全局': 1, '参数设置': 1, '习惯': 1})
# Counter({'单位': 0.375, 'min': 0.25, '全局': 0.125, '参数设置': 0.125, '习惯': 0.125})
# 73
# Counter()
# Counter()
# 74
# Counter({'触点': 2, '按钮': 2, '类型': 1, '选项': 1, '武汉': 1, '高能': 1})
# Counter({'触点': 0.25, '按钮': 0.25, '类型': 0.125, '选项': 0.125, '武汉': 0.125, '高能': 0.125})
# 75
# Counter({'BMC1204': 2, '脉冲': 2, '平率': 1, '频率': 1, 'KHz': 1, 'MHz': 1})
# Counter({'BMC1204': 0.25, '脉冲': 0.25, '平率': 0.125, '频率': 0.125, 'KHz': 0.125, 'MHz': 0.125})
# 76
# Counter({'单位': 2, '英寸': 2, '市场': 1, 'min': 1, '比例': 1})
# Counter({'单位': 0.2857142857142857, '英寸': 0.2857142857142857, '市场': 0.14285714285714285, 'min': 0.14285714285714285, '比例': 0.14285714285714285})
# 77
# Counter({'CYPCUT': 4, 'Coreldraw': 3, '贝塞尔': 3, '曲线': 3, '绘制': 2, '插件': 2, '整圆': 2, '广告行业': 1, 'coreldraw': 1, '绘图': 1, 'DXF': 1, '格式': 1, '圆是': 1, '市场': 1, '图形': 1})
# Counter({'CYPCUT': 0.14814814814814814, 'Coreldraw': 0.1111111111111111, '贝塞尔': 0.1111111111111111, '曲线': 0.1111111111111111, '绘制': 0.07407407407407407, '插件': 0.07407407407407407, '整圆': 0.07407407407407407, '广告行业': 0.037037037037037035, 'coreldraw': 0.037037037037037035, '绘图': 0.037037037037037035, 'DXF': 0.037037037037037035, '格式': 0.037037037037037035, '圆是': 0.037037037037037035, '市场': 0.037037037037037035, '图形': 0.037037037037037035})
# 78
# Counter({'条件': 1, 'PLC': 1})
# Counter({'条件': 0.5, 'PLC': 0.5})
# 79
# Counter({'排序': 4, '图层': 2, '选项': 2, '分层': 1})
# Counter({'排序': 0.4444444444444444, '图层': 0.2222222222222222, '选项': 0.2222222222222222, '分层': 0.1111111111111111})
# 80
# Counter({'原点': 2, '方管': 1, '地方': 1})
# Counter({'原点': 0.5, '方管': 0.25, '地方': 0.25})
# 81
# Counter({'BCS100': 2, '性能': 2, '硬件': 1})
# Counter({'BCS100': 0.4, '性能': 0.4, '硬件': 0.2})
# 82
# Counter({'穿孔': 4, '选项': 2, '高度': 2, '冲孔': 1})
# Counter({'穿孔': 0.4444444444444444, '选项': 0.2222222222222222, '高度': 0.2222222222222222, '冲孔': 0.1111111111111111})
# 83
# Counter({'限位': 8, 'MoveBy': 3, '指令': 2, '经理': 1, '单轴': 1, '边界': 1, '动会': 1, '产生': 1, '意义': 1, '地方': 1, '干涉仪': 1, '光路': 1, '脉冲': 1})
# Counter({'限位': 0.34782608695652173, 'MoveBy': 0.13043478260869565, '指令': 0.08695652173913043, '经理': 0.043478260869565216, '单轴': 0.043478260869565216, '边界': 0.043478260869565216, '动会': 0.043478260869565216, '产生': 0.043478260869565216, '意义': 0.043478260869565216, '地方': 0.043478260869565216, '干涉仪': 0.043478260869565216, '光路': 0.043478260869565216, '脉冲': 0.043478260869565216})
# 84
# Counter({'BCS100': 1, 'ping': 1, '本机': 1, '地址': 1, '高器': 1, '平台': 1, '工具': 1, '参数设置': 1, '网络': 1})
# Counter({'BCS100': 0.1111111111111111, 'ping': 0.1111111111111111, '本机': 0.1111111111111111, '地址': 0.1111111111111111, '高器': 0.1111111111111111, '平台': 0.1111111111111111, '工具': 0.1111111111111111, '参数设置': 0.1111111111111111, '网络': 0.1111111111111111})
# 85
# Counter({'气体': 3, '压力': 2, '密码': 2, '可选择性': 1, '宏石': 1, '平台': 1, '工具': 1})
# Counter({'气体': 0.2727272727272727, '压力': 0.18181818181818182, '密码': 0.18181818181818182, '可选择性': 0.09090909090909091, '宏石': 0.09090909090909091, '平台': 0.09090909090909091, '工具': 0.09090909090909091})
# 86
# Counter()
# Counter()
# 87
# Counter({'穿孔': 6, '群组': 4, '区域': 3, '板材': 2, '图层': 1, '场合': 1, '产生': 1, '图形': 1, '全部': 1})
# Counter({'穿孔': 0.3, '群组': 0.2, '区域': 0.15, '板材': 0.1, '图层': 0.05, '场合': 0.05, '产生': 0.05, '图形': 0.05, '全部': 0.05})
# 88
# Counter({'图形': 4, '错误': 2, '文件': 2, 'address': 2, '内存': 1, '步骤': 1, '测试软件': 1, 'lxd': 1, '全选': 1, '板材': 1, '间隙': 1, '角度': 1, 'NestPart1371': 1, 'Access': 1, 'violation': 1, 'D35E': 1, 'module': 1, 'cutext': 1, 'bpl': 1, 'Read': 1})
# Counter({'图形': 0.15384615384615385, '错误': 0.07692307692307693, '文件': 0.07692307692307693, 'address': 0.07692307692307693, '内存': 0.038461538461538464, '步骤': 0.038461538461538464, '测试软件': 0.038461538461538464, 'lxd': 0.038461538461538464, '全选': 0.038461538461538464, '板材': 0.038461538461538464, '间隙': 0.038461538461538464, '角度': 0.038461538461538464, 'NestPart1371': 0.038461538461538464, 'Access': 0.038461538461538464, 'violation': 0.038461538461538464, 'D35E': 0.038461538461538464, 'module': 0.038461538461538464, 'cutext': 0.038461538461538464, 'bpl': 0.038461538461538464, 'Read': 0.038461538461538464})
# 89
# Counter({'C盘': 3, '地方': 2, 'CypCut': 2, '还原卡': 1, '电脑': 1, '病毒感染': 1})
# Counter({'C盘': 0.3, '地方': 0.2, 'CypCut': 0.2, '还原卡': 0.1, '电脑': 0.1, '病毒感染': 0.1})
# 90
# Counter({'平竖直': 2, '直线': 1, '钣金': 1, '钣金件': 1, '效率': 1})
# Counter({'平竖直': 0.3333333333333333, '直线': 0.16666666666666666, '钣金': 0.16666666666666666, '钣金件': 0.16666666666666666, '效率': 0.16666666666666666})
# 91
# Counter({'次序': 4, '图形': 2, '排序': 2, '倒序': 1, '钢管': 1, '头部': 1, '尾部': 1, '方法': 1})
# Counter({'次序': 0.3076923076923077, '图形': 0.15384615384615385, '排序': 0.15384615384615385, '倒序': 0.07692307692307693, '钢管': 0.07692307692307693, '头部': 0.07692307692307693, '尾部': 0.07692307692307693, '方法': 0.07692307692307693})
# 92
# Counter({'制造商': 2, '平台': 2, '工具': 2, '选项': 2, '界面显示': 1})
# Counter({'制造商': 0.2222222222222222, '平台': 0.2222222222222222, '工具': 0.2222222222222222, '选项': 0.2222222222222222, '界面显示': 0.1111111111111111})
# 93
# Counter({'图形': 7, '大乘': 2, '刀线': 1, '选择性': 1, '长度': 1, '中心': 1, '穿孔': 1})
# Counter({'图形': 0.5, '大乘': 0.14285714285714285, '刀线': 0.07142857142857142, '选择性': 0.07142857142857142, '长度': 0.07142857142857142, '中心': 0.07142857142857142, '穿孔': 0.07142857142857142})
# 94
# Counter({'开始菜单': 3, 'OEM': 2, '名称': 2, '桌面': 1, '快捷方式': 1, '图标': 1, '文件夹': 1, '驱动程序': 1, '平台': 1, '工具': 1})
# Counter({'开始菜单': 0.21428571428571427, 'OEM': 0.14285714285714285, '名称': 0.14285714285714285, '桌面': 0.07142857142857142, '快捷方式': 0.07142857142857142, '图标': 0.07142857142857142, '文件夹': 0.07142857142857142, '驱动程序': 0.07142857142857142, '平台': 0.07142857142857142, '工具': 0.07142857142857142})
# 95
# Counter({'快捷方式': 2, '程序': 1, '开始菜单': 1, '桌面上': 1})
# Counter({'快捷方式': 0.4, '程序': 0.2, '开始菜单': 0.2, '桌面上': 0.2})
# 96
# Counter({'警告': 3, '按钮': 1, '驱动器': 1, '信号线': 1, '电阻': 1, '设计方案': 1})
# Counter({'警告': 0.375, '按钮': 0.125, '驱动器': 0.125, '信号线': 0.125, '电阻': 0.125, '设计方案': 0.125})
# 97
# Counter({'厚板': 3, '拐角': 2, '烧角': 2, '现象': 1, '正方形': 1, '拐角处': 1, '水平': 1, '穿孔': 1, '天泓': 1, '陈兆': 1, '大族': 1, '高功率': 1, '床子': 1, '尖角': 1, '很漂亮': 1})
# Counter({'厚板': 0.15789473684210525, '拐角': 0.10526315789473684, '烧角': 0.10526315789473684, '现象': 0.05263157894736842, '正方形': 0.05263157894736842, '拐角处': 0.05263157894736842, '水平': 0.05263157894736842, '穿孔': 0.05263157894736842, '天泓': 0.05263157894736842, '陈兆': 0.05263157894736842, '大族': 0.05263157894736842, '高功率': 0.05263157894736842, '床子': 0.05263157894736842, '尖角': 0.05263157894736842, '很漂亮': 0.05263157894736842})
# 98
# Counter({'全局': 5, '加密': 5, '图层': 4, '终端用户': 3, '天泓汪': 1, '厂里': 1, '工艺员': 1, '黄工': 1, '加速度': 1, '出厂': 1, '备份': 1, '平台': 1})
# Counter({'全局': 0.2, '加密': 0.2, '图层': 0.16, '终端用户': 0.12, '天泓汪': 0.04, '厂里': 0.04, '工艺员': 0.04, '黄工': 0.04, '加速度': 0.04, '出厂': 0.04, '备份': 0.04, '平台': 0.04})
# 99
# Counter({'光闸': 5, '时序': 5, '大功率': 2, 'IPG': 2, 'ProgramStart': 1, '动作': 1, '全部': 1})
# Counter({'光闸': 0.29411764705882354, '时序': 0.29411764705882354, '大功率': 0.11764705882352941, 'IPG': 0.11764705882352941, 'ProgramStart': 0.058823529411764705, '动作': 0.058823529411764705, '全部': 0.058823529411764705})
# 100
# Counter({'峰值': 5, '电流': 5, '穿孔': 3, 'PWM': 3, '功率': 3, '高功率': 1, '大程度': 1, '形式': 1})
# Counter({'峰值': 0.22727272727272727, '电流': 0.22727272727272727, '穿孔': 0.13636363636363635, 'PWM': 0.13636363636363635, '功率': 0.13636363636363635, '高功率': 0.045454545454545456, '大程度': 0.045454545454545456, '形式': 0.045454545454545456})
# 101
# Counter({'QCW': 7, '频率': 6, '模式': 2, '触摸屏': 2, '大族': 2, 'IPG': 1, '指令': 1, '制造商': 1, 'cypcut': 1, '指标': 1, 'PWM': 1, '乘积': 1, '设定值': 1, '符合要求': 1, '终端用户': 1, '按钮': 1})
# Counter({'QCW': 0.23333333333333334, '频率': 0.2, '模式': 0.06666666666666667, '触摸屏': 0.06666666666666667, '大族': 0.06666666666666667, 'IPG': 0.03333333333333333, '指令': 0.03333333333333333, '制造商': 0.03333333333333333, 'cypcut': 0.03333333333333333, '指标': 0.03333333333333333, 'PWM': 0.03333333333333333, '乘积': 0.03333333333333333, '设定值': 0.03333333333333333, '符合要求': 0.03333333333333333, '终端用户': 0.03333333333333333, '按钮': 0.03333333333333333})
# 102
# Counter({'按钮': 3, 'OUT': 1, '手动': 1})
# Counter({'按钮': 0.6, 'OUT': 0.2, '手动': 0.2})
# 103
# Counter({'CAD': 1, '图层': 1})
# Counter({'CAD': 0.5, '图层': 0.5})
# 104
# Counter({'加密狗': 6, '客服': 2, '嘉兴': 1, '瑞博': 1, '机械': 1, 'Cypcut': 1})
# Counter({'加密狗': 0.5, '客服': 0.16666666666666666, '嘉兴': 0.08333333333333333, '瑞博': 0.08333333333333333, '机械': 0.08333333333333333, 'Cypcut': 0.08333333333333333})
# 105
# Counter({'图形': 6, '排序': 3, '内膜': 2, '文件': 1, '重画': 1})
# Counter({'图形': 0.46153846153846156, '排序': 0.23076923076923078, '内膜': 0.15384615384615385, '文件': 0.07692307692307693, '重画': 0.07692307692307693})
# 106
# Counter({'方管': 2, '图形': 2, '间距': 2, '批量': 1, '绘图': 1, '绘制': 1, '阈值': 1, '范围': 1})
# Counter({'方管': 0.18181818181818182, '图形': 0.18181818181818182, '间距': 0.18181818181818182, '批量': 0.09090909090909091, '绘图': 0.09090909090909091, '绘制': 0.09090909090909091, '阈值': 0.09090909090909091, '范围': 0.09090909090909091})
# 107
# Counter({'中心': 4, '手动': 1, '固定设置': 1, '终端用户': 1, '按钮': 1, '标准': 1, '客服': 1})
# Counter({'中心': 0.4, '手动': 0.1, '固定设置': 0.1, '终端用户': 0.1, '按钮': 0.1, '标准': 0.1, '客服': 0.1})
# 108
# Counter({'动作': 2, 'PLC': 1, '单轴': 1, '制造商': 1, '图形': 1, '提高效率': 1, '节省': 1, '人力': 1, '卡盘': 1, '延时': 1, '浮头': 1, '原点': 1, '距离': 1, '图案': 1, '区别': 1, '进料': 1, '硬件': 1})
# Counter({'动作': 0.1111111111111111, 'PLC': 0.05555555555555555, '单轴': 0.05555555555555555, '制造商': 0.05555555555555555, '图形': 0.05555555555555555, '提高效率': 0.05555555555555555, '节省': 0.05555555555555555, '人力': 0.05555555555555555, '卡盘': 0.05555555555555555, '延时': 0.05555555555555555, '浮头': 0.05555555555555555, '原点': 0.05555555555555555, '距离': 0.05555555555555555, '图案': 0.05555555555555555, '区别': 0.05555555555555555, '进料': 0.05555555555555555, '硬件': 0.05555555555555555})
# 109
# Counter({'厚板': 2, '拐角': 1, '矩形': 1, '烧角': 1, '现象': 1, '原理': 1, '穿孔': 1})
# Counter({'厚板': 0.25, '拐角': 0.125, '矩形': 0.125, '烧角': 0.125, '现象': 0.125, '原理': 0.125, '穿孔': 0.125})
# 110
# Counter({'区域': 2, '管材': 2, '状态': 2, '动作': 2, 'PLC': 1, '条件': 1, '平面': 1, '方向': 1, '坐标值': 1, '方管': 1, '支架': 1, '设定值': 1, '手动': 1, '金运': 1})
# Counter({'区域': 0.1111111111111111, '管材': 0.1111111111111111, '状态': 0.1111111111111111, '动作': 0.1111111111111111, 'PLC': 0.05555555555555555, '条件': 0.05555555555555555, '平面': 0.05555555555555555, '方向': 0.05555555555555555, '坐标值': 0.05555555555555555, '方管': 0.05555555555555555, '支架': 0.05555555555555555, '设定值': 0.05555555555555555, '手动': 0.05555555555555555, '金运': 0.05555555555555555})
# 111
# Counter({'图层': 1, '高度': 1, '方管': 1, '平面': 1, '区分': 1})
# Counter({'图层': 0.2, '高度': 0.2, '方管': 0.2, '平面': 0.2, '区分': 0.2})
# 112
# Counter({'加密狗': 3, '联系': 2, '制造商': 1, '老板': 1, '交款': 1, '伤感情': 1, '人情味': 1, '加密': 1, '人性化': 1, '陈大健': 1})
# Counter({'加密狗': 0.23076923076923078, '联系': 0.15384615384615385, '制造商': 0.07692307692307693, '老板': 0.07692307692307693, '交款': 0.07692307692307693, '伤感情': 0.07692307692307693, '人情味': 0.07692307692307693, '加密': 0.07692307692307693, '人性化': 0.07692307692307693, '陈大健': 0.07692307692307693})
# 113
# Counter({'CypCut': 1})
# Counter({'CypCut': 1.0})
# 114
# Counter({'管材': 3, '伺服电机': 2, '丝杠': 2, '导轨': 2, 'CypTube': 1, '武汉': 1, '高能': 1, '硬件': 1, '受限制': 1, '轨迹': 1, '走时': 1, '板材': 1, '效率': 1, '高度': 1, '利用': 1, '信号': 1, '托架': 1, '太长': 1, '支撑点': 1})
# Counter({'管材': 0.125, '伺服电机': 0.08333333333333333, '丝杠': 0.08333333333333333, '导轨': 0.08333333333333333, 'CypTube': 0.041666666666666664, '武汉': 0.041666666666666664, '高能': 0.041666666666666664, '硬件': 0.041666666666666664, '受限制': 0.041666666666666664, '轨迹': 0.041666666666666664, '走时': 0.041666666666666664, '板材': 0.041666666666666664, '效率': 0.041666666666666664, '高度': 0.041666666666666664, '利用': 0.041666666666666664, '信号': 0.041666666666666664, '托架': 0.041666666666666664, '太长': 0.041666666666666664, '支撑点': 0.041666666666666664})
# 115
# Counter({'引线': 4, '圆孔': 3, '图形': 3, '直线': 2, '步骤': 1, '不合理': 1, '小圆孔': 1, '技术': 1})
# Counter({'引线': 0.25, '圆孔': 0.1875, '图形': 0.1875, '直线': 0.125, '步骤': 0.0625, '不合理': 0.0625, '小圆孔': 0.0625, '技术': 0.0625})
# 116
# Counter({'油路': 2, '平台': 1, '装机': 1, '冲油': 1, '间隔': 1, '油泵': 1, '次数': 1, '供油': 1})
# Counter({'油路': 0.2222222222222222, '平台': 0.1111111111111111, '装机': 0.1111111111111111, '冲油': 0.1111111111111111, '间隔': 0.1111111111111111, '油泵': 0.1111111111111111, '次数': 0.1111111111111111, '供油': 0.1111111111111111})
# 117
# Counter({'按钮': 4, '面板': 2, '灯光': 2, '步骤': 1, '平台': 1, '工具': 1})
# Counter({'按钮': 0.36363636363636365, '面板': 0.18181818181818182, '灯光': 0.18181818181818182, '步骤': 0.09090909090909091, '平台': 0.09090909090909091, '工具': 0.09090909090909091})
# 118
# Counter({'中心': 3, '尺寸': 2, '重置': 1, '自动记录': 1})
# Counter({'中心': 0.42857142857142855, '尺寸': 0.2857142857142857, '重置': 0.14285714285714285, '自动记录': 0.14285714285714285})
# 119
# Counter({'BCS100': 5, '加密': 5, '序列号': 2, '注册码': 2, '网络': 1, '收款': 1, 'CypCut': 1})
# Counter({'BCS100': 0.29411764705882354, '加密': 0.29411764705882354, '序列号': 0.11764705882352941, '注册码': 0.11764705882352941, '网络': 0.058823529411764705, '收款': 0.058823529411764705, 'CypCut': 0.058823529411764705})
# 120
# Counter({'控制卡': 5, '演示版': 4, '模式': 4, '平台': 3, 'CypCut': 1, '有所': 1, '差异': 1, '自动识别': 1, '类型': 1, '专用': 1, '方便使用': 1})
# Counter({'控制卡': 0.21739130434782608, '演示版': 0.17391304347826086, '模式': 0.17391304347826086, '平台': 0.13043478260869565, 'CypCut': 0.043478260869565216, '有所': 0.043478260869565216, '差异': 0.043478260869565216, '自动识别': 0.043478260869565216, '类型': 0.043478260869565216, '专用': 0.043478260869565216, '方便使用': 0.043478260869565216})
# 121
# Counter({'加密狗': 3, '演示版': 1, '程序': 1, '办事处': 1, '环境': 1, 'CypCut': 1, '序列号': 1})
# Counter({'加密狗': 0.3333333333333333, '演示版': 0.1111111111111111, '程序': 0.1111111111111111, '办事处': 0.1111111111111111, '环境': 0.1111111111111111, 'CypCut': 0.1111111111111111, '序列号': 0.1111111111111111})
# 122
# Counter({'路径': 4, '方向': 4, '顺时针': 3, '逆时针': 3, '图形': 2, '手动': 2, '光束': 1, '特性': 1, '吹气': 1, '气流': 1, '差异': 1})
# Counter({'路径': 0.17391304347826086, '方向': 0.17391304347826086, '顺时针': 0.13043478260869565, '逆时针': 0.13043478260869565, '图形': 0.08695652173913043, '手动': 0.08695652173913043, '光束': 0.043478260869565216, '特性': 0.043478260869565216, '吹气': 0.043478260869565216, '气流': 0.043478260869565216, '差异': 0.043478260869565216})
# 123
# Counter({'BCS100': 3, '文件': 3, 'Cypcut': 2, '固件': 2, 'V3059': 2, '以太网': 2, 'AFM': 2, '字节': 2, 'ASCII': 2, 'x30': 2, '远程': 1, '选项': 1, '文件名': 1, 'BCV3': 1, 'x41': 1, 'x46': 1, 'x4D': 1, 'x10': 1, 'x42': 1, 'x43': 1, 'x53': 1, 'x31': 1, '版本号': 1})
# Counter({'BCS100': 0.08571428571428572, '文件': 0.08571428571428572, 'Cypcut': 0.05714285714285714, '固件': 0.05714285714285714, 'V3059': 0.05714285714285714, '以太网': 0.05714285714285714, 'AFM': 0.05714285714285714, '字节': 0.05714285714285714, 'ASCII': 0.05714285714285714, 'x30': 0.05714285714285714, '远程': 0.02857142857142857, '选项': 0.02857142857142857, '文件名': 0.02857142857142857, 'BCV3': 0.02857142857142857, 'x41': 0.02857142857142857, 'x46': 0.02857142857142857, 'x4D': 0.02857142857142857, 'x10': 0.02857142857142857, 'x42': 0.02857142857142857, 'x43': 0.02857142857142857, 'x53': 0.02857142857142857, 'x31': 0.02857142857142857, '版本号': 0.02857142857142857})
# 124
# Counter({'高度': 2, '图形': 2, '市面上': 1, '概率': 1, '头会': 1, '板子': 1, '事情': 1, '声音': 1, '整体': 1, '感观': 1, '起点': 1, '风险': 1, '平面': 1, '视觉效果': 1})
# Counter({'高度': 0.125, '图形': 0.125, '市面上': 0.0625, '概率': 0.0625, '头会': 0.0625, '板子': 0.0625, '事情': 0.0625, '声音': 0.0625, '整体': 0.0625, '感观': 0.0625, '起点': 0.0625, '风险': 0.0625, '平面': 0.0625, '视觉效果': 0.0625})
# 125
# Counter({'Nlight': 3, '通讯': 2, '协议': 2, 'CypCut': 1, '平台': 1, '工具': 1})
# Counter({'Nlight': 0.3, '通讯': 0.2, '协议': 0.2, 'CypCut': 0.1, '平台': 0.1, '工具': 0.1})
# 126
# Counter({'图标': 5, '文件': 3, '备份': 2, '误差': 2, '齿条': 1, 'cfgpkg': 1, '十字': 1, '圆度': 1})
# Counter({'图标': 0.3125, '文件': 0.1875, '备份': 0.125, '误差': 0.125, '齿条': 0.0625, 'cfgpkg': 0.0625, '十字': 0.0625, '圆度': 0.0625})
# 127
# Counter({'雷达': 2, '六边形': 1, '矩形': 1, '图形': 1, '领创': 1})
# Counter({'雷达': 0.3333333333333333, '六边形': 0.16666666666666666, '矩形': 0.16666666666666666, '图形': 0.16666666666666666, '领创': 0.16666666666666666})
# 128
# Counter({'CypCut': 2, '文字': 2, '空心': 2, '精雕': 2, '字体': 1, '中文字体': 1})
# Counter({'CypCut': 0.2, '文字': 0.2, '空心': 0.2, '精雕': 0.2, '字体': 0.1, '中文字体': 0.1})
# 129
# Counter({'按钮': 3, 'PLC': 2, '重命名': 2, '编辑': 1})
# Counter({'按钮': 0.375, 'PLC': 0.25, '重命名': 0.25, '编辑': 0.125})
# 130
# Counter({'直线': 1, '圆弧': 1, '排序': 1})
# Counter({'直线': 0.3333333333333333, '圆弧': 0.3333333333333333, '排序': 0.3333333333333333})
# 131
# Counter({'电动': 3, '迪能': 1, '轴点': 1, '端子板': 1})
# Counter({'电动': 0.5, '迪能': 0.16666666666666666, '轴点': 0.16666666666666666, '端子板': 0.16666666666666666})
# 132
# Counter({'方管': 3, '中心': 2, '平面': 1, '电容': 1, '方法': 1})
# Counter({'方管': 0.375, '中心': 0.25, '平面': 0.125, '电容': 0.125, '方法': 0.125})
# 133
# Counter({'补料': 3, '图形': 3, '板材': 2, '坐标系': 2, '方法': 1, '凌丰路': 1, '工件': 1, '标记': 1, '定位': 1, '地方': 1})
# Counter({'补料': 0.1875, '图形': 0.1875, '板材': 0.125, '坐标系': 0.125, '方法': 0.0625, '凌丰路': 0.0625, '工件': 0.0625, '标记': 0.0625, '定位': 0.0625, '地方': 0.0625})
# 134
# Counter({'终端用户': 1, '午休': 1, '按钮': 1, '桥联': 1, '胡工': 1, '安全性': 1})
# Counter({'终端用户': 0.16666666666666666, '午休': 0.16666666666666666, '按钮': 0.16666666666666666, '桥联': 0.16666666666666666, '胡工': 0.16666666666666666, '安全性': 0.16666666666666666})
# 135
# Counter({'余料': 8, '板材': 5, '边缘': 3, '图形': 2, '直线': 2, '题目': 1})
# Counter({'余料': 0.38095238095238093, '板材': 0.23809523809523808, '边缘': 0.14285714285714285, '图形': 0.09523809523809523, '直线': 0.09523809523809523, '题目': 0.047619047619047616})
# 136
# Counter({'图层': 6, '余料': 2, '文件': 1})
# Counter({'图层': 0.6666666666666666, '余料': 0.2222222222222222, '文件': 0.1111111111111111})
# 137
# Counter({'本体': 2, '电容': 2, '列表': 1, 'help': 1, '解决方案': 1, '提示信息': 1})
# Counter({'本体': 0.25, '电容': 0.25, '列表': 0.125, 'help': 0.125, '解决方案': 0.125, '提示信息': 0.125})
# 138
# Counter({'微调': 6, '距离': 5, '生效': 1, '图形': 1, '时会': 1})
# Counter({'微调': 0.42857142857142855, '距离': 0.35714285714285715, '生效': 0.07142857142857142, '图形': 0.07142857142857142, '时会': 0.07142857142857142})
# 139
# Counter({'批量': 1, '图纸': 1})
# Counter({'批量': 0.5, '图纸': 0.5})
# 140
# Counter({'长度': 2, '板材': 2, '货款': 2, '老板': 1, '成品率': 1, '制造商': 1, '我会': 1, '单子': 1, '理由': 1})
# Counter({'长度': 0.16666666666666666, '板材': 0.16666666666666666, '货款': 0.16666666666666666, '老板': 0.08333333333333333, '成品率': 0.08333333333333333, '制造商': 0.08333333333333333, '我会': 0.08333333333333333, '单子': 0.08333333333333333, '理由': 0.08333333333333333})
# 141
# Counter({'顺序': 3, '图形': 3, '横线': 1, '竖线': 1, '外框': 1, '钢板': 1, '变形': 1})
# Counter({'顺序': 0.2727272727272727, '图形': 0.2727272727272727, '横线': 0.09090909090909091, '竖线': 0.09090909090909091, '外框': 0.09090909090909091, '钢板': 0.09090909090909091, '变形': 0.09090909090909091})
# 142
# Counter({'加密': 2, '经理': 1, '商务': 1, '技术支持': 1})
# Counter({'加密': 0.4, '经理': 0.2, '商务': 0.2, '技术支持': 0.2})
# 143
# Counter({'通讯': 3, '网络通讯': 2, '网络': 1, '市面上': 1, '接线': 1, '装机': 1, 'IP地址': 1, 'COM': 1})
# Counter({'通讯': 0.2727272727272727, '网络通讯': 0.18181818181818182, '网络': 0.09090909090909091, '市面上': 0.09090909090909091, '接线': 0.09090909090909091, '装机': 0.09090909090909091, 'IP地址': 0.09090909090909091, 'COM': 0.09090909090909091})
# 144
# Counter({'电容': 4, '本体': 2, 'Cypcut': 1, '高器': 1})
# Counter({'电容': 0.5, '本体': 0.25, 'Cypcut': 0.125, '高器': 0.125})
# 145
# Counter({'方管': 3, '尺寸': 3, '方法': 2, '图纸': 2, '烧面': 1, '现象': 1})
# Counter({'方管': 0.25, '尺寸': 0.25, '方法': 0.16666666666666666, '图纸': 0.16666666666666666, '烧面': 0.08333333333333333, '现象': 0.08333333333333333})
# 146
# Counter({'板面': 5})
# Counter({'板面': 1.0})
# 147
# Counter({'浮头': 3, '高器': 2, '编码器': 2, '界面显示': 1})
# Counter({'浮头': 0.375, '高器': 0.25, '编码器': 0.25, '界面显示': 0.125})
# 148
# Counter({'坡口': 3, '曲线': 2, '名词解释': 1, '唐总': 1, '名称': 1, '平面曲线': 1, '直观': 1, '总和': 1, '明白': 1, '旋转轴': 1, '相贯孔': 1})
# Counter({'坡口': 0.21428571428571427, '曲线': 0.14285714285714285, '名词解释': 0.07142857142857142, '唐总': 0.07142857142857142, '名称': 0.07142857142857142, '平面曲线': 0.07142857142857142, '直观': 0.07142857142857142, '总和': 0.07142857142857142, '明白': 0.07142857142857142, '旋转轴': 0.07142857142857142, '相贯孔': 0.07142857142857142})
# 149
# Counter({'直线': 2, '绘图': 1, '钣金': 1, '工序': 1, '钣金件': 1, '直角': 1, '小孔': 1, '空间': 1, '交汇点': 1, '圆心': 1, '半径': 1, '圆弧': 1})
# Counter({'直线': 0.15384615384615385, '绘图': 0.07692307692307693, '钣金': 0.07692307692307693, '工序': 0.07692307692307693, '钣金件': 0.07692307692307693, '直角': 0.07692307692307693, '小孔': 0.07692307692307693, '空间': 0.07692307692307693, '交汇点': 0.07692307692307693, '圆心': 0.07692307692307693, '半径': 0.07692307692307693, '圆弧': 0.07692307692307693})
# 150
# Counter({'限位': 2, '信号': 2, '逻辑': 2})
# Counter({'限位': 0.3333333333333333, '信号': 0.3333333333333333, '逻辑': 0.3333333333333333})
# 151
# Counter({'尖角': 5, '环切': 4, '曲线': 3, 'CypCut': 2, '圆弧': 1, '程度': 1, '角度': 1, '手动': 1, '鼠标': 1})
# Counter({'尖角': 0.2631578947368421, '环切': 0.21052631578947367, '曲线': 0.15789473684210525, 'CypCut': 0.10526315789473684, '圆弧': 0.05263157894736842, '程度': 0.05263157894736842, '角度': 0.05263157894736842, '手动': 0.05263157894736842, '鼠标': 0.05263157894736842})
# 152
# Counter({'上料': 3, '卡盘': 3, '时动': 2, '角度': 2, '机械设计': 1, '普适性': 1})
# Counter({'上料': 0.25, '卡盘': 0.25, '时动': 0.16666666666666666, '角度': 0.16666666666666666, '机械设计': 0.08333333333333333, '普适性': 0.08333333333333333})
# 153
# Counter({'策略': 2, '死机': 1, '体验': 1})
# Counter({'策略': 0.5, '死机': 0.25, '体验': 0.25})
# 154
# Counter({'方向': 7, '方向向': 1})
# Counter({'方向': 0.875, '方向向': 0.125})
# 155
# Counter({'余料': 11, '板材': 3, '水平线': 2, '地方': 1, '单张': 1, '形状': 1, '矩形': 1, '研发部': 1})
# Counter({'余料': 0.5238095238095238, '板材': 0.14285714285714285, '水平线': 0.09523809523809523, '地方': 0.047619047619047616, '单张': 0.047619047619047616, '形状': 0.047619047619047616, '矩形': 0.047619047619047616, '研发部': 0.047619047619047616})
# 156
# Counter({'板材': 6, '数量': 2, '个数': 1, '块板': 1})
# Counter({'板材': 0.6, '数量': 0.2, '个数': 0.1, '块板': 0.1})
# 157
# Counter({'规则': 3, '评价': 1, '直观': 1, '指标': 1, '空间': 1})
# Counter({'规则': 0.42857142857142855, '评价': 0.14285714285714285, '直观': 0.14285714285714285, '指标': 0.14285714285714285, '空间': 0.14285714285714285})
# 158
# Counter({'CypCut': 2, '方向': 2, '稳定性': 2, '易用性': 2, '框架': 1, '状态': 1, '原件': 1, '图形': 1, '利用率': 1})
# Counter({'CypCut': 0.15384615384615385, '方向': 0.15384615384615385, '稳定性': 0.15384615384615385, '易用性': 0.15384615384615385, '框架': 0.07692307692307693, '状态': 0.07692307692307693, '原件': 0.07692307692307693, '图形': 0.07692307692307693, '利用率': 0.07692307692307693})
# 159
# Counter({'刀线': 7, '平面': 4, '方管': 2, '起点': 2, '方向': 2, '引刀': 1})
# Counter({'刀线': 0.3888888888888889, '平面': 0.2222222222222222, '方管': 0.1111111111111111, '起点': 0.1111111111111111, '方向': 0.1111111111111111, '引刀': 0.05555555555555555})
# 160
# Counter({'图片': 6, 'Mark': 4, '模板': 3, '图像': 2, '利用': 1, '误会': 1, '关联': 1})
# Counter({'图片': 0.3333333333333333, 'Mark': 0.2222222222222222, '模板': 0.16666666666666666, '图像': 0.1111111111111111, '利用': 0.05555555555555555, '误会': 0.05555555555555555, '关联': 0.05555555555555555})
# 161
# Counter({'镀金': 2, '圆管': 1, '方管': 1, '顶料': 1, '设计方案': 1, '表面': 1, '过程中将': 1})
# Counter({'镀金': 0.25, '圆管': 0.125, '方管': 0.125, '顶料': 0.125, '设计方案': 0.125, '表面': 0.125, '过程中将': 0.125})
# 162
# Counter({'图形': 3, '板子': 2, '文件': 1, '终端用户': 1, 'cypcut': 1, '错位': 1, '引线': 1, '排序': 1, '庆源': 1, '嘉泰': 1, '操作员': 1, '小心': 1, '鼠标': 1})
# Counter({'图形': 0.1875, '板子': 0.125, '文件': 0.0625, '终端用户': 0.0625, 'cypcut': 0.0625, '错位': 0.0625, '引线': 0.0625, '排序': 0.0625, '庆源': 0.0625, '嘉泰': 0.0625, '操作员': 0.0625, '小心': 0.0625, '鼠标': 0.0625})
# 163
# Counter({'ESC': 1, '按钮': 1, '图形': 1, '编辑': 1, '排序': 1, 'AFK': 1, 'away': 1, 'from': 1, 'keyboard': 1, '鼠标': 1})
# Counter({'ESC': 0.1, '按钮': 0.1, '图形': 0.1, '编辑': 0.1, '排序': 0.1, 'AFK': 0.1, 'away': 0.1, 'from': 0.1, 'keyboard': 0.1, '鼠标': 0.1})
# 164
# Counter({'mark': 3, 'Mark': 2, '镜头': 2, '视野': 2, '范围': 2, '板材': 2, '定位': 2, '眼镜': 1, '行业': 1, '工位': 1, '手动': 1, '视窗': 1, '中心': 1, '畸变': 1})
# Counter({'mark': 0.13636363636363635, 'Mark': 0.09090909090909091, '镜头': 0.09090909090909091, '视野': 0.09090909090909091, '范围': 0.09090909090909091, '板材': 0.09090909090909091, '定位': 0.09090909090909091, '眼镜': 0.045454545454545456, '行业': 0.045454545454545456, '工位': 0.045454545454545456, '手动': 0.045454545454545456, '视窗': 0.045454545454545456, '中心': 0.045454545454545456, '畸变': 0.045454545454545456})
# 165
# Counter({'定位': 3, 'Mark': 1, '苹果': 1, 'logo': 1, '背盖': 1, 'mark': 1, '摄像头': 1, '闪光灯': 1, '圆孔': 1, '定位精度': 1})
# Counter({'定位': 0.25, 'Mark': 0.08333333333333333, '苹果': 0.08333333333333333, 'logo': 0.08333333333333333, '背盖': 0.08333333333333333, 'mark': 0.08333333333333333, '摄像头': 0.08333333333333333, '闪光灯': 0.08333333333333333, '圆孔': 0.08333333333333333, '定位精度': 0.08333333333333333})
# 166
# Counter({'引线': 4, '手动': 3, '刀线': 2, '方向': 2, '图形': 2, '矩形框': 1, '绿色': 1, '白色': 1, '拐角': 1, '同向': 1})
# Counter({'引线': 0.2222222222222222, '手动': 0.16666666666666666, '刀线': 0.1111111111111111, '方向': 0.1111111111111111, '图形': 0.1111111111111111, '矩形框': 0.05555555555555555, '绿色': 0.05555555555555555, '白色': 0.05555555555555555, '拐角': 0.05555555555555555, '同向': 0.05555555555555555})
# 167
# Counter({'动作': 4, '图层': 3, '工位': 3, '彭文斌': 1, '区分': 1})
# Counter({'动作': 0.3333333333333333, '图层': 0.25, '工位': 0.25, '彭文斌': 0.08333333333333333, '区分': 0.08333333333333333})
# 168
# Counter({'信号': 7, '原点': 3, 'ready': 2, '按钮': 2, 'PLC': 2, 'start': 2, '韩国': 1})
# Counter({'信号': 0.3684210526315789, '原点': 0.15789473684210525, 'ready': 0.10526315789473684, '按钮': 0.10526315789473684, 'PLC': 0.10526315789473684, 'start': 0.10526315789473684, '韩国': 0.05263157894736842})
# 169
# Counter({'平台': 2, '工具': 2, 'PWM': 2, '信号': 2, '专用': 1})
# Counter({'平台': 0.2222222222222222, '工具': 0.2222222222222222, 'PWM': 0.2222222222222222, '信号': 0.2222222222222222, '专用': 0.1111111111111111})
# 170
# Counter({'穿孔': 4, '群组': 4, '图形': 3, '赵建': 2, '厚板': 1, '整板': 1, '区域': 1, '功率': 1, '贴膜': 1, '建都': 1, '顺序': 1, '全局': 1, '选项': 1, '习惯': 1})
# Counter({'穿孔': 0.17391304347826086, '群组': 0.17391304347826086, '图形': 0.13043478260869565, '赵建': 0.08695652173913043, '厚板': 0.043478260869565216, '整板': 0.043478260869565216, '区域': 0.043478260869565216, '功率': 0.043478260869565216, '贴膜': 0.043478260869565216, '建都': 0.043478260869565216, '顺序': 0.043478260869565216, '全局': 0.043478260869565216, '选项': 0.043478260869565216, '习惯': 0.043478260869565216})
# 171
# Counter({'网络': 4, '高器': 3, '网络连接': 2, '歧义': 1, '所弹': 1, '网络通讯': 1, '配件': 1, '错误判断': 1})
# Counter({'网络': 0.2857142857142857, '高器': 0.21428571428571427, '网络连接': 0.14285714285714285, '歧义': 0.07142857142857142, '所弹': 0.07142857142857142, '网络通讯': 0.07142857142857142, '配件': 0.07142857142857142, '错误判断': 0.07142857142857142})
# 172
# Counter({'面积': 3, '产生': 1, '现象': 1, '材料': 1, '高效率': 1, 'cutup': 1, '指令': 1, '地方': 1, '图形': 1, '尺寸': 1, '凭感觉': 1, '实用性': 1})
# Counter({'面积': 0.21428571428571427, '产生': 0.07142857142857142, '现象': 0.07142857142857142, '材料': 0.07142857142857142, '高效率': 0.07142857142857142, 'cutup': 0.07142857142857142, '指令': 0.07142857142857142, '地方': 0.07142857142857142, '图形': 0.07142857142857142, '尺寸': 0.07142857142857142, '凭感觉': 0.07142857142857142, '实用性': 0.07142857142857142})
# 173
# Counter({'图形': 4, 'MARK': 2, '一键': 1, '制图员': 1, '按钮': 1, 'mark': 1, '节省': 1, 'Mark': 1})
# Counter({'图形': 0.3333333333333333, 'MARK': 0.16666666666666666, '一键': 0.08333333333333333, '制图员': 0.08333333333333333, '按钮': 0.08333333333333333, 'mark': 0.08333333333333333, '节省': 0.08333333333333333, 'Mark': 0.08333333333333333})
# 174
# Counter({'制图员': 1, '图形': 1, '手点': 1, '拐角处': 1, '角度': 1, '一键': 1})
# Counter({'制图员': 0.16666666666666666, '图形': 0.16666666666666666, '手点': 0.16666666666666666, '拐角处': 0.16666666666666666, '角度': 0.16666666666666666, '一键': 0.16666666666666666})
# 175
# Counter({'眼镜': 5, '细边': 2, '图形': 1, '区分': 1, '角度': 1, '附件': 1, '大端': 1, '方向': 1, '顺序': 1})
# Counter({'眼镜': 0.35714285714285715, '细边': 0.14285714285714285, '图形': 0.07142857142857142, '区分': 0.07142857142857142, '角度': 0.07142857142857142, '附件': 0.07142857142857142, '大端': 0.07142857142857142, '方向': 0.07142857142857142, '顺序': 0.07142857142857142})
# 176
# Counter({'编码器': 6, '细化': 1, '市场': 1, '指向性': 1, '区分': 1, '缺相': 1})
# Counter({'编码器': 0.5454545454545454, '细化': 0.09090909090909091, '市场': 0.09090909090909091, '指向性': 0.09090909090909091, '区分': 0.09090909090909091, '缺相': 0.09090909090909091})
# 177
# Counter({'刀线': 8, '图形': 8, '方向': 5, '区分': 3, 'CAD': 2, '排序': 2, '按钮': 2, '终端用户': 1, '节省时间': 1, '起点': 1, '能力': 1, '智能': 1, '渠道': 1, '阳切': 1, '手动': 1, '地方': 1, '手点': 1, 'shift': 1})
# Counter({'刀线': 0.1951219512195122, '图形': 0.1951219512195122, '方向': 0.12195121951219512, '区分': 0.07317073170731707, 'CAD': 0.04878048780487805, '排序': 0.04878048780487805, '按钮': 0.04878048780487805, '终端用户': 0.024390243902439025, '节省时间': 0.024390243902439025, '起点': 0.024390243902439025, '能力': 0.024390243902439025, '智能': 0.024390243902439025, '渠道': 0.024390243902439025, '阳切': 0.024390243902439025, '手动': 0.024390243902439025, '地方': 0.024390243902439025, '手点': 0.024390243902439025, 'shift': 0.024390243902439025})
# 178
# Counter({'PWM': 7, '信号': 6, '脉冲': 5, 'QCW': 3, '模式': 3, '继电器': 3, '频率': 3, '短时间': 2, '常量': 1, '附带': 1, '高灵敏度': 1, '状态': 1, '漏光': 1, '传统': 1, '内置': 1})
# Counter({'PWM': 0.1794871794871795, '信号': 0.15384615384615385, '脉冲': 0.1282051282051282, 'QCW': 0.07692307692307693, '模式': 0.07692307692307693, '继电器': 0.07692307692307693, '频率': 0.07692307692307693, '短时间': 0.05128205128205128, '常量': 0.02564102564102564, '附带': 0.02564102564102564, '高灵敏度': 0.02564102564102564, '状态': 0.02564102564102564, '漏光': 0.02564102564102564, '传统': 0.02564102564102564, '内置': 0.02564102564102564})
# 179
# Counter({'PLC': 3, '频率': 2, '穿孔': 2, '选项': 1, '先生': 1, '材料': 1, '功率': 1, 'PWM': 1, '峰值': 1, '电流': 1})
# Counter({'PLC': 0.21428571428571427, '频率': 0.14285714285714285, '穿孔': 0.14285714285714285, '选项': 0.07142857142857142, '先生': 0.07142857142857142, '材料': 0.07142857142857142, '功率': 0.07142857142857142, 'PWM': 0.07142857142857142, '峰值': 0.07142857142857142, '电流': 0.07142857142857142})
# 180
# Counter({'文件夹': 4, 'Help': 3, '文件': 2, '按钮': 2, '区域': 2, '技术': 1, '总工': 1, '联系': 1, '须知': 1, '冷水机': 1, '故障诊断': 1, '说明书': 1, '视频': 1, '目录': 1, '清空': 1, '东西': 1, '文件目录': 1, 'cypcut': 1})
# Counter({'文件夹': 0.15384615384615385, 'Help': 0.11538461538461539, '文件': 0.07692307692307693, '按钮': 0.07692307692307693, '区域': 0.07692307692307693, '技术': 0.038461538461538464, '总工': 0.038461538461538464, '联系': 0.038461538461538464, '须知': 0.038461538461538464, '冷水机': 0.038461538461538464, '故障诊断': 0.038461538461538464, '说明书': 0.038461538461538464, '视频': 0.038461538461538464, '目录': 0.038461538461538464, '清空': 0.038461538461538464, '东西': 0.038461538461538464, '文件目录': 0.038461538461538464, 'cypcut': 0.038461538461538464})
# 181
# Counter({'sysinfo': 2, '对话框': 1, '命令': 1})
# Counter({'sysinfo': 0.5, '对话框': 0.25, '命令': 0.25})
# 182
# Counter({'穿孔': 3, '厚板': 1, '节约': 1})
# Counter({'穿孔': 0.6, '厚板': 0.2, '节约': 0.2})
# 183
# Counter({'cypcut': 2, '方管': 1, '手工': 1, '粉丝': 1, '曲线': 1, '图形': 1, 'cyptube': 1})
# ...
# 4599
# Counter({'内膜': 2, '正确处理': 1, '阴阳': 1, '终端用户': 1, '我会': 1, '方便管理': 1, '零件库': 1, '批量': 1, '图纸': 1, '附件': 1})
# Counter({'内膜': 0.18181818181818182, '正确处理': 0.09090909090909091, '阴阳': 0.09090909090909091, '终端用户': 0.09090909090909091, '我会': 0.09090909090909091, '方便管理': 0.09090909090909091, '零件库': 0.09090909090909091, '批量': 0.09090909090909091, '图纸': 0.09090909090909091, '附件': 0.09090909090909091})
# 4600
# Counter({'方法': 3, '云端': 2, 'HypCut': 2, '效率': 2, '工具': 1, '科学': 1, '焦点': 1, '光斑': 1})
# Counter({'方法': 0.23076923076923078, '云端': 0.15384615384615385, 'HypCut': 0.15384615384615385, '效率': 0.15384615384615385, '工具': 0.07692307692307693, '科学': 0.07692307692307693, '焦点': 0.07692307692307693, '光斑': 0.07692307692307693})
# 4601
# Counter({'英文': 6, '页面': 2, '语言': 2, 'SaaS': 1, '商城': 1, '老外': 1, '下单': 1, '商品': 1, '中文': 1, '前台': 1, '浏览器': 1, 'WeChat': 1})
# Counter({'英文': 0.3157894736842105, '页面': 0.10526315789473684, '语言': 0.10526315789473684, 'SaaS': 0.05263157894736842, '商城': 0.05263157894736842, '老外': 0.05263157894736842, '下单': 0.05263157894736842, '商品': 0.05263157894736842, '中文': 0.05263157894736842, '前台': 0.05263157894736842, '浏览器': 0.05263157894736842, 'WeChat': 0.05263157894736842})
# 4602
# Counter({'备份': 5, 'CypCut': 3, '云端': 2, '联网': 1, '邮槽': 1, 'mailslot': 1, 'Friendess': 1, '文件名': 1, '逻辑': 1, 'fsdc': 1})
# Counter({'备份': 0.29411764705882354, 'CypCut': 0.17647058823529413, '云端': 0.11764705882352941, '联网': 0.058823529411764705, '邮槽': 0.058823529411764705, 'mailslot': 0.058823529411764705, 'Friendess': 0.058823529411764705, '文件名': 0.058823529411764705, '逻辑': 0.058823529411764705, 'fsdc': 0.058823529411764705})
# 4603
# Counter({'盛泰奇': 1, '动作': 1, '下料': 1})
# Counter({'盛泰奇': 0.3333333333333333, '动作': 0.3333333333333333, '下料': 0.3333333333333333})
# 4604
# Counter({'场景': 3, '普特': 2, '高度': 2, '种点': 2, '间距': 2, '功率': 2, '工具': 2, '背景': 1, '图层': 1, '数量': 1, '方法': 1})
# Counter({'场景': 0.15789473684210525, '普特': 0.10526315789473684, '高度': 0.10526315789473684, '种点': 0.10526315789473684, '间距': 0.10526315789473684, '功率': 0.10526315789473684, '工具': 0.10526315789473684, '背景': 0.05263157894736842, '图层': 0.05263157894736842, '数量': 0.05263157894736842, '方法': 0.05263157894736842})
# 4605
# Counter({'卡盘': 7, '中卡': 3, '张开': 2, '状态': 1, '动作': 1, '有点': 1, '单卡': 1, '平面': 1, '工具': 1, '选项': 1, '长度': 1})
# Counter({'卡盘': 0.35, '中卡': 0.15, '张开': 0.1, '状态': 0.05, '动作': 0.05, '有点': 0.05, '单卡': 0.05, '平面': 0.05, '工具': 0.05, '选项': 0.05, '长度': 0.05})
# 4606
# Counter({'文字': 3, '图纸': 2, '附件': 2, '文件': 2, '曲线': 1, '标字': 1, '步骤': 1, '编辑': 1, '按钮': 1})
# Counter({'文字': 0.21428571428571427, '图纸': 0.14285714285714285, '附件': 0.14285714285714285, '文件': 0.14285714285714285, '曲线': 0.07142857142857142, '标字': 0.07142857142857142, '步骤': 0.07142857142857142, '编辑': 0.07142857142857142, '按钮': 0.07142857142857142})
# 4607
# Counter({'图纸': 2, '小圆': 1, '合法': 1, '步骤': 1, '轮廓': 1, '选项': 1, '原理': 1, '小时': 1, '整圆': 1, '标准': 1})
# Counter({'图纸': 0.18181818181818182, '小圆': 0.09090909090909091, '合法': 0.09090909090909091, '步骤': 0.09090909090909091, '轮廓': 0.09090909090909091, '选项': 0.09090909090909091, '原理': 0.09090909090909091, '小时': 0.09090909090909091, '整圆': 0.09090909090909091, '标准': 0.09090909090909091})
# 4608
# Counter({'刀序': 4, '槽钢': 2, '有点': 1, '会卡': 1, '卡盘': 1, '方向': 1})
# Counter({'刀序': 0.4, '槽钢': 0.2, '有点': 0.1, '会卡': 0.1, '卡盘': 0.1, '方向': 0.1})
# 4609
# Counter({'收刀': 6, '领创': 3, '成功率': 2, '频率': 2, '长度': 2, '厚板': 1, '团队': 1, '中厚板': 1, '缺口': 1, '附件': 1, '侯国': 1, '样品': 1, '瘤子': 1, '段时间': 1, '光辉': 1, '焦点': 1, '高度': 1, '气压': 1, '工具': 1})
# Counter({'收刀': 0.20689655172413793, '领创': 0.10344827586206896, '成功率': 0.06896551724137931, '频率': 0.06896551724137931, '长度': 0.06896551724137931, '厚板': 0.034482758620689655, '团队': 0.034482758620689655, '中厚板': 0.034482758620689655, '缺口': 0.034482758620689655, '附件': 0.034482758620689655, '侯国': 0.034482758620689655, '样品': 0.034482758620689655, '瘤子': 0.034482758620689655, '段时间': 0.034482758620689655, '光辉': 0.034482758620689655, '焦点': 0.034482758620689655, '高度': 0.034482758620689655, '气压': 0.034482758620689655, '工具': 0.034482758620689655})
# 4610
# Counter({'图层': 3, '卷料': 3, '幅面': 3, 'PLC': 1, '指令': 1, '动作': 1, '力锋': 1, '静态': 1, '原图': 1, '距离': 1})
# Counter({'图层': 0.1875, '卷料': 0.1875, '幅面': 0.1875, 'PLC': 0.0625, '指令': 0.0625, '动作': 0.0625, '力锋': 0.0625, '静态': 0.0625, '原图': 0.0625, '距离': 0.0625})
# 4611
# Counter({'支架': 4, '直观': 2, '下降时': 1})
# Counter({'支架': 0.5714285714285714, '直观': 0.2857142857142857, '下降时': 0.14285714285714285})
# 4612
# Counter({'sat': 4, '格式': 4, '单位': 2, '生效': 2, '主线': 1, '步骤': 1, '页面': 1, '选项': 1, '附件': 1, 'IGS': 1, '长度': 1})
# Counter({'sat': 0.21052631578947367, '格式': 0.21052631578947367, '单位': 0.10526315789473684, '生效': 0.10526315789473684, '主线': 0.05263157894736842, '步骤': 0.05263157894736842, '页面': 0.05263157894736842, '选项': 0.05263157894736842, '附件': 0.05263157894736842, 'IGS': 0.05263157894736842, '长度': 0.05263157894736842})
# 4613
# Counter({'CypNest': 5, '文件': 5, '云端': 4, '估时': 3, '结构': 3, 'GMID': 2, '错误': 2, '工厂': 1, '老板': 1, '报价': 1, '停机': 1, '利用率': 1, 'hpm': 1, 'fsm': 1, '联网': 1, '性能参数': 1, '差距': 1, 'nrp2': 1, 'lxds': 1, 'Technical': 1, 'content': 1, 'xml': 1, '本机': 1, '低版本': 1, '原型': 1, '草图': 1, '后台': 1, '小组': 1, 'dll': 1, '地方': 1, '弹窗': 1})
# Counter({'CypNest': 0.10416666666666667, '文件': 0.10416666666666667, '云端': 0.08333333333333333, '估时': 0.0625, '结构': 0.0625, 'GMID': 0.041666666666666664, '错误': 0.041666666666666664, '工厂': 0.020833333333333332, '老板': 0.020833333333333332, '报价': 0.020833333333333332, '停机': 0.020833333333333332, '利用率': 0.020833333333333332, 'hpm': 0.020833333333333332, 'fsm': 0.020833333333333332, '联网': 0.020833333333333332, '性能参数': 0.020833333333333332, '差距': 0.020833333333333332, 'nrp2': 0.020833333333333332, 'lxds': 0.020833333333333332, 'Technical': 0.020833333333333332, 'content': 0.020833333333333332, 'xml': 0.020833333333333332, '本机': 0.020833333333333332, '低版本': 0.020833333333333332, '原型': 0.020833333333333332, '草图': 0.020833333333333332, '后台': 0.020833333333333332, '小组': 0.020833333333333332, 'dll': 0.020833333333333332, '地方': 0.020833333333333332, '弹窗': 0.020833333333333332})
# 4614
# Counter({'板材': 4, '材质': 4, '厚度': 3, '图纸': 2, '尺寸': 2, '客服': 1, '标的': 1})
# Counter({'板材': 0.23529411764705882, '材质': 0.23529411764705882, '厚度': 0.17647058823529413, '图纸': 0.11764705882352941, '尺寸': 0.11764705882352941, '客服': 0.058823529411764705, '标的': 0.058823529411764705})
# 4615
# Counter({'穿孔': 6, '斯特': 2, 'HypCut': 2, '高度': 2, '经理': 1, '普雷': 1, '板面': 1, '视频': 1, '视觉效果': 1, '效率': 1})
# Counter({'穿孔': 0.3333333333333333, '斯特': 0.1111111111111111, 'HypCut': 0.1111111111111111, '高度': 0.1111111111111111, '经理': 0.05555555555555555, '普雷': 0.05555555555555555, '板面': 0.05555555555555555, '视频': 0.05555555555555555, '视觉效果': 0.05555555555555555, '效率': 0.05555555555555555})
# 4616
# Counter({'共用': 4, '定子': 3, '定位': 2, '蓝思罗': 1, '模式': 1, '静态': 1, '龙门': 1, '交叉': 1, '区域': 1, '信号': 1, '状态': 1, '标定': 1})
# Counter({'共用': 0.2222222222222222, '定子': 0.16666666666666666, '定位': 0.1111111111111111, '蓝思罗': 0.05555555555555555, '模式': 0.05555555555555555, '静态': 0.05555555555555555, '龙门': 0.05555555555555555, '交叉': 0.05555555555555555, '区域': 0.05555555555555555, '信号': 0.05555555555555555, '状态': 0.05555555555555555, '标定': 0.05555555555555555})
# 4617
# Counter({'密码': 6, 'OEM': 4, '程序': 2, '江苏': 1, '维特': 1, 'CypCut': 1, '平台': 1, '工具': 1, '初始密码': 1, '损耗': 1})
# Counter({'密码': 0.3157894736842105, 'OEM': 0.21052631578947367, '程序': 0.10526315789473684, '江苏': 0.05263157894736842, '维特': 0.05263157894736842, 'CypCut': 0.05263157894736842, '平台': 0.05263157894736842, '工具': 0.05263157894736842, '初始密码': 0.05263157894736842, '损耗': 0.05263157894736842})
# 4618
# Counter({'图层': 5, '尺寸': 3, '轮廓': 3, '范围': 2, '终端用户': 1, '客服': 1, '场景': 1})
# Counter({'图层': 0.3125, '尺寸': 0.1875, '轮廓': 0.1875, '范围': 0.125, '终端用户': 0.0625, '客服': 0.0625, '场景': 0.0625})
# 4619
# Counter({'报价单': 3, 'pdf': 2, '格式': 2, '客服': 1, '单的': 1, '单子': 1, '表单': 1, '文件': 1})
# Counter({'报价单': 0.25, 'pdf': 0.16666666666666666, '格式': 0.16666666666666666, '客服': 0.08333333333333333, '单的': 0.08333333333333333, '单子': 0.08333333333333333, '表单': 0.08333333333333333, '文件': 0.08333333333333333})
# 4620
# Counter({'编号': 5, '报告单': 4, '图纸': 2, '装配车间': 2, 'CypNest': 1, '文件': 1, '车间': 1, '表单': 1, '序号': 1, '列表': 1})
# Counter({'编号': 0.2631578947368421, '报告单': 0.21052631578947367, '图纸': 0.10526315789473684, '装配车间': 0.10526315789473684, 'CypNest': 0.05263157894736842, '文件': 0.05263157894736842, '车间': 0.05263157894736842, '表单': 0.05263157894736842, '序号': 0.05263157894736842, '列表': 0.05263157894736842})
# 4621
# Counter({'图形': 4, '修正': 4, '标题栏': 2, '显示文件': 2, '名称': 2, '文件': 2, '文件名称': 1, '体验': 1, '经理': 1, '徐总': 1, '项目经理': 1, '石斌': 1, '文字': 1, '后缀': 1, '人为': 1})
# Counter({'图形': 0.16, '修正': 0.16, '标题栏': 0.08, '显示文件': 0.08, '名称': 0.08, '文件': 0.08, '文件名称': 0.04, '体验': 0.04, '经理': 0.04, '徐总': 0.04, '项目经理': 0.04, '石斌': 0.04, '文字': 0.04, '后缀': 0.04, '人为': 0.04})
# 4622
# Counter({'单线': 2, '余料': 2, 'CypNest': 1, '红框': 1, '板材': 1, '手动': 1})
# Counter({'单线': 0.25, '余料': 0.25, 'CypNest': 0.125, '红框': 0.125, '板材': 0.125, '手动': 0.125})
# 4623
# Counter({'余料': 7, '绘制': 5, '手动': 3, 'CypNest': 2})
# Counter({'余料': 0.4117647058823529, '绘制': 0.29411764705882354, '手动': 0.17647058823529413, 'CypNest': 0.11764705882352941})
# 4624
# Counter({'利用率': 8, '老板': 2, 'CypNest': 1, '板材': 1, '类型': 1})
# Counter({'利用率': 0.6153846153846154, '老板': 0.15384615384615385, 'CypNest': 0.07692307692307693, '板材': 0.07692307692307693, '类型': 0.07692307692307693})
# 4625
# Counter({'HypCut': 1, '经理': 1, '林华斌': 1, '华南': 1, '荣品': 1, '典型': 1, '场景': 1, '碳钢': 1, '整板': 1, '前半部': 1, '表面': 1, '板面': 1, '生效': 1, '选项': 1, '视频': 1, '附件': 1})
# Counter({'HypCut': 0.0625, '经理': 0.0625, '林华斌': 0.0625, '华南': 0.0625, '荣品': 0.0625, '典型': 0.0625, '场景': 0.0625, '碳钢': 0.0625, '整板': 0.0625, '前半部': 0.0625, '表面': 0.0625, '板面': 0.0625, '生效': 0.0625, '选项': 0.0625, '视频': 0.0625, '附件': 0.0625})
# 4626
# Counter({'切法': 2, '断面': 2, 'TubesT': 2, '分段': 2, '槽钢': 1, '角钢': 1, '音视频': 1, '安利': 1, '优质': 1, '方法': 1, '视频': 1, '专门': 1, '原本': 1})
# Counter({'切法': 0.11764705882352941, '断面': 0.11764705882352941, 'TubesT': 0.11764705882352941, '分段': 0.11764705882352941, '槽钢': 0.058823529411764705, '角钢': 0.058823529411764705, '音视频': 0.058823529411764705, '安利': 0.058823529411764705, '优质': 0.058823529411764705, '方法': 0.058823529411764705, '视频': 0.058823529411764705, '专门': 0.058823529411764705, '原本': 0.058823529411764705})
# 4627
# Counter({'数量': 5, '图纸': 5, '套数': 2, '整体': 1, '客服': 1, '场景': 1, '列表': 1, '样子': 1})
# Counter({'数量': 0.29411764705882354, '图纸': 0.29411764705882354, '套数': 0.11764705882352941, '整体': 0.058823529411764705, '客服': 0.058823529411764705, '场景': 0.058823529411764705, '列表': 0.058823529411764705, '样子': 0.058823529411764705})
# 4628
# Counter({'气体': 7, 'Cypcut': 2, '平台': 2, '工具': 2})
# Counter({'气体': 0.5384615384615384, 'Cypcut': 0.15384615384615385, '平台': 0.15384615384615385, '工具': 0.15384615384615385})
# 4629
# Counter({'模式': 3, '步骤': 1, '图纸': 1, '全局': 1})
# Counter({'模式': 0.5, '步骤': 0.16666666666666666, '图纸': 0.16666666666666666, '全局': 0.16666666666666666})
# 4630
# Counter({'步骤': 1, '附件': 1, 'YXY': 1, '文件': 1, '孤岛': 1})
# Counter({'步骤': 0.2, '附件': 0.2, 'YXY': 0.2, '文件': 0.2, '孤岛': 0.2})
# 4631
# Counter({'引线': 6, '群组': 4, '来源': 1, 'Cypcut': 1, '生效': 1, '小源': 1, '和娜姐': 1})
# Counter({'引线': 0.4, '群组': 0.26666666666666666, '来源': 0.06666666666666667, 'Cypcut': 0.06666666666666667, '生效': 0.06666666666666667, '小源': 0.06666666666666667, '和娜姐': 0.06666666666666667})
# 4632
# Counter({'角度': 2, '管心': 2, '顶点': 1, '距离': 1})
# Counter({'角度': 0.3333333333333333, '管心': 0.3333333333333333, '顶点': 0.16666666666666666, '距离': 0.16666666666666666})
# 4633
# Counter({'圆心': 10, '距离': 10, '半径': 9, '圆弧': 7, '管头': 3, '角度': 3, '形状': 3, '管心': 2, '举例': 2, '长度': 2, '管子': 2, '宽度': 2, '图形': 2, 'tubest': 1, '绘制': 1, '线段': 1})
# Counter({'圆心': 0.16666666666666666, '距离': 0.16666666666666666, '半径': 0.15, '圆弧': 0.11666666666666667, '管头': 0.05, '角度': 0.05, '形状': 0.05, '管心': 0.03333333333333333, '举例': 0.03333333333333333, '长度': 0.03333333333333333, '管子': 0.03333333333333333, '宽度': 0.03333333333333333, '图形': 0.03333333333333333, 'tubest': 0.016666666666666666, '绘制': 0.016666666666666666, '线段': 0.016666666666666666})
# 4634
# Counter({'喷码': 6, '单行': 3, '标签': 3, '门业': 2, '工人': 2, '文字': 2, '红色': 2, '宽度': 1, '工厂': 1, '光线': 1, '能将': 1, '手写': 1, '编号': 1})
# Counter({'喷码': 0.23076923076923078, '单行': 0.11538461538461539, '标签': 0.11538461538461539, '门业': 0.07692307692307693, '工人': 0.07692307692307693, '文字': 0.07692307692307693, '红色': 0.07692307692307693, '宽度': 0.038461538461538464, '工厂': 0.038461538461538464, '光线': 0.038461538461538464, '能将': 0.038461538461538464, '手写': 0.038461538461538464, '编号': 0.038461538461538464})
# 4635
# Counter({'喷码': 6, '平台': 2, '工具': 2, '装机': 2, '信号': 2, '界面显示': 1, '参数设置': 1, '延时': 1, '阶跃': 1})
# Counter({'喷码': 0.3333333333333333, '平台': 0.1111111111111111, '工具': 0.1111111111111111, '装机': 0.1111111111111111, '信号': 0.1111111111111111, '界面显示': 0.05555555555555555, '参数设置': 0.05555555555555555, '延时': 0.05555555555555555, '阶跃': 0.05555555555555555})
# 4636
# Counter({'CypNest': 4, 'dll': 3, 'TechnicalID': 3, '云端': 2, '能力': 2, '材质': 2, '厚度': 2, '气体': 2, 'GMID': 2, 'pms': 1, 'index': 1, 'php': 1, 'story': 1, 'view': 1, 'API': 1, '函数': 1, 'LoadMachines': 1, 'Material': 1, 'Thickness': 1, 'Gas': 1, '全部': 1, 'LoadTechnical': 1})
# Counter({'CypNest': 0.11428571428571428, 'dll': 0.08571428571428572, 'TechnicalID': 0.08571428571428572, '云端': 0.05714285714285714, '能力': 0.05714285714285714, '材质': 0.05714285714285714, '厚度': 0.05714285714285714, '气体': 0.05714285714285714, 'GMID': 0.05714285714285714, 'pms': 0.02857142857142857, 'index': 0.02857142857142857, 'php': 0.02857142857142857, 'story': 0.02857142857142857, 'view': 0.02857142857142857, 'API': 0.02857142857142857, '函数': 0.02857142857142857, 'LoadMachines': 0.02857142857142857, 'Material': 0.02857142857142857, 'Thickness': 0.02857142857142857, 'Gas': 0.02857142857142857, '全部': 0.02857142857142857, 'LoadTechnical': 0.02857142857142857})
# 4637
# Counter({'卡盘': 3, '密封': 1, 'PLC': 1})
# Counter({'卡盘': 0.6, '密封': 0.2, 'PLC': 0.2})
# 4638
# Counter({'济南': 2, '驱动器': 1, '陈宇轩': 1, '科技': 1, '有限公司': 1, '解决方案': 1, '云中': 1, '解决问题': 1})
# Counter({'济南': 0.2222222222222222, '驱动器': 0.1111111111111111, '陈宇轩': 0.1111111111111111, '科技': 0.1111111111111111, '有限公司': 0.1111111111111111, '解决方案': 0.1111111111111111, '云中': 0.1111111111111111, '解决问题': 0.1111111111111111})
# 4639
# Counter({'尖角': 4, '原地': 2, 'HypCut': 1, '经理': 1, '领创': 1, '宝哥': 1, '三角形': 1, '过长': 1, '附件': 1, '视频': 1, '地方': 1})
# Counter({'尖角': 0.26666666666666666, '原地': 0.13333333333333333, 'HypCut': 0.06666666666666667, '经理': 0.06666666666666667, '领创': 0.06666666666666667, '宝哥': 0.06666666666666667, '三角形': 0.06666666666666667, '过长': 0.06666666666666667, '附件': 0.06666666666666667, '视频': 0.06666666666666667, '地方': 0.06666666666666667})
# 4640
# Counter({'喷码': 20, '标准': 6, 'DPI': 4, '范围': 3, 'BMH': 3, '高度': 2, '参数设置': 1, '界面显示': 1, '全局': 1, '入口': 1, '标签': 1, '名称': 1, '关系': 1, '可选项': 1, '墨盒': 1, '类型': 1, '典藏': 1, '单位': 1, '小时': 1})
# Counter({'喷码': 0.39215686274509803, '标准': 0.11764705882352941, 'DPI': 0.0784313725490196, '范围': 0.058823529411764705, 'BMH': 0.058823529411764705, '高度': 0.0392156862745098, '参数设置': 0.0196078431372549, '界面显示': 0.0196078431372549, '全局': 0.0196078431372549, '入口': 0.0196078431372549, '标签': 0.0196078431372549, '名称': 0.0196078431372549, '关系': 0.0196078431372549, '可选项': 0.0196078431372549, '墨盒': 0.0196078431372549, '类型': 0.0196078431372549, '典藏': 0.0196078431372549, '单位': 0.0196078431372549, '小时': 0.0196078431372549})
# 4641
# Counter({'骨架': 2, '右键': 1, '余料': 1, '强度': 1, '示意图': 1})
# Counter({'骨架': 0.3333333333333333, '右键': 0.16666666666666666, '余料': 0.16666666666666666, '强度': 0.16666666666666666, '示意图': 0.16666666666666666})

# %%
words
# Out:
# Counter({'加密狗': 28,
#          '选型': 10,
#          '硬件': 54,
#          '时钟': 2,
#          '稳定性': 48,
#          '信誉': 2,
#          '供货': 2,
#          '价格': 23,
#          '外框': 21,
#          '排序': 151,
#          '标图': 17,
#          '图层': 146,
#          '原则': 12,
#          '图形': 502,
#          '选项': 279,
#          '规则': 58,
#          '板材': 287,
#          '水平度': 1,
#          '曲面': 1,
#          '模式': 240,
#          '带膜': 1,
#          '工作台': 98,
#          '由天琪': 1,
#          '迪能': 66,
#          '手工': 26,
#          '按钮': 252,
#          '动作': 280,
#          '钢板': 13,
#          '气缸': 46,
#          '条件': 58,
#          '信号': 212,
#          '行程开关': 3,
#          '控制卡': 29,
#          'CypOne': 20,
#          '动态': 12,
#          'mmm': 1,
#          'and': 2,
#          '滤波器': 3,
#          'FBFW3': 1,
#          'MaxAcc': 1,
#          'WorkSpeed': 1,
#          'Acc': 1,
#          '加速度': 48,
#          'FIRFreq': 1,
#          '通滤波': 14,
#          '频率': 59,
#          'ArcTolerance': 1,
#          '圆弧': 56,
#          '控制精度': 12,
#          'CornerTolerance': 1,
#          '拐角': 45,
#          'SplitTime': 1,
#          '边框': 37,
#          '程序': 125,
#          '任务栏': 4,
#          'Windows': 5,
#          '对话框': 11,
#          'CypCut': 318,
#          'Cypcut': 77,
#          '板子': 65,
#          '角度': 124,
#          '板边': 3,
#          '距离': 153,
#          '雷达': 4,
#          '功率': 99,
#          '曲线': 116,
#          '方法': 76,
#          '单调': 3,
#          '半速': 1,
#          '成功率': 7,
#          '规律': 7,
#          '方管': 67,
#          '高度': 128,
#          '圆管': 85,
#          '灯具': 1,
#          '艺术': 2,
#          '造型': 1,
#          '文字': 58,
#          '平面': 80,
#          '开机': 40,
#          '画面': 21,
#          '制造商': 92,
#          '出厂': 27,
#          '示教盒': 1,
#          '认知度': 1,
#          '加密': 33,
#          'BCS100': 62,
#          '天数': 4,
#          '序列号': 25,
#          '注册码': 17,
#          '贷款': 1,
#          '银行': 2,
#          'cypcut': 123,
#          '场合': 13,
#          '人机界面': 3,
#          '经理': 194,
#          '无线': 9,
#          '面板': 36,
#          '体验': 131,
#          '状态': 268,
#          '武汉': 17,
#          '天琪': 22,
#          '管径': 8,
#          '地方': 133,
#          '间距': 126,
#          '编程': 4,
#          '全局': 74,
#          '旋转轴': 23,
#          '减速比': 5,
#          '键盘': 16,
#          '开发人员': 79,
#          '强制性': 2,
#          '独立性': 2,
#          '时则': 4,
#          'DSP3000': 2,
#          '系列产品': 2,
#          '计时': 6,
#          '电池': 2,
#          '钥匙': 11,
#          '工具': 279,
#          '恒顺': 3,
#          '老板': 25,
#          '小弟': 2,
#          '权限': 52,
#          '电脑': 75,
#          '微狗': 1,
#          '许可证': 7,
#          '载体': 1,
#          'DSP3000M': 1,
#          '抗干扰性': 1,
#          '通讯': 57,
#          '伺服电机': 9,
#          '报警信号': 10,
#          '不合理': 54,
#          '步骤': 169,
#          '边缘': 31,
#          '材料': 97,
#          '引刀': 2,
#          '线会': 2,
#          '期望值': 2,
#          '等离子': 5,
#          '解密': 10,
#          '密码': 28,
#          'NCK': 1,
#          '限位': 103,
#          '单轴': 9,
#          '误差': 103,
#          '龙门': 19,
#          '基本功能': 4,
#          '主轴': 5,
#          '商务': 8,
#          '上位': 67,
#          'CLR': 2,
#          '管脚': 4,
#          '嘉铭': 1,
#          '清空': 5,
#          '错误': 90,
#          '欧系': 3,
#          'PLC': 213,
#          '韩国': 5,
#          'bjlaser': 1,
#          '路径': 59,
#          '有点': 42,
#          '明灯': 1,
#          '飞博': 3,
#          '协议': 25,
#          '应飞博': 1,
#          '老总': 1,
#          '中科': 4,
#          '光辉': 3,
#          '技术人员': 11,
#          '嘉泰': 45,
#          '陈大健': 2,
#          '个带': 2,
#          '市场': 208,
#          '英寸': 4,
#          '单位': 47,
#          '大量': 57,
#          '终端用户': 167,
#          '机制': 43,
#          '国际友人': 1,
#          '习惯': 99,
#          'oem': 6,
#          '警告': 35,
#          '图片': 54,
#          'BCP5045': 3,
#          'LED': 5,
#          '亮度': 3,
#          'SIEMENS': 1,
#          '相框': 1,
#          '乐创': 1,
#          '级联': 1,
#          '项目经理': 14,
#          '王仕卿': 5,
#          '磁铁': 1,
#          '磁力': 1,
#          '教盒': 1,
#          '迪能周': 4,
#          '橙色': 4,
#          '黄色': 19,
#          '身体': 1,
#          '区域': 125,
#          '标题栏': 11,
#          '间隔': 20,
#          '小时': 20,
#          '金厂': 7,
#          '工件': 56,
#          '发票': 5,
#          'PWM': 24,
#          '胶头': 1,
#          '创新性': 1,
#          '滴塑': 1,
#          '胶量': 1,
#          '拐弯': 3,
#          '整体': 67,
#          '网络连接': 6,
#          '网络结构': 1,
#          '网线': 7,
#          '网卡': 4,
#          '交换机': 6,
#          '编辑': 174,
#          'OEM': 111,
#          '数据库': 34,
#          '厂家': 16,
#          '列表': 127,
#          '资源': 19,
#          '计数': 13,
#          '管理者': 3,
#          '菜单': 38,
#          '次数': 34,
#          '使用者': 37,
#          '试用版': 1,
#          '上将': 1,
#          '文件': 378,
#          'Userconfig': 1,
#          '手动': 433,
#          '数量': 144,
#          'PIC': 1,
#          '端口': 18,
#          '庆源': 150,
#          '零点': 69,
#          '定义': 42,
#          '风险': 55,
#          '类型': 126,
#          '画圆': 2,
#          '原点': 168,
#          '高低压': 1,
#          '广州': 1,
#          '海目': 9,
#          '气路': 13,
#          '原理图': 1,
#          '附件': 243,
#          '空气': 22,
#          '氧气': 19,
#          '氮气': 19,
#          '流量': 3,
#          '高压': 7,
#          '单向': 5,
#          '电磁阀': 10,
#          '一段距离': 13,
#          '刚性': 17,
#          '床子': 13,
#          '因素': 17,
#          '原地': 5,
#          '烧点': 2,
#          '并联': 3,
#          '架构': 8,
#          '网络': 48,
#          '调高器': 19,
#          '损失': 23,
#          '性价比': 5,
#          '产生': 87,
#          '替代': 7,
#          '轨迹': 113,
#          '吹气': 26,
#          '热加工': 1,
#          '效应': 3,
#          '高精度': 13,
#          '可选择性': 2,
#          '用法': 2,
#          '浮渣': 8,
#          '温漂': 5,
#          '穿孔': 189,
#          '不锈钢': 25,
#          '分段': 17,
#          '传统': 16,
#          '自润滑': 5,
#          '延时': 116,
#          '润滑油': 4,
#          '俄文版': 1,
#          'Cyp': 2,
#          '幅面': 44,
#          '机型': 38,
#          '交换式': 1,
#          '效率': 224,
#          '山大鲁': 1,
#          '英文版': 8,
#          '页面': 168,
#          '网站': 12,
#          '框框': 7,
#          '红色': 47,
#          '字体': 19,
#          '平台': 293,
#          '除尘': 8,
#          '标记': 64,
#          '校平': 8,
#          '测试点': 1,
#          '动时': 1,
#          '失灵': 2,
#          '负向': 10,
#          '轴会': 12,
#          '机械': 119,
#          '分区': 2,
#          '无锡': 3,
#          '桥联': 10,
#          '卖点': 2,
#          '长度': 139,
#          '群组': 20,
#          'SPI': 5,
#          '说明书': 15,
#          'IPG': 57,
#          'YLS': 8,
#          'CCD': 10,
#          '对位': 3,
#          '广东地区': 1,
#          '机台': 18,
#          'PCB': 1,
#          '钢网': 1,
#          '蓝宝石': 10,
#          '陶瓷': 13,
#          '安全性': 30,
#          '上海': 7,
#          '奉贤': 1,
#          '周志祥': 8,
#          '指令': 112,
#          '起点': 101,
#          '进料': 4,
#          '管材': 185,
#          '全自动': 10,
#          '大族': 84,
#          '视频': 50,
#          '双驱': 28,
#          '专业': 21,
#          '米左右': 1,
#          '特作': 1,
#          '主动轴': 1,
#          '动轴': 1,
#          '参数设置': 50,
#          'min': 15,
#          '触点': 1,
#          '高能': 35,
#          'BMC1204': 1,
#          '脉冲': 34,
#          '平率': 1,
#          'KHz': 5,
#          'MHz': 2,
#          '比例': 11,
#          'Coreldraw': 1,
#          '绘制': 94,
#          '贝塞尔': 7,
#          '广告行业': 12,
#          'coreldraw': 2,
#          '绘图': 75,
#          'DXF': 28,
#          '格式': 68,
#          'CYPCUT': 8,
#          '圆是': 2,
#          '插件': 7,
#          '整圆': 4,
#          '分层': 2,
#          '性能': 33,
#          '冲孔': 4,
#          'MoveBy': 3,
#          '边界': 19,
#          '动会': 1,
#          '意义': 26,
#          '干涉仪': 20,
#          '光路': 10,
#          'ping': 1,
#          '本机': 6,
#          '地址': 22,
#          '高器': 151,
#          '宏石': 2,
#          '压力': 13,
#          '气体': 81,
#          '全部': 100,
#          '内存': 14,
#          '测试软件': 12,
#          'lxd': 41,
#          '全选': 14,
#          '间隙': 15,
#          'NestPart1371': 1,
#          'Access': 1,
#          'violation': 1,
#          'address': 2,
#          'D35E': 1,
#          'module': 1,
#          'cutext': 1,
#          'bpl': 4,
#          'Read': 1,
#          'C盘': 6,
#          '还原卡': 1,
#          '病毒感染': 1,
#          '平竖直': 3,
#          '直线': 103,
#          '钣金': 16,
#          '钣金件': 3,
#          '次序': 13,
#          '倒序': 2,
#          '钢管': 3,
#          '头部': 1,
#          '尾部': 2,
#          '界面显示': 31,
#          '刀线': 8,
#          '选择性': 3,
#          '大乘': 1,
#          '中心': 75,
#          '桌面': 4,
#          '开始菜单': 2,
#          '快捷方式': 2,
#          '名称': 96,
#          '图标': 36,
#          '文件夹': 23,
#          '驱动程序': 3,
#          '桌面上': 1,
#          '驱动器': 68,
#          '信号线': 1,
#          '电阻': 1,
#          '设计方案': 3,
#          '烧角': 5,
#          '厚板': 60,
#          '现象': 67,
#          '正方形': 8,
#          '拐角处': 19,
#          '水平': 32,
#          '天泓': 1,
#          '陈兆': 1,
#          '高功率': 50,
#          '尖角': 18,
#          '很漂亮': 1,
#          '天泓汪': 1,
#          '厂里': 2,
#          '工艺员': 1,
#          '黄工': 17,
#          '备份': 39,
#          '大功率': 9,
#          '光闸': 18,
#          '时序': 13,
#          'ProgramStart': 2,
#          '峰值': 26,
#          '电流': 17,
#          '大程度': 1,
#          '形式': 69,
#          'QCW': 28,
#          '指标': 7,
#          '乘积': 1,
#          '设定值': 12,
#          '符合要求': 3,
#          '触摸屏': 6,
#          'OUT': 8,
#          'CAD': 111,
#          '嘉兴': 1,
#          '瑞博': 1,
#          '客服': 138,
#          '重画': 5,
#          '内膜': 7,
#          '批量': 84,
#          '阈值': 18,
#          '范围': 128,
#          '固定设置': 1,
#          '标准': 91,
#          '提高效率': 24,
#          '节省': 34,
#          '人力': 7,
#          '卡盘': 169,
#          '浮头': 11,
#          '图案': 8,
#          '区别': 32,
#          '矩形': 88,
#          '原理': 12,
#          '方向': 160,
#          '坐标值': 18,
#          '支架': 103,
#          '金运': 9,
#          '区分': 125,
#          '交款': 1,
#          '伤感情': 1,
#          '人情味': 1,
#          '联系': 17,
#          '人性化': 3,
#          'CypTube': 21,
#          '丝杠': 1,
#          '导轨': 1,
#          '受限制': 3,
#          '走时': 3,
#          '利用': 41,
#          '托架': 1,
#          '太长': 1,
#          '支撑点': 2,
#          '圆孔': 33,
#          '小圆孔': 10,
#          '引线': 123,
#          '技术': 31,
#          '装机': 41,
#          '油路': 3,
#          '冲油': 1,
#          '油泵': 4,
#          '供油': 1,
#          '灯光': 5,
#          '尺寸': 144,
#          '重置': 8,
#          '自动记录': 5,
#          '收款': 2,
#          '演示版': 8,
#          '有所': 11,
#          '差异': 13,
#          '自动识别': 25,
#          '专用': 36,
#          '方便使用': 7,
#          '办事处': 1,
#          '环境': 30,
#          '光束': 2,
#          '特性': 13,
#          '气流': 2,
#          '顺时针': 15,
#          '逆时针': 14,
#          '远程': 27,
#          '固件': 36,
#          'V3059': 1,
#          '以太网': 1,
#          '文件名': 25,
#          'BCV3': 1,
#          'AFM': 1,
#          '字节': 1,
#          'ASCII': 1,
#          'x41': 1,
#          'x46': 1,
#          'x4D': 1,
#          'x10': 2,
#          'x42': 1,
#          'x43': 1,
#          'x53': 1,
#          'x31': 1,
#          'x30': 1,
#          '版本号': 18,
#          '市面上': 9,
#          '概率': 37,
#          '头会': 8,
#          '事情': 20,
#          '声音': 5,
#          '感观': 1,
#          '视觉效果': 10,
#          'Nlight': 2,
#          '齿条': 10,
#          'cfgpkg': 2,
#          '十字': 36,
#          '圆度': 8,
#          '六边形': 6,
#          '领创': 54,
#          '空心': 4,
#          '精雕': 6,
#          '中文字体': 2,
#          '重命名': 7,
#          '电动': 25,
#          '轴点': 10,
#          '端子板': 6,
#          '电容': 78,
#          '凌丰路': 1,
#          '坐标系': 44,
#          '补料': 6,
#          '定位': 266,
#          '午休': 1,
#          '胡工': 3,
#          '余料': 81,
#          '题目': 3,
#          '本体': 10,
#          'help': 1,
#          '解决方案': 21,
#          '提示信息': 15,
#          '微调': 22,
#          '生效': 121,
#          '时会': 36,
#          '图纸': 308,
#          '成品率': 1,
#          '我会': 22,
#          '单子': 19,
#          '货款': 1,
#          '理由': 7,
#          '顺序': 63,
#          '横线': 2,
#          '竖线': 1,
#          '变形': 22,
#          '技术支持': 19,
#          '网络通讯': 14,
#          '接线': 17,
#          'IP地址': 6,
#          'COM': 1,
#          '烧面': 1,
#          '板面': 12,
#          '编码器': 58,
#          '坡口': 25,
#          '名词解释': 1,
#          '唐总': 21,
#          '平面曲线': 1,
#          '直观': 68,
#          '总和': 1,
#          '明白': 2,
#          '相贯孔': 4,
#          '工序': 21,
#          '直角': 9,
#          '小孔': 9,
#          '空间': 21,
#          '交汇点': 1,
#          '圆心': 11,
#          '半径': 31,
#          '逻辑': 113,
#          '环切': 5,
#          '程度': 32,
#          '鼠标': 63,
#          '上料': 63,
#          '时动': 1,
#          '机械设计': 6,
#          '普适性': 2,
#          '策略': 16,
#          '死机': 3,
#          '方向向': 1,
#          '单张': 6,
#          '水平线': 3,
#          '形状': 30,
#          '研发部': 9,
#          '个数': 25,
#          '块板': 1,
#          '评价': 7,
#          '框架': 10,
#          '易用性': 6,
#          '原件': 1,
#          '利用率': 50,
#          'Mark': 52,
#          '图像': 28,
#          '模板': 52,
#          '误会': 3,
#          '关联': 36,
#          '顶料': 5,
#          '镀金': 1,
#          '表面': 20,
#          '过程中将': 2,
#          '错位': 11,
#          '操作员': 25,
#          '小心': 12,
#          'ESC': 4,
#          'AFK': 1,
#          'away': 1,
#          'from': 7,
#          'keyboard': 1,
#          '镜头': 9,
#          '视野': 30,
#          '眼镜': 4,
#          '行业': 24,
#          'mark': 89,
#          '工位': 33,
#          '视窗': 4,
#          '畸变': 2,
#          '苹果': 2,
#          'logo': 8,
#          '背盖': 1,
#          '摄像头': 6,
#          '闪光灯': 1,
#          '定位精度': 11,
#          '矩形框': 3,
#          '绿色': 24,
#          '白色': 20,
#          '同向': 1,
#          '彭文斌': 13,
#          'ready': 5,
#          'start': 1,
#          '赵建': 19,
#          '整板': 13,
#          '贴膜': 3,
#          '建都': 1,
#          '歧义': 7,
#          '所弹': 1,
#          '配件': 7,
#          '错误判断': 1,
#          '高效率': 3,
#          'cutup': 1,
#          '面积': 12,
#          '凭感觉': 1,
#          '实用性': 5,
#          '一键': 85,
#          'MARK': 2,
#          '制图员': 3,
#          '手点': 2,
#          '大端': 1,
#          '细边': 1,
#          '细化': 4,
#          '指向性': 1,
#          '缺相': 1,
#          '节省时间': 12,
#          '能力': 18,
#          '智能': 58,
#          '渠道': 5,
#          '阳切': 4,
#          'shift': 6,
#          '继电器': 6,
#          '常量': 1,
#          '附带': 3,
#          '高灵敏度': 1,
#          '漏光': 3,
#          '短时间': 6,
#          '内置': 9,
#          '先生': 1,
#          'Help': 1,
#          '总工': 1,
#          '须知': 1,
#          '冷水机': 1,
#          '故障诊断': 2,
#          '目录': 20,
#          '东西': 16,
#          '文件目录': 3,
#          'sysinfo': 1,
#          '命令': 28,
#          '节约': 35,
#          '粉丝': 2,
#          'cyptube': 18,
#          '倒角': 27,
#          '王飞锦': 5,
#          '行程': 75,
#          '机会': 9,
#          '装置': 41,
#          '管长': 5,
#          '支撑架': 8,
#          '开气': 9,
#          '洪涛': 34,
#          '和洲翔': 1,
#          '线段': 22,
#          '折线': 7,
#          '集体': 1,
#          '管子': 116,
#          '省料': 17,
#          '制图': 4,
#          '画图': 20,
#          '总长': 8,
#          'Word': 1,
#          'log': 3,
#          'txt': 3,
#          'word': 3,
#          '系统日志': 8,
#          '工厂': 46,
#          '成本': 64,
#          '生产商': 5,
#          '输入输出': 23,
#          '解决办法': 3,
#          '素养': 1,
#          '红光': 15,
#          '曝光': 7,
#          '交点': 12,
#          '材料库': 18,
#          '宏山': 149,
#          '焦距': 4,
#          '前会': 3,
#          '型号': 40,
#          '厚度': 76,
#          'veda': 2,
#          '入板': 2,
#          'ManualArray': 1,
#          '同类': 3,
#          '数目': 7,
#          '测试人员': 86,
#          'edit': 1,
#          '键入': 1,
#          'Edit': 1,
#          '框选': 19,
#          '右键': 26,
#          '耗时': 23,
#          '现实意义': 3,
#          '菱丰': 1,
#          '路工': 1,
#          '出边': 3,
#          '轴口': 15,
#          '测试工具': 4,
#          '字母': 8,
#          '数字': 20,
#          '信息量': 1,
#          '发生冲突': 1,
#          '矫正': 19,
#          '保温杯': 3,
#          'Demo': 7,
#          '蓝色': 16,
#          '所在位置': 2,
#          '杯口': 1,
#          '目标': 17,
#          '断面': 14,
#          '句容': 1,
#          '大华': 5,
#          '郭靖': 1,
#          '宫格': 1,
#          '格子': 3,
#          '整张': 4,
#          '温度': 20,
#          '部位': 1,
#          '装夹': 13,
#          '切段': 1,
#          '场景': 162,
#          '安全门': 9,
#          '调试模式': 6,
#          '最高级别': 1,
#          '主观': 3,
#          'YLR': 11,
#          '工人': 16,
#          '序号': 22,
#          'Integer': 4,
#          '插拔': 4,
#          'CYPTUBE': 4,
#          '丝杆': 6,
#          '单驱': 6,
#          '共用': 11,
#          '两用机': 2,
#          '误操作': 44,
#          '管板': 14,
#          '顶点': 21,
#          '特殊要求': 2,
#          '分支': 18,
#          '学生': 1,
#          '业务部': 1,
#          '薄板': 20,
#          'load': 1,
#          '焦点': 86,
#          '竞争力': 17,
#          '读数': 3,
#          '偏差': 78,
#          '检查和': 1,
#          '函数': 18,
#          '新建': 49,
#          'lxv': 13,
#          'dxf': 41,
#          '迅雷': 14,
#          '细小': 2,
#          '减速机': 8,
#          '偏位': 5,
#          '零漂': 2,
#          'machine': 12,
#          'config': 12,
#          'ZeroAdjustEn': 1,
#          '工艺品': 4,
#          '浪费': 47,
#          '整圈': 2,
#          '圈数': 5,
#          '身份': 3,
#          'LXD': 6,
#          'CypNest': 248,
#          '优势': 9,
#          'ArtEdit': 1,
#          '细节': 18,
#          '关键字': 4,
#          '菜单项': 1,
#          'vendor': 1,
#          '严巍': 9,
#          '电源': 13,
#          '泵压': 1,
#          '油位': 3,
#          '里油': 1,
#          '分割线': 3,
#          '黑色': 8,
#          '方框': 3,
#          'Beta': 1,
#          '两者': 12,
#          '消失': 18,
#          '关系': 49,
#          '厂商': 55,
#          '邦德': 34,
#          '高工': 3,
#          '字型': 3,
#          '降速': 13,
#          '高精密': 2,
#          '局部': 19,
#          '板下': 1,
#          '细分': 9,
#          'Veda': 1,
#          '张板': 8,
#          '代唐总': 5,
#          '光点': 5,
#          '断光': 1,
#          '光源': 29,
#          'Com': 1,
#          '寿命': 8,
#          '全程': 8,
#          '常开常': 3,
#          '蒲工': 1,
#          '使用寿命': 10,
#          '弹簧': 3,
#          '废料': 25,
#          '刀点': 7,
#          '外观': 5,
#          '大金': 6,
#          '基础': 55,
#          '标定': 136,
#          '最高点': 7,
#          '刻线': 1,
#          '局域网': 7,
#          '同事': 28,
#          '服务器': 13,
#          '李学文': 3,
#          '电压': 12,
#          '陈大建': 15,
#          '普雷斯特': 2,
#          '双赢': 2,
#          'DA3': 1,
#          '高电平': 7,
#          'follow': 1,
#          'DA1': 1,
#          'DA4': 1,
#          '区间': 17,
#          '公式': 8,
#          '板卡': 13,
#          '变频器': 3,
#          '减速慢行': 1,
#          'U盘': 3,
#          '不太会': 2,
#          '手机': 45,
#          '加解密': 3,
#          '卡时': 2,
#          '卡开': 1,
#          'enableport': 1,
#          '对象': 16,
#          '保险': 1,
#          '源头': 2,
#          '号口': 3,
#          'IGS': 31,
#          '模型': 16,
#          'IGSViewer': 1,
#          '唐晔': 33,
#          '按键': 34,
#          '案件': 1,
#          'cypvision': 37,
#          '数值': 30,
#          '键盘输入': 2,
#          '增益': 14,
#          '输入框': 9,
#          '加微': 8,
#          '下料': 64,
#          '缺口': 29,
#          '理论': 21,
#          '短距离': 10,
#          '浪费时间': 19,
#          '事故': 10,
#          '军方': 1,
#          '装饰': 1,
#          '领域': 3,
#          '代码生成': 1,
#          '地点': 2,
#          '可靠性': 8,
#          '角钢': 18,
#          '槽钢': 25,
#          '扁钢': 1,
#          '钢材': 2,
#          '外凸': 2,
#          '轮廓': 76,
#          '内凹': 5,
#          '借机': 1,
#          '金属': 10,
#          '背壳': 1,
#          '小圆': 21,
#          'YLP': 1,
#          '罗列': 3,
#          'Pin1': 1,
#          'Pin9': 1,
#          'Pin18': 1,
#          'Pin19': 1,
#          'Pin20': 1,
#          '光谷': 2,
#          '诺太': 1,
#          '毛胜婷': 1,
#          '德国': 4,
#          'Program': 1,
#          'Start': 1,
#          'Emission': 1,
#          'States': 1,
#          '平行': 9,
#          '二维码': 35,
#          '华俄': 7,
#          '田承新': 1,
#          '图号': 1,
#          '图库': 5,
#          '复制粘贴': 8,
#          '周小兰': 1,
#          '快捷键': 23,
#          '里点': 2,
#          '要点': 5,
#          '总经理': 2,
#          '布满': 4,
#          '缩略图': 15,
#          '工会': 2,
#          '工作日': 1,
#          '割线': 1,
#          '价值': 20,
#          '空移': 4,
#          '扳手': 1,
#          '波浪': 5,
#          '时调': 1,
#          '张宏涛': 1,
#          ...})

# %%
story_df
# Out:
#       story              title  \
# 1         1              加密狗选型
# 2         2     特定情况下的外框最后排序问题
# 3         3     带膜切割开发一个直接跟随选项
# 4         4        双交换工作台的到位检测
# 5         5       CypOne动态速度算法
# ...     ...                ...
# 4637   4637   增加plc：所有B轴强制绝对空移
# 4638   4638        支持读取驱动器的报警码
# 4639   4639    [预研需求]尖角入刀跟随不停顿
# 4640   4640        优化喷码参数设置界面。
# 4641   4641  排样结果右键增加整版自动居中的功能
#
#                                                    spec  \
# 1              选择一个合适的加密狗，带有硬件时钟，稳定性好，供应商信誉好，供货稳定，价格偏移。
# 2     类似于\n打标图层\n:\n开放一个\n最后切割图层\n, \n以弥补和应对\n新排序原则下...
# 3           目前带膜切割采用的是类似于定高切割规则执行，能满足大多数需求。\n但是如果切割板...
# 4     \r\n需求由天琪、迪能提出\r\n\r\n目前双交换工作台是用手工方式来控制的，也就是客户...
# 5     1. 在不同速度下算法的切换。\r\n    1）速度\r\n < 10mmm/s \r\n...
# ...                                                 ...
# 4637  客户使用的密封销卡盘，需要卡盘移到到固定位置进行夹紧松开，于是配的PLC卡盘。\n但目前的B...
# 4638  从空软陈宇轩的出差报告中得知：\n作为济南济南新天科技有限公司，我使用设备健康云时，监控到的...
# 4639  我是HypCut产品经理，我发现领创终端宝哥那边切三角形的零件时，在尖角入刀的时候，切割头判...
# 4640  【内部迭代需求】\n          基于功能点文档优化界面显示。功能点文档参考：http...
# 4641  作为一名用户，当排样结果不能排入更多的零件且余料很小没有用时，希望有整版自动居中的功能。\n...
#
#                                                     seg
# 1     {'加密狗': 5.72, '选型': 4.06, '硬件': 2.19, '时钟': 5....
# 2     {'外框': 5.73, '排序': 3.51, '标图': 3.08, '图层': 1.1...
# 3     {'选项': 0.79, '规则': 3.81, '板材': 2.32, '水平度': 6....
# 4     {'工作台': 2.96, '由天琪': 2.4, '迪能': 0.72, '手工': 2....
# 5     {'CypOne': 0.83, '动态': 0.99, 'mmm': 6.86, 'and...
# ...                                                 ...
# 4637             {'密封': 10.79, '卡盘': 6.56, 'PLC': 1.89}
# 4638  {'驱动器': 1.97, '陈宇轩': 6.67, '济南': 10.38, '科技': ...
# 4639  {'尖角': 8.06, 'HypCut': 0.69, '经理': 0.67, '领创':...
# 4640  {'喷码': 12.9, '参数设置': 0.4, '界面显示': 0.49, '全局': ...
# 4641  {'右键': 4.42, '余料': 2.71, '骨架': 10.28, '强度': 8....
#
# [4641 rows x 4 columns]

# %%
upload_df = story_df.drop(columns= ['seg']).copy(deep =  True)
upload_df['keywords'] = ''

# %%
from datetime import datetime
from elasticsearch import Elasticsearch


es = Elasticsearch('127.0.0.1:9200')

# %%
import math
for i in range(1, len(upload_df) + 1):
    tf = story_df['seg'][i].copy()
    for word in tf:
        tf[word] = round(tf[word]*math.log(words['n']/(words[word] + 1)), 2)
    tf = dict(tf.most_common(10))
    upload_df['keywords'][i] = tf
    
    es.index(index="articles", id=es_id, body=upload_df.loc[i,:])
# Out:
# d:\Users\fscut\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
upload_df
# Out:
#       story              title  \
# 1         1              加密狗选型
# 2         2     特定情况下的外框最后排序问题
# 3         3     带膜切割开发一个直接跟随选项
# 4         4        双交换工作台的到位检测
# 5         5       CypOne动态速度算法
# ...     ...                ...
# 4637   4637   增加plc：所有B轴强制绝对空移
# 4638   4638        支持读取驱动器的报警码
# 4639   4639    [预研需求]尖角入刀跟随不停顿
# 4640   4640        优化喷码参数设置界面。
# 4641   4641  排样结果右键增加整版自动居中的功能
#
#                                                    spec  \
# 1              选择一个合适的加密狗，带有硬件时钟，稳定性好，供应商信誉好，供货稳定，价格偏移。
# 2     类似于\n打标图层\n:\n开放一个\n最后切割图层\n, \n以弥补和应对\n新排序原则下...
# 3           目前带膜切割采用的是类似于定高切割规则执行，能满足大多数需求。\n但是如果切割板...
# 4     \r\n需求由天琪、迪能提出\r\n\r\n目前双交换工作台是用手工方式来控制的，也就是客户...
# 5     1. 在不同速度下算法的切换。\r\n    1）速度\r\n < 10mmm/s \r\n...
# ...                                                 ...
# 4637  客户使用的密封销卡盘，需要卡盘移到到固定位置进行夹紧松开，于是配的PLC卡盘。\n但目前的B...
# 4638  从空软陈宇轩的出差报告中得知：\n作为济南济南新天科技有限公司，我使用设备健康云时，监控到的...
# 4639  我是HypCut产品经理，我发现领创终端宝哥那边切三角形的零件时，在尖角入刀的时候，切割头判...
# 4640  【内部迭代需求】\n          基于功能点文档优化界面显示。功能点文档参考：http...
# 4641  作为一名用户，当排样结果不能排入更多的零件且余料很小没有用时，希望有整版自动居中的功能。\n...
#
#                                                keywords
# 1     {'时钟': 6.02, '信誉': 6.02, '供货': 6.02, '加密狗': 5....
# 2     {'原则': 6.94, '外框': 5.73, '排序': 3.52, '标图': 3.1...
# 3     {'水平度': 5.97, '曲面': 5.97, '带膜': 5.97, '规则': 3....
# 4     {'工作台': 2.96, '气缸': 2.53, '由天琪': 2.4, '手工': 2....
# 5     {'FBFW3': 8.6, 'mmm': 6.9, '加速度': 4.14, '滤波器':...
# ...                                                 ...
# 4637              {'密封': 10.8, '卡盘': 6.55, 'PLC': 1.91}
# 4638  {'济南': 10.39, '陈宇轩': 6.66, '有限公司': 5.5, '科技': ...
# 4639  {'尖角': 8.08, '原地': 5.92, '宝哥': 3.6, '三角形': 3.1...
# 4640  {'喷码': 12.9, 'DPI': 4.26, 'BMH': 3.56, '标准': 1...
# 4641  {'骨架': 10.27, '强度': 8.96, '示意图': 4.46, '右键': 4...
#
# [4641 rows x 4 columns]

# %%
dict(Counter({'a':0.5, 'b': 0.6 , 'c': 0.3}).most_common(2))
# Out:
# {'b': 0.6, 'a': 0.5}

# %%
upload_df
# Out:
#       story              title  \
# 1         1              加密狗选型
# 2         2     特定情况下的外框最后排序问题
# 3         3     带膜切割开发一个直接跟随选项
# 4         4        双交换工作台的到位检测
# 5         5       CypOne动态速度算法
# ...     ...                ...
# 4637   4637   增加plc：所有B轴强制绝对空移
# 4638   4638        支持读取驱动器的报警码
# 4639   4639    [预研需求]尖角入刀跟随不停顿
# 4640   4640        优化喷码参数设置界面。
# 4641   4641  排样结果右键增加整版自动居中的功能
#
#                                                    spec
# 1     {'加密狗': 1.1278642909454892, '时钟': 0.8160080945...
# 2     {'原则': 1.1755471563559279, '外框': 1.07032853717...
# 3     {'规则': 0.8730295390670912, '板材': 0.83391739773...
# 4     {'工作台': 0.7695130578213172, '气缸': 0.5511045045...
# 5     {'FBFW3': 1.1070768512401756, '加速度': 0.9101729...
# ...                                                 ...
# 4637  {'卡盘': 1.9841320213145486, '密封': 1.46881457011...
# 4638  {'济南': 1.5184993837349057, '陈宇轩': 0.8610597731...
# 4639  {'尖角': 1.4661989760199294, '原地': 0.88679008933...
# 4640  {'喷码': 2.248876446329006, 'DPI': 0.57600571377...
# 4641  {'骨架': 1.8507711271150038, '强度': 1.22401214176...
#
# [4641 rows x 3 columns]

# %%
story_df.to_json('data/pms_story.json')

# %%
import json
f = open("data\wordcount.json", 'w')
json.dump(words,f)
f.close()

# %%
with open("data\wordcount.json") as f:
    word_count = json.load(f)
word_count
# Out:
# {'加密狗': 28,
#  '选型': 10,
#  '硬件': 54,
#  '时钟': 2,
#  '稳定性': 48,
#  '信誉': 2,
#  '供货': 2,
#  '价格': 23,
#  '外框': 21,
#  '排序': 151,
#  '标图': 17,
#  '图层': 146,
#  '原则': 12,
#  '图形': 502,
#  '选项': 279,
#  '规则': 58,
#  '板材': 287,
#  '水平度': 1,
#  '曲面': 1,
#  '模式': 240,
#  '带膜': 1,
#  '工作台': 98,
#  '由天琪': 1,
#  '迪能': 66,
#  '手工': 26,
#  '按钮': 252,
#  '动作': 280,
#  '钢板': 13,
#  '气缸': 46,
#  '条件': 58,
#  '信号': 212,
#  '行程开关': 3,
#  '控制卡': 29,
#  'CypOne': 20,
#  '动态': 12,
#  'mmm': 1,
#  'and': 2,
#  '滤波器': 3,
#  'FBFW3': 1,
#  'MaxAcc': 1,
#  'WorkSpeed': 1,
#  'Acc': 1,
#  '加速度': 48,
#  'FIRFreq': 1,
#  '通滤波': 14,
#  '频率': 59,
#  'ArcTolerance': 1,
#  '圆弧': 56,
#  '控制精度': 12,
#  'CornerTolerance': 1,
#  '拐角': 45,
#  'SplitTime': 1,
#  '边框': 37,
#  '程序': 125,
#  '任务栏': 4,
#  'Windows': 5,
#  '对话框': 11,
#  'CypCut': 318,
#  'Cypcut': 77,
#  '板子': 65,
#  '角度': 124,
#  '板边': 3,
#  '距离': 153,
#  '雷达': 4,
#  '功率': 99,
#  '曲线': 116,
#  '方法': 76,
#  '单调': 3,
#  '半速': 1,
#  '成功率': 7,
#  '规律': 7,
#  '方管': 67,
#  '高度': 127,
#  '圆管': 85,
#  '灯具': 1,
#  '艺术': 2,
#  '造型': 1,
#  '文字': 58,
#  '平面': 80,
#  '开机': 40,
#  '画面': 21,
#  '制造商': 92,
#  '出厂': 27,
#  '示教盒': 1,
#  '认知度': 1,
#  '加密': 33,
#  'BCS100': 62,
#  '天数': 4,
#  '序列号': 25,
#  '注册码': 17,
#  '贷款': 1,
#  '银行': 2,
#  'cypcut': 123,
#  '场合': 13,
#  '人机界面': 3,
#  '经理': 194,
#  '无线': 9,
#  '面板': 36,
#  '体验': 131,
#  '状态': 268,
#  '武汉': 17,
#  '天琪': 22,
#  '管径': 8,
#  '地方': 133,
#  '间距': 126,
#  '编程': 4,
#  '全局': 73,
#  '旋转轴': 23,
#  '减速比': 5,
#  '键盘': 16,
#  '开发人员': 79,
#  '强制性': 2,
#  '独立性': 2,
#  '时则': 4,
#  'DSP3000': 2,
#  '系列产品': 2,
#  '计时': 6,
#  '电池': 2,
#  '钥匙': 11,
#  '工具': 279,
#  '恒顺': 3,
#  '老板': 25,
#  '小弟': 2,
#  '权限': 52,
#  '电脑': 75,
#  '微狗': 1,
#  '许可证': 7,
#  '载体': 1,
#  'DSP3000M': 1,
#  '抗干扰性': 1,
#  '通讯': 57,
#  '伺服电机': 9,
#  '报警信号': 10,
#  '不合理': 54,
#  '步骤': 169,
#  '边缘': 31,
#  '材料': 97,
#  '引刀': 2,
#  '线会': 2,
#  '期望值': 2,
#  '等离子': 5,
#  '解密': 10,
#  '密码': 28,
#  'NCK': 1,
#  '限位': 103,
#  '单轴': 9,
#  '误差': 103,
#  '龙门': 19,
#  '基本功能': 4,
#  '主轴': 5,
#  '商务': 8,
#  '上位': 67,
#  'CLR': 2,
#  '管脚': 4,
#  '嘉铭': 1,
#  '清空': 5,
#  '错误': 90,
#  '欧系': 3,
#  'PLC': 213,
#  '韩国': 5,
#  'bjlaser': 1,
#  '路径': 59,
#  '有点': 42,
#  '明灯': 1,
#  '飞博': 3,
#  '协议': 25,
#  '应飞博': 1,
#  '老总': 1,
#  '中科': 4,
#  '光辉': 3,
#  '技术人员': 11,
#  '嘉泰': 45,
#  '陈大健': 2,
#  '个带': 2,
#  '市场': 208,
#  '英寸': 4,
#  '单位': 46,
#  '大量': 57,
#  '终端用户': 167,
#  '机制': 43,
#  '国际友人': 1,
#  '习惯': 99,
#  'oem': 6,
#  '警告': 35,
#  '图片': 54,
#  'BCP5045': 3,
#  'LED': 5,
#  '亮度': 3,
#  'SIEMENS': 1,
#  '相框': 1,
#  '乐创': 1,
#  '级联': 1,
#  '项目经理': 14,
#  '王仕卿': 5,
#  '磁铁': 1,
#  '磁力': 1,
#  '教盒': 1,
#  '迪能周': 4,
#  '橙色': 4,
#  '黄色': 19,
#  '身体': 1,
#  '区域': 125,
#  '标题栏': 11,
#  '间隔': 20,
#  '小时': 19,
#  '金厂': 7,
#  '工件': 56,
#  '发票': 5,
#  'PWM': 24,
#  '胶头': 1,
#  '创新性': 1,
#  '滴塑': 1,
#  '胶量': 1,
#  '拐弯': 3,
#  '整体': 67,
#  '网络连接': 6,
#  '网络结构': 1,
#  '网线': 7,
#  '网卡': 4,
#  '交换机': 6,
#  '编辑': 174,
#  'OEM': 111,
#  '数据库': 34,
#  '厂家': 16,
#  '列表': 127,
#  '资源': 19,
#  '计数': 13,
#  '管理者': 3,
#  '菜单': 38,
#  '次数': 34,
#  '使用者': 37,
#  '试用版': 1,
#  '上将': 1,
#  '文件': 378,
#  'Userconfig': 1,
#  '手动': 433,
#  '数量': 144,
#  'PIC': 1,
#  '端口': 18,
#  '庆源': 150,
#  '零点': 69,
#  '定义': 42,
#  '风险': 55,
#  '类型': 125,
#  '画圆': 2,
#  '原点': 168,
#  '高低压': 1,
#  '广州': 1,
#  '海目': 9,
#  '气路': 13,
#  '原理图': 1,
#  '附件': 243,
#  '空气': 22,
#  '氧气': 19,
#  '氮气': 19,
#  '流量': 3,
#  '高压': 7,
#  '单向': 5,
#  '电磁阀': 10,
#  '一段距离': 13,
#  '刚性': 17,
#  '床子': 13,
#  '因素': 17,
#  '原地': 5,
#  '烧点': 2,
#  '并联': 3,
#  '架构': 8,
#  '网络': 48,
#  '调高器': 19,
#  '损失': 23,
#  '性价比': 5,
#  '产生': 87,
#  '替代': 7,
#  '轨迹': 113,
#  '吹气': 26,
#  '热加工': 1,
#  '效应': 3,
#  '高精度': 13,
#  '可选择性': 2,
#  '用法': 2,
#  '浮渣': 8,
#  '温漂': 5,
#  '穿孔': 189,
#  '不锈钢': 25,
#  '分段': 17,
#  '传统': 16,
#  '自润滑': 5,
#  '延时': 116,
#  '润滑油': 4,
#  '俄文版': 1,
#  'Cyp': 2,
#  '幅面': 44,
#  '机型': 38,
#  '交换式': 1,
#  '效率': 224,
#  '山大鲁': 1,
#  '英文版': 8,
#  '页面': 168,
#  '网站': 12,
#  '框框': 7,
#  '红色': 47,
#  '字体': 19,
#  '平台': 293,
#  '除尘': 8,
#  '标记': 64,
#  '校平': 8,
#  '测试点': 1,
#  '动时': 1,
#  '失灵': 2,
#  '负向': 10,
#  '轴会': 12,
#  '机械': 119,
#  '分区': 2,
#  '无锡': 3,
#  '桥联': 10,
#  '卖点': 2,
#  '长度': 139,
#  '群组': 20,
#  'SPI': 5,
#  '说明书': 15,
#  'IPG': 57,
#  'YLS': 8,
#  'CCD': 10,
#  '对位': 3,
#  '广东地区': 1,
#  '机台': 18,
#  'PCB': 1,
#  '钢网': 1,
#  '蓝宝石': 10,
#  '陶瓷': 13,
#  '安全性': 30,
#  '上海': 7,
#  '奉贤': 1,
#  '周志祥': 8,
#  '指令': 112,
#  '起点': 101,
#  '进料': 4,
#  '管材': 185,
#  '全自动': 10,
#  '大族': 84,
#  '视频': 50,
#  '双驱': 28,
#  '专业': 21,
#  '米左右': 1,
#  '特作': 1,
#  '主动轴': 1,
#  '动轴': 1,
#  '参数设置': 49,
#  'min': 15,
#  '触点': 1,
#  '高能': 35,
#  'BMC1204': 1,
#  '脉冲': 34,
#  '平率': 1,
#  'KHz': 5,
#  'MHz': 2,
#  '比例': 11,
#  'Coreldraw': 1,
#  '绘制': 94,
#  '贝塞尔': 7,
#  '广告行业': 12,
#  'coreldraw': 2,
#  '绘图': 75,
#  'DXF': 28,
#  '格式': 68,
#  'CYPCUT': 8,
#  '圆是': 2,
#  '插件': 7,
#  '整圆': 4,
#  '分层': 2,
#  '性能': 33,
#  '冲孔': 4,
#  'MoveBy': 3,
#  '边界': 19,
#  '动会': 1,
#  '意义': 26,
#  '干涉仪': 20,
#  '光路': 10,
#  'ping': 1,
#  '本机': 6,
#  '地址': 22,
#  '高器': 151,
#  '宏石': 2,
#  '压力': 13,
#  '气体': 81,
#  '全部': 100,
#  '内存': 14,
#  '测试软件': 12,
#  'lxd': 41,
#  '全选': 14,
#  '间隙': 15,
#  'NestPart1371': 1,
#  'Access': 1,
#  'violation': 1,
#  'address': 2,
#  'D35E': 1,
#  'module': 1,
#  'cutext': 1,
#  'bpl': 4,
#  'Read': 1,
#  'C盘': 6,
#  '还原卡': 1,
#  '病毒感染': 1,
#  '平竖直': 3,
#  '直线': 103,
#  '钣金': 16,
#  '钣金件': 3,
#  '次序': 13,
#  '倒序': 2,
#  '钢管': 3,
#  '头部': 1,
#  '尾部': 2,
#  '界面显示': 30,
#  '刀线': 8,
#  '选择性': 3,
#  '大乘': 1,
#  '中心': 75,
#  '桌面': 4,
#  '开始菜单': 2,
#  '快捷方式': 2,
#  '名称': 95,
#  '图标': 36,
#  '文件夹': 23,
#  '驱动程序': 3,
#  '桌面上': 1,
#  '驱动器': 68,
#  '信号线': 1,
#  '电阻': 1,
#  '设计方案': 3,
#  '烧角': 5,
#  '厚板': 60,
#  '现象': 67,
#  '正方形': 8,
#  '拐角处': 19,
#  '水平': 32,
#  '天泓': 1,
#  '陈兆': 1,
#  '高功率': 50,
#  '尖角': 18,
#  '很漂亮': 1,
#  '天泓汪': 1,
#  '厂里': 2,
#  '工艺员': 1,
#  '黄工': 17,
#  '备份': 39,
#  '大功率': 9,
#  '光闸': 18,
#  '时序': 13,
#  'ProgramStart': 2,
#  '峰值': 26,
#  '电流': 17,
#  '大程度': 1,
#  '形式': 69,
#  'QCW': 28,
#  '指标': 7,
#  '乘积': 1,
#  '设定值': 12,
#  '符合要求': 3,
#  '触摸屏': 6,
#  'OUT': 8,
#  'CAD': 111,
#  '嘉兴': 1,
#  '瑞博': 1,
#  '客服': 138,
#  '重画': 5,
#  '内膜': 7,
#  '批量': 84,
#  '阈值': 18,
#  '范围': 127,
#  '固定设置': 1,
#  '标准': 90,
#  '提高效率': 24,
#  '节省': 34,
#  '人力': 7,
#  '卡盘': 169,
#  '浮头': 11,
#  '图案': 8,
#  '区别': 32,
#  '矩形': 88,
#  '原理': 12,
#  '方向': 160,
#  '坐标值': 18,
#  '支架': 103,
#  '金运': 9,
#  '区分': 125,
#  '交款': 1,
#  '伤感情': 1,
#  '人情味': 1,
#  '联系': 17,
#  '人性化': 3,
#  'CypTube': 21,
#  '丝杠': 1,
#  '导轨': 1,
#  '受限制': 3,
#  '走时': 3,
#  '利用': 41,
#  '托架': 1,
#  '太长': 1,
#  '支撑点': 2,
#  '圆孔': 33,
#  '小圆孔': 10,
#  '引线': 123,
#  '技术': 31,
#  '装机': 41,
#  '油路': 3,
#  '冲油': 1,
#  '油泵': 4,
#  '供油': 1,
#  '灯光': 5,
#  '尺寸': 144,
#  '重置': 8,
#  '自动记录': 5,
#  '收款': 2,
#  '演示版': 8,
#  '有所': 11,
#  '差异': 13,
#  '自动识别': 25,
#  '专用': 36,
#  '方便使用': 7,
#  '办事处': 1,
#  '环境': 30,
#  '光束': 2,
#  '特性': 13,
#  '气流': 2,
#  '顺时针': 15,
#  '逆时针': 14,
#  '远程': 27,
#  '固件': 36,
#  'V3059': 1,
#  '以太网': 1,
#  '文件名': 25,
#  'BCV3': 1,
#  'AFM': 1,
#  '字节': 1,
#  'ASCII': 1,
#  'x41': 1,
#  'x46': 1,
#  'x4D': 1,
#  'x10': 2,
#  'x42': 1,
#  'x43': 1,
#  'x53': 1,
#  'x31': 1,
#  'x30': 1,
#  '版本号': 18,
#  '市面上': 9,
#  '概率': 37,
#  '头会': 8,
#  '事情': 20,
#  '声音': 5,
#  '感观': 1,
#  '视觉效果': 10,
#  'Nlight': 2,
#  '齿条': 10,
#  'cfgpkg': 2,
#  '十字': 36,
#  '圆度': 8,
#  '六边形': 6,
#  '领创': 54,
#  '空心': 4,
#  '精雕': 6,
#  '中文字体': 2,
#  '重命名': 7,
#  '电动': 25,
#  '轴点': 10,
#  '端子板': 6,
#  '电容': 78,
#  '凌丰路': 1,
#  '坐标系': 44,
#  '补料': 6,
#  '定位': 266,
#  '午休': 1,
#  '胡工': 3,
#  '余料': 80,
#  '题目': 3,
#  '本体': 10,
#  'help': 1,
#  '解决方案': 21,
#  '提示信息': 15,
#  '微调': 22,
#  '生效': 121,
#  '时会': 36,
#  '图纸': 308,
#  '成品率': 1,
#  '我会': 22,
#  '单子': 19,
#  '货款': 1,
#  '理由': 7,
#  '顺序': 63,
#  '横线': 2,
#  '竖线': 1,
#  '变形': 22,
#  '技术支持': 19,
#  '网络通讯': 14,
#  '接线': 17,
#  'IP地址': 6,
#  'COM': 1,
#  '烧面': 1,
#  '板面': 12,
#  '编码器': 58,
#  '坡口': 25,
#  '名词解释': 1,
#  '唐总': 21,
#  '平面曲线': 1,
#  '直观': 68,
#  '总和': 1,
#  '明白': 2,
#  '相贯孔': 4,
#  '工序': 21,
#  '直角': 9,
#  '小孔': 9,
#  '空间': 21,
#  '交汇点': 1,
#  '圆心': 11,
#  '半径': 31,
#  '逻辑': 113,
#  '环切': 5,
#  '程度': 32,
#  '鼠标': 63,
#  '上料': 63,
#  '时动': 1,
#  '机械设计': 6,
#  '普适性': 2,
#  '策略': 16,
#  '死机': 3,
#  '方向向': 1,
#  '单张': 6,
#  '水平线': 3,
#  '形状': 30,
#  '研发部': 9,
#  '个数': 25,
#  '块板': 1,
#  '评价': 7,
#  '框架': 10,
#  '易用性': 6,
#  '原件': 1,
#  '利用率': 50,
#  'Mark': 52,
#  '图像': 28,
#  '模板': 52,
#  '误会': 3,
#  '关联': 36,
#  '顶料': 5,
#  '镀金': 1,
#  '表面': 20,
#  '过程中将': 2,
#  '错位': 11,
#  '操作员': 25,
#  '小心': 12,
#  'ESC': 4,
#  'AFK': 1,
#  'away': 1,
#  'from': 7,
#  'keyboard': 1,
#  '镜头': 9,
#  '视野': 30,
#  '眼镜': 4,
#  '行业': 24,
#  'mark': 89,
#  '工位': 33,
#  '视窗': 4,
#  '畸变': 2,
#  '苹果': 2,
#  'logo': 8,
#  '背盖': 1,
#  '摄像头': 6,
#  '闪光灯': 1,
#  '定位精度': 11,
#  '矩形框': 3,
#  '绿色': 24,
#  '白色': 20,
#  '同向': 1,
#  '彭文斌': 13,
#  'ready': 5,
#  'start': 1,
#  '赵建': 19,
#  '整板': 13,
#  '贴膜': 3,
#  '建都': 1,
#  '歧义': 7,
#  '所弹': 1,
#  '配件': 7,
#  '错误判断': 1,
#  '高效率': 3,
#  'cutup': 1,
#  '面积': 12,
#  '凭感觉': 1,
#  '实用性': 5,
#  '一键': 85,
#  'MARK': 2,
#  '制图员': 3,
#  '手点': 2,
#  '大端': 1,
#  '细边': 1,
#  '细化': 4,
#  '指向性': 1,
#  '缺相': 1,
#  '节省时间': 12,
#  '能力': 18,
#  '智能': 58,
#  '渠道': 5,
#  '阳切': 4,
#  'shift': 6,
#  '继电器': 6,
#  '常量': 1,
#  '附带': 3,
#  '高灵敏度': 1,
#  '漏光': 3,
#  '短时间': 6,
#  '内置': 9,
#  '先生': 1,
#  'Help': 1,
#  '总工': 1,
#  '须知': 1,
#  '冷水机': 1,
#  '故障诊断': 2,
#  '目录': 20,
#  '东西': 16,
#  '文件目录': 3,
#  'sysinfo': 1,
#  '命令': 28,
#  '节约': 35,
#  '粉丝': 2,
#  'cyptube': 18,
#  '倒角': 27,
#  '王飞锦': 5,
#  '行程': 75,
#  '机会': 9,
#  '装置': 41,
#  '管长': 5,
#  '支撑架': 8,
#  '开气': 9,
#  '洪涛': 34,
#  '和洲翔': 1,
#  '线段': 22,
#  '折线': 7,
#  '集体': 1,
#  '管子': 116,
#  '省料': 17,
#  '制图': 4,
#  '画图': 20,
#  '总长': 8,
#  'Word': 1,
#  'log': 3,
#  'txt': 3,
#  'word': 3,
#  '系统日志': 8,
#  '工厂': 46,
#  '成本': 64,
#  '生产商': 5,
#  '输入输出': 23,
#  '解决办法': 3,
#  '素养': 1,
#  '红光': 15,
#  '曝光': 7,
#  '交点': 12,
#  '材料库': 18,
#  '宏山': 149,
#  '焦距': 4,
#  '前会': 3,
#  '型号': 40,
#  '厚度': 76,
#  'veda': 2,
#  '入板': 2,
#  'ManualArray': 1,
#  '同类': 3,
#  '数目': 7,
#  '测试人员': 86,
#  'edit': 1,
#  '键入': 1,
#  'Edit': 1,
#  '框选': 19,
#  '右键': 25,
#  '耗时': 23,
#  '现实意义': 3,
#  '菱丰': 1,
#  '路工': 1,
#  '出边': 3,
#  '轴口': 15,
#  '测试工具': 4,
#  '字母': 8,
#  '数字': 20,
#  '信息量': 1,
#  '发生冲突': 1,
#  '矫正': 19,
#  '保温杯': 3,
#  'Demo': 7,
#  '蓝色': 16,
#  '所在位置': 2,
#  '杯口': 1,
#  '目标': 17,
#  '断面': 14,
#  '句容': 1,
#  '大华': 5,
#  '郭靖': 1,
#  '宫格': 1,
#  '格子': 3,
#  '整张': 4,
#  '温度': 20,
#  '部位': 1,
#  '装夹': 13,
#  '切段': 1,
#  '场景': 162,
#  '安全门': 9,
#  '调试模式': 6,
#  '最高级别': 1,
#  '主观': 3,
#  'YLR': 11,
#  '工人': 16,
#  '序号': 22,
#  'Integer': 4,
#  '插拔': 4,
#  'CYPTUBE': 4,
#  '丝杆': 6,
#  '单驱': 6,
#  '共用': 11,
#  '两用机': 2,
#  '误操作': 44,
#  '管板': 14,
#  '顶点': 21,
#  '特殊要求': 2,
#  '分支': 18,
#  '学生': 1,
#  '业务部': 1,
#  '薄板': 20,
#  'load': 1,
#  '焦点': 86,
#  '竞争力': 17,
#  '读数': 3,
#  '偏差': 78,
#  '检查和': 1,
#  '函数': 18,
#  '新建': 49,
#  'lxv': 13,
#  'dxf': 41,
#  '迅雷': 14,
#  '细小': 2,
#  '减速机': 8,
#  '偏位': 5,
#  '零漂': 2,
#  'machine': 12,
#  'config': 12,
#  'ZeroAdjustEn': 1,
#  '工艺品': 4,
#  '浪费': 47,
#  '整圈': 2,
#  '圈数': 5,
#  '身份': 3,
#  'LXD': 6,
#  'CypNest': 248,
#  '优势': 9,
#  'ArtEdit': 1,
#  '细节': 18,
#  '关键字': 4,
#  '菜单项': 1,
#  'vendor': 1,
#  '严巍': 9,
#  '电源': 13,
#  '泵压': 1,
#  '油位': 3,
#  '里油': 1,
#  '分割线': 3,
#  '黑色': 8,
#  '方框': 3,
#  'Beta': 1,
#  '两者': 12,
#  '消失': 18,
#  '关系': 48,
#  '厂商': 55,
#  '邦德': 34,
#  '高工': 3,
#  '字型': 3,
#  '降速': 13,
#  '高精密': 2,
#  '局部': 19,
#  '板下': 1,
#  '细分': 9,
#  'Veda': 1,
#  '张板': 8,
#  '代唐总': 5,
#  '光点': 5,
#  '断光': 1,
#  '光源': 29,
#  'Com': 1,
#  '寿命': 8,
#  '全程': 8,
#  '常开常': 3,
#  '蒲工': 1,
#  '使用寿命': 10,
#  '弹簧': 3,
#  '废料': 25,
#  '刀点': 7,
#  '外观': 5,
#  '大金': 6,
#  '基础': 55,
#  '标定': 136,
#  '最高点': 7,
#  '刻线': 1,
#  '局域网': 7,
#  '同事': 28,
#  '服务器': 13,
#  '李学文': 3,
#  '电压': 12,
#  '陈大建': 15,
#  '普雷斯特': 2,
#  '双赢': 2,
#  'DA3': 1,
#  '高电平': 7,
#  'follow': 1,
#  'DA1': 1,
#  'DA4': 1,
#  '区间': 17,
#  '公式': 8,
#  '板卡': 13,
#  '变频器': 3,
#  '减速慢行': 1,
#  'U盘': 3,
#  '不太会': 2,
#  '手机': 45,
#  '加解密': 3,
#  '卡时': 2,
#  '卡开': 1,
#  'enableport': 1,
#  '对象': 16,
#  '保险': 1,
#  '源头': 2,
#  '号口': 3,
#  'IGS': 31,
#  '模型': 16,
#  'IGSViewer': 1,
#  '唐晔': 33,
#  '按键': 34,
#  '案件': 1,
#  'cypvision': 37,
#  '数值': 30,
#  '键盘输入': 2,
#  '增益': 14,
#  '输入框': 9,
#  '加微': 8,
#  '下料': 64,
#  '缺口': 29,
#  '理论': 21,
#  '短距离': 10,
#  '浪费时间': 19,
#  '事故': 10,
#  '军方': 1,
#  '装饰': 1,
#  '领域': 3,
#  '代码生成': 1,
#  '地点': 2,
#  '可靠性': 8,
#  '角钢': 18,
#  '槽钢': 25,
#  '扁钢': 1,
#  '钢材': 2,
#  '外凸': 2,
#  '轮廓': 76,
#  '内凹': 5,
#  '借机': 1,
#  '金属': 10,
#  '背壳': 1,
#  '小圆': 21,
#  'YLP': 1,
#  '罗列': 3,
#  'Pin1': 1,
#  'Pin9': 1,
#  'Pin18': 1,
#  'Pin19': 1,
#  'Pin20': 1,
#  '光谷': 2,
#  '诺太': 1,
#  '毛胜婷': 1,
#  '德国': 4,
#  'Program': 1,
#  'Start': 1,
#  'Emission': 1,
#  'States': 1,
#  '平行': 9,
#  '二维码': 35,
#  '华俄': 7,
#  '田承新': 1,
#  '图号': 1,
#  '图库': 5,
#  '复制粘贴': 8,
#  '周小兰': 1,
#  '快捷键': 23,
#  '里点': 2,
#  '要点': 5,
#  '总经理': 2,
#  '布满': 4,
#  '缩略图': 15,
#  '工会': 2,
#  '工作日': 1,
#  '割线': 1,
#  '价值': 20,
#  '空移': 4,
#  '扳手': 1,
#  '波浪': 5,
#  '时调': 1,
#  '张宏涛': 1,
#  ...}

# %%
story_df =  pd.read_json("pms_story.json",encoding="utf-8", orient='records')
story_df
# Out:
#                         title  \
# 0                       加密狗选型
# 1              特定情况下的外框最后排序问题
# 2              带膜切割开发一个直接跟随选项
# 3                 双交换工作台的到位检测
# 4                CypOne动态速度算法
# ...                       ...
# 6133  希望可以读取图纸中的零件编号，并在报告单中显示
# 6134          图形修正界面增加文件名称的显示
# 6135           希望可以支持生成单线的余料线
# 6136   希望手动绘制余料线时，可以增加撤销上一步功能
# 6137           希望可以控制排样结果的利用率
#
#                                                    spec
# 0     {'加密狗': 2, '选型': 1, '硬件': 1, '时钟': 1, '稳定性': 1...
# 1     {'外框': 2, '排序': 3, '标图': 1, '图层': 1, '原则': 2, ...
# 2     {'选项': 1, '规则': 2, '板材': 3, '水平度': 1, '曲面': 1,...
# 3     {'工作台': 5, '由天琪': 1, '迪能': 1, '手工': 2, '按钮': 3...
# 4     {'CypOne': 1, '动态': 1, 'mmm': 4, 'and': 1, '滤波...
# ...                                                 ...
# 6133  {'图纸': 2, '编号': 5, '报告单': 4, 'CypNest': 1, '文件...
# 6134  {'图形': 4, '修正': 4, '文件名称': 1, '体验': 1, '经理': 1...
# 6135  {'单线': 2, '余料': 2, 'CypNest': 1, '红框': 1, '板材'...
# 6136          {'手动': 3, '绘制': 5, '余料': 7, 'CypNest': 2}
# 6137  {'利用率': 8, 'CypNest': 1, '老板': 2, '板材': 1, '类型...
#
# [6138 rows x 2 columns]

# %%
story_df['spec'][0]
# Out:
# {'加密狗': 2, '选型': 1, '硬件': 1, '时钟': 1, '稳定性': 1, '信誉': 1, '供货': 1, '价格': 1}
