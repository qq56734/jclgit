# %%
import requests
import json
from bs4 import BeautifulSoup
import re
from collections import Counter
import jieba
import csv
import math

def requestreport(id):
    global headers
    s = requests.Session()
    id = id
    url = 'http://oa.fscut.com/seeyon/bbs.do?method=bbsView&articleId=' + id + '&spaceType=&spaceId='

    formdata = {
        "managerMethod": "findListData",
        "arguments": '[{"pageSize":"100","pageNo":2,"spaceType":"","spaceId":"","boardId":"","listType":"latestArticle","condition":"","textfield1":"","textfield2":""}]'
    }

    r = s.post(url, data=formdata, headers=headers)

    return r








s = requests.Session()
url = 'http://oa.fscut.com/seeyon/ajax.do?d=4095&method=ajaxAction&managerName=bbsArticleManager'
headers = {
            'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36',
            'cookie': cookie,
            'Referer': 'http://oa.fscut.com/seeyon/bbs.do?method=bbsIndex&portalId=-3489196460133432033&_resourceCode=F05_bbsIndexAccount'
        }
formdata = {
                "managerMethod": "findListData",
                "arguments":'[{"pageSize":"3000","pageNo":1,"spaceType":"","spaceId":"","boardId":"","listType":"latestArticle","condition":"","textfield1":"","textfield2":""}]'
           }


r = s.post(url, data = formdata, headers = headers)

# %%
soup = BeautifulSoup(r.content, 'lxml')

# %%
import json
page_dict = json.loads(r.text)

# %%
page_dict['list']
# Out:
# [{'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '【第三届台球争霸赛预热】新的一年，新的台球故事',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '3583629909388575618',
#   'boardName': 'Share一下',
#   'clickNumber': 65,
#   'content': None,
#   'eliteFlag': True,
#   'id': '370372613879121448',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=2776208320535351064&createDate=2018-01-17&size=custom&w=100&h=100',
#   'issueName': '丁英',
#   'issueTime': '2020-08-06 11:47',
#   'issueTimeM3': '昨天 11:47',
#   'issueTimes': '2020-08-06 11:47',
#   'issueUser': '-4196022104209010899',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 6,
#   'resourceFlag': '1',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 1,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【苏州领创7.31】【方潇，石斌，陈琳琳】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 52,
#   'content': None,
#   'eliteFlag': False,
#   'id': '1859464272987701376',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/ddfb856872a5d6359383306a403ed344.png',
#   'issueName': '陈琳琳',
#   'issueTime': '2020-08-04 10:02',
#   'issueTimeM3': '08-04 10:02',
#   'issueTimes': '2020-08-04 10:02',
#   'issueUser': '148232691174821526',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【浙江永佳07.30-08.01】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 81,
#   'content': None,
#   'eliteFlag': False,
#   'id': '2353028607925307404',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/c34483e72beb1e7e503510f804744c57.png',
#   'issueName': '简桢强',
#   'issueTime': '2020-08-03 19:43',
#   'issueTimeM3': '08-03 19:43',
#   'issueTimes': '2020-08-03 19:43',
#   'issueUser': '8209260809082127663',
#   'messageNotifyFlag': True,
#   'praiseSum': 7,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【永康步阳2020.7.28】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 20,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-5189614748095656176',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4e044e9001a1b2721d901c0c32267747.png',
#   'issueName': '江浩波',
#   'issueTime': '2020-08-03 17:25',
#   'issueTimeM3': '08-03 17:25',
#   'issueTimes': '2020-08-03 17:25',
#   'issueUser': '-1687641040758488666',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【苏州迅镭_2020.7.31】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 78,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-8087053727133384079',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4035a0cabbef4a31bba7a4980451428a.png',
#   'issueName': '吴文武',
#   'issueTime': '2020-08-01 14:54',
#   'issueTimeM3': '08-01 14:54',
#   'issueTimes': '2020-08-01 14:54',
#   'issueUser': '-1098557621149611302',
#   'messageNotifyFlag': True,
#   'praiseSum': 6,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【王梦茜 7.29 无锡】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 87,
#   'content': None,
#   'eliteFlag': False,
#   'id': '4709418203275479774',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=237998064335866294&createDate=2019-09-18&size=custom&w=100&h=100',
#   'issueName': '王梦茜',
#   'issueTime': '2020-07-29 11:27',
#   'issueTimeM3': '07-29 11:27',
#   'issueTimes': '2020-07-29 11:27',
#   'issueUser': '908941047326196845',
#   'messageNotifyFlag': True,
#   'praiseSum': 8,
#   'replyNumber': 3,
#   'resourceFlag': '1',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【苏州领创 2020-07.27】【唐鹏翔 林华斌 何鑫锋】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 54,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-3563934811284878003',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4ca39ea1147144ef90af14a9ef25edfe.png',
#   'issueName': '唐鹏翔',
#   'issueTime': '2020-07-29 09:15',
#   'issueTimeM3': '07-29 09:15',
#   'issueTimes': '2020-07-29 09:15',
#   'issueUser': '-4012166801625300889',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【赵德明 陈小天 7.22昆山领创】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 57,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-4042158641027134401',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/6282dd3837d39d348bb73065b01c47e3.png',
#   'issueName': '陈小天',
#   'issueTime': '2020-07-27 12:51',
#   'issueTimeM3': '07-27 12:51',
#   'issueTimes': '2020-07-27 12:51',
#   'issueUser': '-6617558212725947243',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【7.15~7.17出差深圳圣石，大族超能，东程激光】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 51,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-2740864241153785519',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/5f8011718718c9b9a07ed89bfdd5de0d.png',
#   'issueName': '殷鄂湘',
#   'issueTime': '2020-07-20 19:39',
#   'issueTimeM3': '07-20 19:39',
#   'issueTimes': '2020-07-20 19:39',
#   'issueUser': '8912603298653356400',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【永康 7.15-7.17 门业软件推广】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 39,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-8172555293908581903',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4e044e9001a1b2721d901c0c32267747.png',
#   'issueName': '江浩波',
#   'issueTime': '2020-07-20 15:34',
#   'issueTimeM3': '07-20 15:34',
#   'issueTimes': '2020-07-20 15:34',
#   'issueUser': '-1687641040758488666',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【戴南\xa07.13-7.14\xa0调研CypNest】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 180,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-2696153348591432670',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/90b18a02db0595233d32c2da9289b299.png',
#   'issueName': '王新杰',
#   'issueTime': '2020-07-16 00:25',
#   'issueTimeM3': '07-16 00:25',
#   'issueTimes': '2020-07-16 00:25',
#   'issueUser': '-8636837236786838685',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【深圳、东莞调试1214卡2020.6.29-7.1】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 85,
#   'content': None,
#   'eliteFlag': False,
#   'id': '4971304444312437621',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/281b85a707520cced2e2a03d0a513548.png',
#   'issueName': '王涛',
#   'issueTime': '2020-07-06 14:00',
#   'issueTimeM3': '07-06 14:00',
#   'issueTimes': '2020-07-06 14:00',
#   'issueUser': '-435108549330580578',
#   'messageNotifyFlag': True,
#   'praiseSum': 5,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【卷料调试学习2020.0618-0620】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 72,
#   'content': None,
#   'eliteFlag': False,
#   'id': '7911651041792706761',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=-6930908085082763783&createDate=2017-04-01&size=custom&w=100&h=100',
#   'issueName': '石斌',
#   'issueTime': '2020-06-30 08:58',
#   'issueTimeM3': '06-30 08:58',
#   'issueTimes': '2020-06-30 08:58',
#   'issueUser': '-1727898293307815838',
#   'messageNotifyFlag': True,
#   'praiseSum': 7,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【苏州迅镭升级1214为力矩卡2020.6.22】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 62,
#   'content': None,
#   'eliteFlag': False,
#   'id': '4020014394070878549',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/281b85a707520cced2e2a03d0a513548.png',
#   'issueName': '王涛',
#   'issueTime': '2020-06-23 13:27',
#   'issueTimeM3': '06-23 13:27',
#   'issueTimes': '2020-06-23 13:27',
#   'issueUser': '-435108549330580578',
#   'messageNotifyFlag': True,
#   'praiseSum': 6,
#   'replyNumber': 2,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【庆源激光06-18-06-19】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 54,
#   'content': None,
#   'eliteFlag': False,
#   'id': '5192815444388956262',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/832c93834f19fa58d1324a9ee979bc64.png',
#   'issueName': '邓霄',
#   'issueTime': '2020-06-20 10:07',
#   'issueTimeM3': '06-20 10:07',
#   'issueTimes': '2020-06-20 10:07',
#   'issueUser': '-4844934404099849138',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【06.08-06.12\xa0马鞍山设备健康云推广上线】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 72,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-8043725623723144437',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/7555838112d44ceada94262fe4df1b90.png',
#   'issueName': '陈宇轩',
#   'issueTime': '2020-06-14 22:08',
#   'issueTimeM3': '06-14 22:08',
#   'issueTimes': '2020-06-14 22:08',
#   'issueUser': '-3650554598913323531',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【王鹏 06.08-06.12 马鞍山】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 57,
#   'content': None,
#   'eliteFlag': False,
#   'id': '4037647829680213211',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/22529cdc7dc49167522408c2aca241ed.png',
#   'issueName': '王鹏',
#   'issueTime': '2020-06-13 18:23',
#   'issueTimeM3': '06-13 18:23',
#   'issueTimes': '2020-06-13 18:23',
#   'issueUser': '2158499584690177379',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【驱动优化功能验收 6.09-6.13】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 34,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-3038039597326710076',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/eb35286c1a261c49bc04903f44c5e4e8.png',
#   'issueName': '杨钊',
#   'issueTime': '2020-06-13 17:46',
#   'issueTimeM3': '06-13 17:46',
#   'issueTimes': '2020-06-13 17:46',
#   'issueUser': '-3285102036843083033',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【6.9-6.12 马鞍山设备健康云推广】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 43,
#   'content': None,
#   'eliteFlag': False,
#   'id': '590744441766298457',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=5612331950850458780&createDate=2020-06-13&size=custom&w=100&h=100',
#   'issueName': '陈鑫火',
#   'issueTime': '2020-06-13 15:14',
#   'issueTimeM3': '06-13 15:14',
#   'issueTimes': '2020-06-13 15:14',
#   'issueUser': '7520696197759389164',
#   'messageNotifyFlag': True,
#   'praiseSum': 4,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【6.8 上海沪工安装调试激光魔盒】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 35,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-3779655148012156017',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=5612331950850458780&createDate=2020-06-13&size=custom&w=100&h=100',
#   'issueName': '陈鑫火',
#   'issueTime': '2020-06-13 15:14',
#   'issueTimeM3': '06-13 15:14',
#   'issueTimes': '2020-06-13 15:14',
#   'issueUser': '7520696197759389164',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【法利莱激光魔盒对接出差报告6.09-6.11】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 52,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-4317764853001336623',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4ddbcd4f33b9e56c3f3f3e761c1dac48.png',
#   'issueName': '杜朋飞',
#   'issueTime': '2020-06-12 09:14',
#   'issueTimeM3': '06-12 09:14',
#   'issueTimes': '2020-06-12 09:14',
#   'issueUser': '2609626361285919963',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 3,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【佛山百盛_2020.6.9】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 40,
#   'content': None,
#   'eliteFlag': False,
#   'id': '7484886418487070499',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=-4272566433067286392&createDate=2017-03-31&size=custom&w=100&h=100',
#   'issueName': '常文达',
#   'issueTime': '2020-06-11 18:37',
#   'issueTimeM3': '06-11 18:37',
#   'issueTimes': '2020-06-11 18:37',
#   'issueUser': '5223091617781139495',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2020儿童节之『你就是列文虎克』',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '3583629909388575618',
#   'boardName': 'Share一下',
#   'clickNumber': 223,
#   'content': None,
#   'eliteFlag': True,
#   'id': '7995835923654198967',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=2776208320535351064&createDate=2018-01-17&size=custom&w=100&h=100',
#   'issueName': '丁英',
#   'issueTime': '2020-06-09 11:31',
#   'issueTimeM3': '06-09 11:31',
#   'issueTimes': '2020-06-09 11:31',
#   'issueUser': '-4196022104209010899',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 0,
#   'resourceFlag': '1',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 1,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【永康门友及步阳门业出差报告6.2-6.4】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 60,
#   'content': None,
#   'eliteFlag': False,
#   'id': '3544069372531722139',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4e044e9001a1b2721d901c0c32267747.png',
#   'issueName': '江浩波',
#   'issueTime': '2020-06-05 11:37',
#   'issueTimeM3': '06-05 11:37',
#   'issueTimes': '2020-06-05 11:37',
#   'issueUser': '-1687641040758488666',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 2,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【青县终端-功能验收-吴琦5.25/27】\xa0\xa0\xa0\xa0',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 120,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-6983523811562795632',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4a02ee8d90be19cc65f49b4c98e66c17.png',
#   'issueName': '吴琦',
#   'issueTime': '2020-05-28 11:13',
#   'issueTimeM3': '05-28 11:13',
#   'issueTimes': '2020-05-28 11:13',
#   'issueUser': '3089059896164239820',
#   'messageNotifyFlag': True,
#   'praiseSum': 7,
#   'replyNumber': 4,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告——无锡创科源七轴机器调试2020.5.27',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 66,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-6291339583005637840',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/832c93834f19fa58d1324a9ee979bc64.png',
#   'issueName': '邓霄',
#   'issueTime': '2020-05-27 10:33',
#   'issueTimeM3': '05-27 10:33',
#   'issueTimes': '2020-05-27 10:33',
#   'issueUser': '-4844934404099849138',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告 【永康门友及步阳门业出差报告2020.5.22】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 46,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-1552387664427073490',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4e044e9001a1b2721d901c0c32267747.png',
#   'issueName': '江浩波',
#   'issueTime': '2020-05-25 13:30',
#   'issueTimeM3': '05-25 13:30',
#   'issueTimes': '2020-05-25 13:30',
#   'issueUser': '-1687641040758488666',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2020/05/21-2020/05/22出差报告',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 42,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-8735969838760771545',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/1c34cc2426ced97fb6c930d3f2266eae.png',
#   'issueName': '杨浩男',
#   'issueTime': '2020-05-25 11:01',
#   'issueTimeM3': '05-25 11:01',
#   'issueTimes': '2020-05-25 11:01',
#   'issueUser': '-2130381004631686418',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【立成涂装（嘉泰终端）-2000S+BLT641调试，5.19~5.21】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 77,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-8084761168016031513',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/b40c4ed78e4412fcfcb52b1af4a9a92e.png',
#   'issueName': '李桐娜',
#   'issueTime': '2020-05-22 23:55',
#   'issueTimeM3': '05-22 23:55',
#   'issueTimes': '2020-05-22 23:55',
#   'issueUser': '6324357862305842321',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【南京迪能终端客户_20205.20-5.21】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 46,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-4921072683783075538',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/97dcaba7f267f2bc4350b8f88ff0e2bd.png',
#   'issueName': '林森',
#   'issueTime': '2020-05-22 16:30',
#   'issueTimeM3': '05-22 16:30',
#   'issueTimes': '2020-05-22 16:30',
#   'issueUser': '-8926565581902688639',
#   'messageNotifyFlag': True,
#   'praiseSum': 5,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2020.05.13无锡庆源出差报告',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 92,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-5205703266422207881',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/3785e12d3ff89af9a6884aa42c929a7e.png',
#   'issueName': '黄超华',
#   'issueTime': '2020-05-14 09:49',
#   'issueTimeM3': '05-14 09:49',
#   'issueTimes': '2020-05-14 09:49',
#   'issueUser': '-6966330768058266170',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 2,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告-【浙江永康喷码终端客户_2020.5.7】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 110,
#   'content': None,
#   'eliteFlag': False,
#   'id': '4144250447844099711',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/c34483e72beb1e7e503510f804744c57.png',
#   'issueName': '简桢强',
#   'issueTime': '2020-05-08 18:12',
#   'issueTimeM3': '05-08 18:12',
#   'issueTimes': '2020-05-08 18:12',
#   'issueUser': '8209260809082127663',
#   'messageNotifyFlag': True,
#   'praiseSum': 4,
#   'replyNumber': 3,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告-迅镭调试验证工字钢刀路和V槽拼接 2020.5.8',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 58,
#   'content': None,
#   'eliteFlag': False,
#   'id': '5420986428131264051',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=-6254228526247754254&createDate=2018-03-05&size=custom&w=100&h=100',
#   'issueName': '曾玉宗',
#   'issueTime': '2020-05-08 10:42',
#   'issueTimeM3': '05-08 10:42',
#   'issueTimes': '2020-05-08 10:42',
#   'issueUser': '1554812635338131498',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 0,
#   'resourceFlag': '1',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【无锡庆源终端客户_2020.4.26】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 66,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-3488330644995683278',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=-4272566433067286392&createDate=2017-03-31&size=custom&w=100&h=100',
#   'issueName': '常文达',
#   'issueTime': '2020-04-29 19:45',
#   'issueTimeM3': '04-29 19:45',
#   'issueTimes': '2020-04-29 19:45',
#   'issueUser': '5223091617781139495',
#   'messageNotifyFlag': True,
#   'praiseSum': 6,
#   'replyNumber': 2,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告-昆山允可精密力矩卡调试',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 80,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-7848049429647505309',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/281b85a707520cced2e2a03d0a513548.png',
#   'issueName': '王涛',
#   'issueTime': '2020-04-21 18:45',
#   'issueTimeM3': '04-21 18:45',
#   'issueTimes': '2020-04-21 18:45',
#   'issueUser': '-435108549330580578',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 4,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【苏州领创_2020.4.18】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 87,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-838247824462888954',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4035a0cabbef4a31bba7a4980451428a.png',
#   'issueName': '吴文武',
#   'issueTime': '2020-04-20 14:47',
#   'issueTimeM3': '04-20 14:47',
#   'issueTimes': '2020-04-20 14:47',
#   'issueUser': '-1098557621149611302',
#   'messageNotifyFlag': True,
#   'praiseSum': 4,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2020/04/18兴化镭铭和嘉泰终端出差报告',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 65,
#   'content': None,
#   'eliteFlag': False,
#   'id': '1197943394158202027',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/26ed8ffe0f7c3fa3f74944e0068b4a90.png',
#   'issueName': '邵达',
#   'issueTime': '2020-04-18 16:40',
#   'issueTimeM3': '04-18 16:40',
#   'issueTimes': '2020-04-18 16:40',
#   'issueUser': '8599185097581609974',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 2,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '戴南出差报告【李鹏飞 4/16】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 52,
#   'content': None,
#   'eliteFlag': False,
#   'id': '1190746523259849961',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/806bde71556b442f5e08811f1d8e68c3.png',
#   'issueName': '李鹏飞',
#   'issueTime': '2020-04-17 10:19',
#   'issueTimeM3': '04-17 10:19',
#   'issueTimes': '2020-04-17 10:19',
#   'issueUser': '-3268294618358397346',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【余料识别终端客户2020.4.15】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 39,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-3671681299642496136',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/6da55d97c5768310802ac863261ef5ab.png',
#   'issueName': '徐超',
#   'issueTime': '2020-04-16 11:26',
#   'issueTimeM3': '04-16 11:26',
#   'issueTimes': '2020-04-16 11:26',
#   'issueUser': '2284505611157391419',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '戴南出差报告【刘光辉0413】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 26,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-2267868653231323480',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/41c9aef2e212b7b5c03e17ae7b27b15f.png',
#   'issueName': '刘光辉',
#   'issueTime': '2020-04-16 09:59',
#   'issueTimeM3': '04-16 09:59',
#   'issueTimes': '2020-04-16 09:59',
#   'issueUser': '-1128160936470886517',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2020.4.9-10长沙蓝思机台问题报告',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 43,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-1069296097024784789',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/281b85a707520cced2e2a03d0a513548.png',
#   'issueName': '王涛',
#   'issueTime': '2020-04-11 17:40',
#   'issueTimeM3': '04-11 17:40',
#   'issueTimes': '2020-04-11 17:40',
#   'issueUser': '-435108549330580578',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差驱动优化调试【杨钊04.11】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 31,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-1143728781014643844',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/eb35286c1a261c49bc04903f44c5e4e8.png',
#   'issueName': '杨钊',
#   'issueTime': '2020-04-11 16:59',
#   'issueTimeM3': '04-11 16:59',
#   'issueTimes': '2020-04-11 16:59',
#   'issueUser': '-3285102036843083033',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2020/04/07 - 2020/04/9 永康丽水 出差报告',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 38,
#   'content': None,
#   'eliteFlag': False,
#   'id': '6568669698089437074',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4e044e9001a1b2721d901c0c32267747.png',
#   'issueName': '江浩波',
#   'issueTime': '2020-04-10 15:29',
#   'issueTimeM3': '04-10 15:29',
#   'issueTimes': '2020-04-10 15:29',
#   'issueUser': '-1687641040758488666',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2020/04/07 -\xa02020/04/09\xa0出差报告',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 46,
#   'content': None,
#   'eliteFlag': False,
#   'id': '1864518250556834183',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/1c34cc2426ced97fb6c930d3f2266eae.png',
#   'issueName': '杨浩男',
#   'issueTime': '2020-04-10 13:39',
#   'issueTimeM3': '04-10 13:39',
#   'issueTimes': '2020-04-10 13:39',
#   'issueUser': '-2130381004631686418',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '庆源激光器测试【吴琦\xa04/8】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 68,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-4112305982183158532',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4a02ee8d90be19cc65f49b4c98e66c17.png',
#   'issueName': '吴琦',
#   'issueTime': '2020-04-09 09:39',
#   'issueTimeM3': '04-09 09:39',
#   'issueTimes': '2020-04-09 09:39',
#   'issueUser': '3089059896164239820',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '庆源出差报告【杨钊04.02】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 39,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-1504884974802287911',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/eb35286c1a261c49bc04903f44c5e4e8.png',
#   'issueName': '杨钊',
#   'issueTime': '2020-04-03 11:47',
#   'issueTimeM3': '04-03 11:47',
#   'issueTimes': '2020-04-03 11:47',
#   'issueUser': '-3285102036843083033',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '戴南终端客户出差报告【吴琦 3/30-31】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 50,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-1356594310161022185',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4a02ee8d90be19cc65f49b4c98e66c17.png',
#   'issueName': '吴琦',
#   'issueTime': '2020-03-31 17:32',
#   'issueTimeM3': '03-31 17:32',
#   'issueTimes': '2020-03-31 17:32',
#   'issueUser': '3089059896164239820',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '松江普瑞玛终端客户出差报告【3/23 刘洋 王新杰】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 87,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-5568230398016140865',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/90b18a02db0595233d32c2da9289b299.png',
#   'issueName': '王新杰',
#   'issueTime': '2020-03-24 22:40',
#   'issueTimeM3': '03-24 22:40',
#   'issueTimes': '2020-03-24 22:40',
#   'issueUser': '-8636837236786838685',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 2,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '嘉泰出差报告【20200111 唐郑伟】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 50,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-7182036449046674504',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/101e9a9d3eabad028be4061cf7374d24.png',
#   'issueName': '唐郑伟',
#   'issueTime': '2020-01-13 18:04',
#   'issueTimeM3': '01-13 18:04',
#   'issueTimes': '2020-01-13 18:04',
#   'issueUser': '-2407780570796307180',
#   'messageNotifyFlag': True,
#   'praiseSum': 6,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '威强电出差报告【1/10 崔斌 】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 39,
#   'content': None,
#   'eliteFlag': False,
#   'id': '6064479518753506985',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/7bf6582387222db3d01fa4aeae9c7115.png',
#   'issueName': '崔斌',
#   'issueTime': '2020-01-13 11:25',
#   'issueTimeM3': '01-13 11:25',
#   'issueTimes': '2020-01-13 11:25',
#   'issueUser': '8375145876648379687',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '苏州图森出差报告【1/2 周怡心 王新杰】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 72,
#   'content': None,
#   'eliteFlag': False,
#   'id': '1480869055550672818',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/90b18a02db0595233d32c2da9289b299.png',
#   'issueName': '王新杰',
#   'issueTime': '2020-01-07 09:53',
#   'issueTimeM3': '01-07 09:53',
#   'issueTimes': '2020-01-07 09:53',
#   'issueUser': '-8636837236786838685',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '庆源出差报告【1/3-吴琦/王飞锦】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 58,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-6960857084523100980',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4a02ee8d90be19cc65f49b4c98e66c17.png',
#   'issueName': '吴琦',
#   'issueTime': '2020-01-04 17:27',
#   'issueTimeM3': '01-04 17:27',
#   'issueTimes': '2020-01-04 17:27',
#   'issueUser': '3089059896164239820',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【许泽慧 长沙蓝思 20191225~28】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 81,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-4696668826737883362',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/56d5c7fb8c2c43cc420fc827b2bac93a.png',
#   'issueName': '许泽慧',
#   'issueTime': '2020-01-04 17:13',
#   'issueTimeM3': '01-04 17:13',
#   'issueTimes': '2020-01-04 17:13',
#   'issueUser': '3066113250330036353',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 6,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '嘉泰无锡终端出差报告',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 70,
#   'content': None,
#   'eliteFlag': False,
#   'id': '6728169893357830882',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/1d54f94e745c9318f631a76aeeeb160a.png',
#   'issueName': '郑羽',
#   'issueTime': '2019-12-27 14:12',
#   'issueTimeM3': '2019-12-27 14:12',
#   'issueTimes': '2019-12-27 14:12',
#   'issueUser': '-7481244331730910650',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '青县8000/830终端【吴埼/李春龙 12/24-25】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 62,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-1184189687647547546',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4a02ee8d90be19cc65f49b4c98e66c17.png',
#   'issueName': '吴琦',
#   'issueTime': '2019-12-26 12:51',
#   'issueTimeM3': '2019-12-26 12:51',
#   'issueTimes': '2019-12-26 12:51',
#   'issueUser': '3089059896164239820',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '华中区出差报告【12.16-12.19王鹏、刘鹏、徐楠】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 53,
#   'content': None,
#   'eliteFlag': False,
#   'id': '7923579663995916101',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/a73088898d4c748e5653f97f56d721bf.png',
#   'issueName': '徐楠',
#   'issueTime': '2019-12-26 08:57',
#   'issueTimeM3': '2019-12-26 08:57',
#   'issueTimes': '2019-12-26 08:57',
#   'issueUser': '3122265383833454315',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '华北出差报告【12.16\xa0-12.19唐郑伟、高飞、\xa0吴刚、王鑫、李彦龙】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 70,
#   'content': None,
#   'eliteFlag': False,
#   'id': '7999068299937270252',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/a7df037c67151ddd0ab935e2eeafb797.png',
#   'issueName': '吴刚',
#   'issueTime': '2019-12-20 08:45',
#   'issueTimeM3': '2019-12-20 08:45',
#   'issueTimes': '2019-12-20 08:45',
#   'issueUser': '-3955833189188941408',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【上海曦创通讯  2019.12.13  王新杰  周怡心】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 65,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-1204396059726494581',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/78ad1efc05f76c8f24fc51610fd06ccd.png',
#   'issueName': '周怡心',
#   'issueTime': '2019-12-16 20:23',
#   'issueTimeM3': '2019-12-16 20:23',
#   'issueTimes': '2019-12-16 20:23',
#   'issueUser': '8343717800330153133',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 0,
#   'resourceFlag': '1',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '12月12-13日 浙江松阳华威门业及无锡福臣门业出差报告',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 22,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-8791540307603667131',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4e044e9001a1b2721d901c0c32267747.png',
#   'issueName': '江浩波',
#   'issueTime': '2019-12-16 15:08',
#   'issueTimeM3': '2019-12-16 15:08',
#   'issueTimes': '2019-12-16 15:08',
#   'issueUser': '-1687641040758488666',
#   'messageNotifyFlag': True,
#   'praiseSum': 1,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
# ...
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2017年12月工作月报【宋凯敏】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '22',
#   'boardName': '工作月报',
#   'clickNumber': 7,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-5593862975226623433',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/41c6fe1dd4b4aa3cb13adca5e1b8ca10.png',
#   'issueName': '宋凯敏',
#   'issueTime': '2017-12-29 14:17',
#   'issueTimeM3': '2017-12-29 14:17',
#   'issueTimes': '2017-12-29 14:17',
#   'issueUser': '5219729575988642097',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2017年12月工作月报【史大真】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '22',
#   'boardName': '工作月报',
#   'clickNumber': 32,
#   'content': None,
#   'eliteFlag': False,
#   'id': '4838956575764334685',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=4640110525912072364&createDate=2017-04-11&size=custom&w=100&h=100',
#   'issueName': '史大真',
#   'issueTime': '2017-12-29 13:55',
#   'issueTimeM3': '2017-12-29 13:55',
#   'issueTimes': '2017-12-29 13:55',
#   'issueUser': '2013097229510985326',
#   'messageNotifyFlag': True,
#   'praiseSum': 3,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2017年12月份工作月报【毛良】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '22',
#   'boardName': '工作月报',
#   'clickNumber': 8,
#   'content': None,
#   'eliteFlag': False,
#   'id': '5877868471448587944',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/b8906ecedb9de2205a86956a195057b8.png',
#   'issueName': '毛良',
#   'issueTime': '2017-12-29 11:48',
#   'issueTimeM3': '2017-12-29 11:48',
#   'issueTimes': '2017-12-29 11:48',
#   'issueUser': '-2007403799360092699',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2017年12月工作月报【常文达】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '22',
#   'boardName': '工作月报',
#   'clickNumber': 10,
#   'content': None,
#   'eliteFlag': False,
#   'id': '8128432452285647915',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=-4272566433067286392&createDate=2017-03-31&size=custom&w=100&h=100',
#   'issueName': '常文达',
#   'issueTime': '2017-12-29 11:42',
#   'issueTimeM3': '2017-12-29 11:42',
#   'issueTimes': '2017-12-29 11:42',
#   'issueUser': '5223091617781139495',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2017年12月工作月报【赵庆来】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '22',
#   'boardName': '工作月报',
#   'clickNumber': 7,
#   'content': None,
#   'eliteFlag': False,
#   'id': '5929032478338010074',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=4545811146815064927&createDate=2017-04-27 10:19&size=custom&w=100&h=100',
#   'issueName': '赵庆来',
#   'issueTime': '2017-12-29 10:41',
#   'issueTimeM3': '2017-12-29 10:41',
#   'issueTimes': '2017-12-29 10:41',
#   'issueUser': '-8989073687348493870',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2017年12月工作月报【田恒英】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '22',
#   'boardName': '工作月报',
#   'clickNumber': 14,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-5769707927072390853',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=-7656537583420682398&createDate=2018-12-20&size=custom&w=100&h=100',
#   'issueName': '田恒英',
#   'issueTime': '2017-12-29 10:38',
#   'issueTimeM3': '2017-12-29 10:38',
#   'issueTimes': '2017-12-29 10:38',
#   'issueUser': '8518256903609929087',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '1',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2017年12月工作月报【章胜平】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '22',
#   'boardName': '工作月报',
#   'clickNumber': 9,
#   'content': None,
#   'eliteFlag': False,
#   'id': '6397992796892972455',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/b67cec8e553ecc15a81ca19445b19ddb.png',
#   'issueName': '章胜平',
#   'issueTime': '2017-12-29 10:19',
#   'issueTimeM3': '2017-12-29 10:19',
#   'issueTimes': '2017-12-29 10:19',
#   'issueUser': '-4513234909620123416',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2017年12月工作月报【刘力宁】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '22',
#   'boardName': '工作月报',
#   'clickNumber': 23,
#   'content': None,
#   'eliteFlag': False,
#   'id': '6746752484501637166',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/e5347b9275708c21fdf1b9582ea4c929.png',
#   'issueName': '刘力宁',
#   'issueTime': '2017-12-28 19:42',
#   'issueTimeM3': '2017-12-28 19:42',
#   'issueTimes': '2017-12-28 19:42',
#   'issueUser': '8211388295382714617',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【谢淼、罗一尧 12.25-12.27 大族超能、铭镭】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 22,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-3127222517035020390',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=-1035928155503116278&createDate=2017-03-31 17:32&size=custom&w=100&h=100',
#   'issueName': '罗一尧',
#   'issueTime': '2017-12-28 17:45',
#   'issueTimeM3': '2017-12-28 17:45',
#   'issueTimes': '2017-12-28 17:45',
#   'issueUser': '5417414740312671435',
#   'messageNotifyFlag': True,
#   'praiseSum': 2,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '2017年12月工作月报【李欣曈】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '22',
#   'boardName': '工作月报',
#   'clickNumber': 17,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-1228001947976514222',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/cb6b380dd81e49cb104a3390927570f9.png',
#   'issueName': '李欣曈',
#   'issueTime': '2017-12-28 11:05',
#   'issueTimeM3': '2017-12-28 11:05',
#   'issueTimes': '2017-12-28 11:05',
#   'issueUser': '981964820463963413',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【范肇宸\xa0深圳、东莞\xa020171212-1221】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 30,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-4055684694445047423',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/ea4c339a540e60e40d0380016b8b921f.png',
#   'issueName': '范肇宸',
#   'issueTime': '2017-12-23 15:46',
#   'issueTimeM3': '2017-12-23 15:46',
#   'issueTimes': '2017-12-23 15:46',
#   'issueUser': '5154870138115408338',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 3,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【赵德明\xa012.21\xa0洛阳】',
#   'attachmentFlag': True,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 49,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-6196738118622034384',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=-7490986014663293190&createDate=2017-04-05&size=custom&w=100&h=100',
#   'issueName': '赵德明',
#   'issueTime': '2017-12-23 14:04',
#   'issueTimeM3': '2017-12-23 14:04',
#   'issueTimes': '2017-12-23 14:04',
#   'issueUser': '-4844067090144016419',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 5,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【林彩芳 昆山维康 20171222】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 17,
#   'content': None,
#   'eliteFlag': False,
#   'id': '5704853882155190051',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=3127791483294731216&createDate=2017-08-21&size=custom&w=100&h=100',
#   'issueName': '林彩芳',
#   'issueTime': '2017-12-23 14:03',
#   'issueTimeM3': '2017-12-23 14:03',
#   'issueTimes': '2017-12-23 14:03',
#   'issueUser': '6774849862957223454',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【韦敏全12.11-12.15昆明，杭州】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 26,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-8220094545783796299',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=5168323702697443438&createDate=2017-04-05 09:08&size=custom&w=100&h=100',
#   'issueName': '韦敏全',
#   'issueTime': '2017-12-22 14:24',
#   'issueTimeM3': '2017-12-22 14:24',
#   'issueTimes': '2017-12-22 14:24',
#   'issueUser': '1311891593183906802',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 2,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【吴琦\xa0\xa012.14-12.15\xa0\xa0南京/宿州】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 44,
#   'content': None,
#   'eliteFlag': False,
#   'id': '9146432112295563079',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/4a02ee8d90be19cc65f49b4c98e66c17.png',
#   'issueName': '吴琦',
#   'issueTime': '2017-12-19 11:38',
#   'issueTimeM3': '2017-12-19 11:38',
#   'issueTimes': '2017-12-19 11:38',
#   'issueUser': '3089059896164239820',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【鞠勇、陈明毅 12/14-12/15  浙江绍兴超能终端客户 】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 51,
#   'content': None,
#   'eliteFlag': False,
#   'id': '3052728123357938268',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/085437834492220f2287f197f0b633ae.png',
#   'issueName': '陈明毅',
#   'issueTime': '2017-12-17 22:37',
#   'issueTimeM3': '2017-12-17 22:37',
#   'issueTimes': '2017-12-17 22:37',
#   'issueUser': '4106509693746565080',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 1,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【张卫杰\xa02017.12.14\xa0苏州&无锡】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 54,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-5753744264578644783',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=5992981396458064202&createDate=2019-07-21&size=custom&w=100&h=100',
#   'issueName': '张卫杰',
#   'issueTime': '2017-12-16 18:10',
#   'issueTimeM3': '2017-12-16 18:10',
#   'issueTimes': '2017-12-16 18:10',
#   'issueUser': '-2719599582976982951',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 9,
#   'resourceFlag': '1',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【江舟亚 12/14 苏州】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 24,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-2509634321934432083',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/commonimage.do?method=showImage&id=2600938440620525587&createDate=2017-03-31&size=custom&w=100&h=100',
#   'issueName': '江舟亚',
#   'issueTime': '2017-12-15 17:37',
#   'issueTimeM3': '2017-12-15 17:37',
#   'issueTimes': '2017-12-15 17:37',
#   'issueUser': '2834791072012518945',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 0,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  {'accountId': None,
#   'adminFlag': False,
#   'anonymousFlag': False,
#   'anonymousReplyFlag': None,
#   'articleName': '出差报告【王鑫\xa012.4~12.11\xa0无锡/扬州】',
#   'attachmentFlag': False,
#   'board': None,
#   'boardId': '23',
#   'boardName': '出差报告',
#   'clickNumber': 41,
#   'content': None,
#   'eliteFlag': False,
#   'id': '-2603714859438879469',
#   'imgUrl': None,
#   'isAdminFlag': False,
#   'issueArea': None,
#   'issueImage': '/seeyon/fontimage/person/01c852464320c99f1a1f05b7c67ee8db.png',
#   'issueName': '王鑫',
#   'issueTime': '2017-12-14 19:35',
#   'issueTimeM3': '2017-12-14 19:35',
#   'issueTimes': '2017-12-14 19:35',
#   'issueUser': '2759821522906074728',
#   'messageNotifyFlag': True,
#   'praiseSum': 0,
#   'replyNumber': 2,
#   'resourceFlag': '0',
#   'spaceType': 0,
#   'state': '0',
#   'topSequence': 0,
#   'userPraiseState': False},
#  ...]

# %%
s = requests.Session()


id = '4037647829680213211'
url = 'http://oa.fscut.com/seeyon/bbs.do?method=bbsView&articleId=' + id + '&spaceType=&spaceId='

cookie = 'JSESSIONID=6CA24E3B955E05BCCB4D5EB165CC14FE'
headers = {
            'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36',
            'cookie': cookie,
            'Referer': 'http://oa.fscut.com/seeyon/bbs.do?method=bbsIndex&portalId=-3489196460133432033&_resourceCode=F05_bbsIndexAccount'
        }


formdata = {
    "managerMethod": "findListData",
    "arguments": '[{"pageSize":"100","pageNo":2,"spaceType":"","spaceId":"","boardId":"","listType":"latestArticle","condition":"","textfield1":"","textfield2":""}]'
}

r = s.post(url, data=formdata, headers=headers)

# %%
r.content
# Out:
# b'\r\n<!DOCTYPE html>\r\n<meta http-equiv="X-UA-Compatible" content="IE=EDGE" />\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!--[if lt IE 9]>\r\n<link rel="stylesheet" href="/seeyon/portal/management/css/iconfont.css?V=V7_1_2019-06-21_2640837408"/>\r\n<![endif]-->\r\n<link href="/seeyon/common/images/A8/favicon.ico?V=V7_1_2019-06-21_2640837408" type="image/x-icon" rel="icon"/>\r\n<link rel="stylesheet" href="/seeyon/common/all-min.css?V=V7_1_2019-06-21_2640837408">\r\n<!--[if (!IE)|(gte IE 9)]><!-->\r\n<link rel="stylesheet" type="text/css" href="/seeyon/skin/dist/common/special-notIE8.css?V=V7_1_2019-06-21_2640837408">\r\n<!--<![endif]-->\r\n\r\n\r\n\r\n<!-- common -->\r\n<link rel="stylesheet" href="/seeyon/skin/dist/common/skin.css?V=V7_1_2019-06-21_2640837408">\r\n<!-- components layout -->\r\n<link rel="stylesheet" href="/seeyon/skin/dist/components/components_layout.css?V=V7_1_2019-06-21_2640837408">\r\n<!-- components theme-->\r\n\r\n<link rel="stylesheet" href="/seeyon/skin/dist/components/components_theme_default.css?V=V7_1_2019-06-21_2640837408">\r\n\r\n<!-- common iconfont -->\r\n<link rel="stylesheet" type="text/css" href="/seeyon/skin/dist/fonts/common/iconfont.css?V=V7_1_2019-06-21_2640837408">\r\n\r\n\r\n<link rel="stylesheet" href="/seeyon/common/css/peoplecard.css?V=V7_1_2019-06-21_2640837408">\r\n<link rel="stylesheet" type="text/css"  href="/seeyon/common/css/dd.css?V=V7_1_2019-06-21_2640837408">\r\n<link rel="stylesheet" type="text/css"  href="/seeyon/main/skin/frame/default/default_common.css?V=V7_1_2019-06-21_2640837408">\r\n<link rel="stylesheet" id="mainSkinCss" type="text/css"  href="">\r\n<link href="/seeyon/common/css/select2.css?V=V7_1_2019-06-21_2640837408" type="text/css" rel="stylesheet" />\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<script type="text/javascript">\r\n  var CSRFTOKEN = \'null\';\r\n  var APPID = \'4095\';\r\n  var _ctxPath = \'/seeyon\', _ctxServer = \'http://oa.fscut.com:80/seeyon\';\r\n  var _locale = \'zh_CN\',_isDevelop = false,_sessionid = \'6CA24E3B955E05BCCB4D5EB165CC14FE\',_isModalDialog = false;\r\n  var _editionI18nSuffix = \'\';\r\n  \r\n  var _resourceCode = "";\r\n  var seeyonProductId="2";\r\n  var systemfileUploadmaxsize="10485760";\r\n  var _fontNames = \'\';\r\n</script>\r\n\r\n\r\n <script type="text/javascript">\r\n var setFlag=false;\r\n  if(typeof Set!="undefined"){\r\n     var SysSet=Set;\r\n     setFlag=true;\r\n  }\r\n </script>\r\n\r\n\r\n\r\n\r\n\r\n\r\n<script type="text/javascript" src="/seeyon/common/all-min.js?V=V7_1_2019-06-21_2640837408"></script>\r\n\r\n<script type="text/javascript" src="/seeyon/common/js/ui/calendar/calendar-language.js?V=V7_1_2019-06-21_2640837408"></script>\r\n\r\n<script type="text/javascript" src="/seeyon/main.do?method=headerjs&login=1117346058"></script>\r\n<script type="text/javascript">\r\n\r\nvar addinMenus = new Array();\r\n\r\n\r\n$.ctx._currentPathId = \'bbs_bbsView\';\r\n$.ctx._pageSize = 20;\r\n\r\n$.ctx._emailShow = true;\r\n$.ctx.fillmaps = null;\r\n$.releaseOnunload();\r\n</script>\r\n\r\n<script type="text/javascript" src="/seeyon/ajaxStub.js?v=1596552643181"></script>\r\n\r\n<script type="text/javascript" src="/seeyon/common/image/jquery.touchTouch-debug.js?V=V7_1_2019-06-21_2640837408"></script>\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<html xmlns="http://www.w3.org/1999/xhtml">\r\n\t<head>\r\n\t\t<meta charset="utf-8">\r\n\t\t<title>\xe5\x87\xba\xe5\xb7\xae\xe6\x8a\xa5\xe5\x91\x8a\xe3\x80\x90\xe7\x8e\x8b\xe9\xb9\x8f&nbsp;06.08-06.12&nbsp;\xe9\xa9\xac\xe9\x9e\x8d\xe5\xb1\xb1\xe3\x80\x91</title>\r\n\t\t<link rel="stylesheet" type="text/css" href="/seeyon/skin/dist/modules/bbs.css?V=V7_1_2019-06-21_2640837408" />\r\n\t\t<link rel="stylesheet" type="text/css" href="/seeyon/apps_res/bbs/css/discuss_info.css?V=V7_1_2019-06-21_2640837408" />\r\n\t\t<script src="/seeyon/apps_res/bbs/js/discuss_info.js?V=V7_1_2019-06-21_2640837408"></script>\r\n\t\t<script src="/seeyon/apps_res/bbs/js/common.js?V=V7_1_2019-06-21_2640837 ...
